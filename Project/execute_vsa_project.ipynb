# %%
import os
print("Current working directory:", os.getcwd())

# %%
# Call the scanner

# Call the scanner
import asyncio
import sys
import os
project_dir = os.path.join(os.getcwd(), "Project")
sys.path.insert(0, project_dir)
print(f"✓ Added {project_dir} to sys.path")
from run_scanner import run, run_all_exchanges, run_multi_timeframes, run_multi_timeframes_all_exchanges, run_optimized_scans
from scanner.main import kline_cache

# Define futures exchanges
futures_exchanges = ["binance_futures", "bybit_futures", "mexc_futures", "gateio_futures"]
spot_exchanges = ["binance_spot", "bybit_spot", "kucoin_spot", "mexc_spot", "gateio_spot" ]

kline_cache.clear()  # Clear cache for fresh data

# # Scan on futures exchanges
# result = await run_all_exchanges(
#     timeframe="4h",                    # Example timeframe (adjust as needed)
#     strategies=["breakout_bar", "reversal_bar", "pin_down", "breakout_bar"],       # Strategy to scan
#     exchanges=futures_exchanges,       # Custom list of futures exchanges
#     users=["default"],                 # Recipients for Telegram notifications
#     send_telegram=True,                 # Enable Telegram notifications
#     min_volume_usd=None
# )

# # Scan on spot exchanges
# result = await run_all_exchanges(
#     timeframe="4h",                    # Example timeframe (adjust as needed)
#     strategies=["breakout_bar"],       # Strategy to scan
#     exchanges=spot_exchanges,       # Custom list of futures exchanges
#     users=["default"],                 # Recipients for Telegram notifications
#     send_telegram=True,                # Enable Telegram notifications
#     min_volume_usd=None
# )

# # Single exchange, one strategy
# result = await run("mexc_spot", "1d", ["breakout_bar"], ["default"], min_volume_usd=None)

# Multiple strategies
# result2 = await run("gateio_futures", "1d", ["pin_down", "breakout_bar"], ["default"], False, min_volume_usd=None)


# # For a single exchange with multiple timeframes
# result = await run_multi_timeframes(
#     exchange=futures_exchanges,
#     timeframes=["1d", "2d", "4h"],
#     strategies=["breakout_bar", "reversal_bar"],
#     users=["default"],
#     send_telegram=True
# )

# # For all exchanges with multiple timeframes
# result = await run_multi_timeframes_all_exchanges(
#     timeframes=["4h"],
#     strategies=["reversal_bar", "breakout_bar"],
#     exchanges=None,
#     users=["default"],
#     send_telegram=True
# )

# Run optimized scans with all timeframes: priotirize 4h, 1d, 2d and then 1w with smart cache mangement for built 2d and 1w.
# There is also a mapping between timeframes, spot/futrures exchanges and strategy. Start_ bar is irrelevant for 4h typically. 
result = await run_optimized_scans(
    timeframes=["4h", "1d", "2d", "1w"],  # Specify which timeframes to scan
    users=["default"],                    # Recipients for Telegram notifications
    send_telegram=True,                   # Enable Telegram notifications
    min_volume_usd=None                   # Use default volume thresholds
)

# # Run with specific timeframes
# result = await run_optimized_scans(
#     timeframes=["1d", "2d"],  # Only scan daily and 2-day timeframes
#     users=["default"],
#     send_telegram=False       # Disable Telegram for testing
# )
# Out:
# ✓ Added /home/jovyan/work/Crypto/sevenfigures-bot/hbs_2025/Project to sys.path
# Cache cleared before processing 4h timeframe
# Scanning binance_spot 4h for breakout_bar
# ================================================================================
#   RUNNING OPTIMIZED STRATEGY SCANS
# ================================================================================
#
# • Timeframes: 1d, 1w, 2d, 4h
# • Notifications: Enabled
# • Recipients: default
#
# Processing 4h timeframe...
# Found 402 markets on Binance Spot for 4h timeframe
# Scanning Binance Spot markets (4h): 100% 402/402 [03:00<00:00,  2.23it/s]
# Scanning bybit_spot 4h for breakout_bar
# Found 528 markets on Bybit for 4h timeframe
# Scanning Bybit markets (4h): 100% 528/528 [02:49<00:00,  3.12it/s]
# Scanning gateio_spot 4h for breakout_bar
# Found 2835 markets on Gateio for 4h timeframe
# Scanning Gateio markets (4h): 100% 2835/2835 [07:57<00:00,  5.93it/s]
# Scanning mexc_spot 4h for breakout_bar
# Found 2772 markets on Mexc for 4h timeframe
# Scanning Mexc markets (4h):  98% 2730/2772 [09:41<00:09,  4.46it/s]Error fetching klines for ZENIXUSDT: Integer out of range. at position 74
# Scanning Mexc markets (4h): 100% 2772/2772 [09:53<00:00,  4.67it/s]
# Scanning kucoin_spot 4h for breakout_bar
# Found 1011 markets on Kucoin for 4h timeframe
# Scanning Kucoin markets (4h):  24% 240/1011 [00:45<02:15,  5.68it/s]breakout_bar detected for DOP-USDT
# breakout_bar detected for DOP-USDT
# Scanning Kucoin markets (4h): 100% 1011/1011 [03:11<00:00,  5.28it/s]
# HTTP Request: POST https://api.telegram.org/bot7501317114:AAHqd8BYNqR81zWEHAuwQhKji1fOM9HxjdQ/getMe "HTTP/1.1 200 OK"
# Application started
# HTTP Request: POST https://api.telegram.org/bot7501317114:AAHqd8BYNqR81zWEHAuwQhKji1fOM9HxjdQ/sendMessage "HTTP/1.1 200 OK"
# Application is stopping. This might take a moment.
# Application.stop() complete
# Scanning binance_futures 4h for reversal_bar, volume_surge
# Found 384 markets on Binance Futures for 4h timeframe
# Scanning Binance Futures markets (4h):  10% 40/384 [00:16<02:26,  2.35it/s]volume_surge detected for ASTRUSDT (last closed bar)
# volume_surge detected for ASTRUSDT
# Scanning Binance Futures markets (4h):  21% 80/384 [00:33<02:05,  2.41it/s]volume_surge detected for BSWUSDT (last closed bar)
# volume_surge detected for BSWUSDT
# Scanning Binance Futures markets (4h):  23% 90/384 [00:37<02:00,  2.44it/s]volume_surge detected for CHESSUSDT (last closed bar)
# volume_surge detected for CHESSUSDT
# Scanning Binance Futures markets (4h):  29% 110/384 [00:45<01:56,  2.35it/s]volume_surge detected for DODOXUSDT (last closed bar)
# volume_surge detected for DODOXUSDT
# Scanning Binance Futures markets (4h):  36% 140/384 [00:59<01:45,  2.32it/s]volume_surge detected for FLMUSDT (last closed bar)
# volume_surge detected for FLMUSDT
# Scanning Binance Futures markets (4h):  52% 200/384 [01:24<01:18,  2.33it/s]volume_surge detected for LOKAUSDT (last closed bar)
# volume_surge detected for LOKAUSDT
# Scanning Binance Futures markets (4h):  55% 210/384 [01:28<01:15,  2.31it/s]volume_surge detected for MBOXUSDT (last closed bar)
# volume_surge detected for MBOXUSDT
# Scanning Binance Futures markets (4h):  60% 230/384 [01:37<01:05,  2.36it/s]volume_surge detected for NKNUSDT (last closed bar)
# volume_surge detected for NKNUSDT
# Scanning Binance Futures markets (4h):  65% 250/384 [01:45<00:56,  2.36it/s]volume_surge detected for PERPUSDT (last closed bar)
# volume_surge detected for PERPUSDT
# Scanning Binance Futures markets (4h):  70% 270/384 [01:53<00:47,  2.40it/s]volume_surge detected for RAREUSDT (last closed bar)
# volume_surge detected for RAREUSDT
# Scanning Binance Futures markets (4h):  83% 320/384 [02:15<00:27,  2.32it/s]volume_surge detected for SYSUSDT (last closed bar)
# volume_surge detected for SYSUSDT
# Scanning Binance Futures markets (4h):  86% 330/384 [02:19<00:23,  2.30it/s]volume_surge detected for TLMUSDT (last closed bar)
# volume_surge detected for TLMUSDT
# Scanning Binance Futures markets (4h):  91% 350/384 [02:28<00:15,  2.26it/s]volume_surge detected for VOXELUSDT (last closed bar)
# volume_surge detected for VOXELUSDT
# Scanning Binance Futures markets (4h): 100% 384/384 [02:45<00:00,  2.32it/s]
# HTTP Request: POST https://api.telegram.org/bot7553154813:AAG4KU9eAEhSpFRgIgNR5vpG05mT8at4Udw/getMe "HTTP/1.1 200 OK"
# Application started
# HTTP Request: POST https://api.telegram.org/bot7553154813:AAG4KU9eAEhSpFRgIgNR5vpG05mT8at4Udw/sendMessage "HTTP/1.1 200 OK"
# Application is stopping. This might take a moment.
# Application.stop() complete
# Scanning bybit_futures 4h for reversal_bar, volume_surge
# Found 446 markets on Bybit Futures for 4h timeframe
# Scanning Bybit Futures markets (4h):  13% 60/446 [00:24<02:44,  2.35it/s]volume_surge detected for ASTRUSDT (last closed bar)
# volume_surge detected for ASTRUSDT
# Scanning Bybit Futures markets (4h):  22% 100/446 [00:41<02:25,  2.37it/s]volume_surge detected for BSWUSDT (last closed bar)
# volume_surge detected for BSWUSDT
# Scanning Bybit Futures markets (4h):  25% 110/446 [00:45<02:20,  2.38it/s]volume_surge detected for CHESSUSDT (last closed bar)
# volume_surge detected for CHESSUSDT
# Scanning Bybit Futures markets (4h):  38% 170/446 [01:11<01:56,  2.36it/s]volume_surge detected for FLMUSDT (last closed bar)
# volume_surge detected for FLOCKUSDT (last closed bar)
# volume_surge detected for FLMUSDT
# volume_surge detected for FLOCKUSDT
# Scanning Bybit Futures markets (4h):  45% 200/446 [01:24<01:44,  2.35it/s]volume_surge detected for HEIUSDT (last closed bar)
# volume_surge detected for HEIUSDT
# Scanning Bybit Futures markets (4h):  61% 270/446 [01:54<01:15,  2.32it/s]volume_surge detected for MBOXUSDT (last closed bar)
# volume_surge detected for MBOXUSDT
# Scanning Bybit Futures markets (4h):  67% 300/446 [02:06<01:01,  2.37it/s]volume_surge detected for NKNUSDT (last closed bar)
# volume_surge detected for NKNUSDT
# Scanning Bybit Futures markets (4h):  72% 320/446 [02:15<00:53,  2.36it/s]volume_surge detected for OXTUSDT (last closed bar)
# volume_surge detected for OXTUSDT
# Scanning Bybit Futures markets (4h):  74% 330/446 [02:19<00:48,  2.38it/s]volume_surge detected for PERPUSDT (last closed bar)
# volume_surge detected for PERPUSDT
# Scanning Bybit Futures markets (4h):  78% 350/446 [02:27<00:40,  2.35it/s]volume_surge detected for RAREUSDT (last closed bar)
# volume_surge detected for RAREUSDT
# Scanning Bybit Futures markets (4h):  94% 420/446 [02:57<00:11,  2.34it/s]volume_surge detected for SYSUSDT (last closed bar)
# volume_surge detected for SYSUSDT
# Scanning Bybit Futures markets (4h):  96% 430/446 [03:02<00:06,  2.33it/s]volume_surge detected for TLMUSDT (last closed bar)
# volume_surge detected for TLMUSDT
# Scanning Bybit Futures markets (4h):  99% 440/446 [03:06<00:02,  2.33it/s]volume_surge detected for TWTUSDT (last closed bar)
# volume_surge detected for TWTUSDT
# Scanning Bybit Futures markets (4h): 100% 446/446 [03:10<00:00,  2.34it/s]
# HTTP Request: POST https://api.telegram.org/bot7553154813:AAG4KU9eAEhSpFRgIgNR5vpG05mT8at4Udw/getMe "HTTP/1.1 200 OK"
# Application started
# HTTP Request: POST https://api.telegram.org/bot7553154813:AAG4KU9eAEhSpFRgIgNR5vpG05mT8at4Udw/sendMessage "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.telegram.org/bot7553154813:AAG4KU9eAEhSpFRgIgNR5vpG05mT8at4Udw/sendMessage "HTTP/1.1 200 OK"
# Application is stopping. This might take a moment.
# Application.stop() complete
# Scanning gateio_futures 4h for reversal_bar, volume_surge
# Found 563 markets on Gate.io Futures for 4h timeframe
# Scanning Gate.io Futures markets (4h):   0% 0/563 [00:00<?, ?it/s]volume_surge detected for 1INCH_USDT (last closed bar)
# volume_surge detected for 1INCH_USDT
# Scanning Gate.io Futures markets (4h):   9% 50/563 [00:14<02:32,  3.36it/s]volume_surge detected for AXS_USDT (last closed bar)
# volume_surge detected for AXS_USDT
# Scanning Gate.io Futures markets (4h):  16% 90/563 [00:25<01:59,  3.97it/s]volume_surge detected for BSW_USDT (last closed bar)
# volume_surge detected for BSW_USDT
# Scanning Gate.io Futures markets (4h):  32% 180/563 [00:48<01:55,  3.32it/s]volume_surge detected for FLM_USDT (last closed bar)
# volume_surge detected for FLM_USDT
# Scanning Gate.io Futures markets (4h):  59% 330/563 [01:27<00:59,  3.94it/s]volume_surge detected for NKN_USDT (last closed bar)
# volume_surge detected for NKN_USDT
# Scanning Gate.io Futures markets (4h):  66% 370/563 [01:38<00:49,  3.89it/s]volume_surge detected for PERP_USDT (last closed bar)
# volume_surge detected for PERP_USDT
# Scanning Gate.io Futures markets (4h):  71% 400/563 [01:46<00:42,  3.79it/s]volume_surge detected for RARE_USDT (last closed bar)
# volume_surge detected for RARE_USDT
# Scanning Gate.io Futures markets (4h):  89% 500/563 [02:11<00:16,  3.86it/s]volume_surge detected for UXLINK_USDT (last closed bar)
# volume_surge detected for UXLINK_USDT
# Scanning Gate.io Futures markets (4h):  91% 510/563 [02:14<00:14,  3.62it/s]volume_surge detected for VOXEL_USDT (last closed bar)
# volume_surge detected for VOXEL_USDT
# Scanning Gate.io Futures markets (4h):  94% 530/563 [02:20<00:08,  3.78it/s]volume_surge detected for XCH_USDT (current bar)
# volume_surge detected for WING_USDT (last closed bar)
# volume_surge detected for WING_USDT
# volume_surge detected for XCH_USDT
# Scanning Gate.io Futures markets (4h): 100% 563/563 [02:31<00:00,  3.72it/s]
# HTTP Request: POST https://api.telegram.org/bot7553154813:AAG4KU9eAEhSpFRgIgNR5vpG05mT8at4Udw/getMe "HTTP/1.1 200 OK"
# Application started
# HTTP Request: POST https://api.telegram.org/bot7553154813:AAG4KU9eAEhSpFRgIgNR5vpG05mT8at4Udw/sendMessage "HTTP/1.1 200 OK"
# Application is stopping. This might take a moment.
# Application.stop() complete
# Scanning mexc_futures 4h for reversal_bar, volume_surge
# Found 725 markets on MEXC Futures for 4h timeframe
# Scanning MEXC Futures markets (4h):   8% 60/725 [00:16<03:13,  3.44it/s]volume_surge detected for ASTR_USDT (last closed bar)
# volume_surge detected for ASTR_USDT
# Scanning MEXC Futures markets (4h):  17% 120/725 [00:34<02:45,  3.66it/s]volume_surge detected for BSW_USDT (last closed bar)
# volume_surge detected for BSW_USDT
# Scanning MEXC Futures markets (4h):  19% 140/725 [00:40<02:33,  3.81it/s]volume_surge detected for CHESS_USDT (last closed bar)
# volume_surge detected for CHESS_USDT
# Scanning MEXC Futures markets (4h):  32% 230/725 [01:06<02:32,  3.25it/s]volume_surge detected for FLM_USDT (last closed bar)
# volume_surge detected for FLM_USDT
# Scanning MEXC Futures markets (4h):  39% 280/725 [01:21<02:12,  3.35it/s]volume_surge detected for GST_USDT (last closed bar)
# volume_surge detected for GST_USDT
# Scanning MEXC Futures markets (4h):  40% 290/725 [01:23<02:00,  3.61it/s]volume_surge detected for HMSTR_USDT (last closed bar)
# volume_surge detected for HMSTR_USDT
# Scanning MEXC Futures markets (4h):  50% 360/725 [01:43<01:41,  3.60it/s]volume_surge detected for LOKA_USDT (last closed bar)
# volume_surge detected for LOKA_USDT
# Scanning MEXC Futures markets (4h):  52% 380/725 [01:50<01:45,  3.26it/s]volume_surge detected for MBOX_USDT (last closed bar)
# volume_surge detected for MBOX_USDT
# Scanning MEXC Futures markets (4h):  54% 390/725 [01:53<01:37,  3.44it/s]volume_surge detected for MINT_USDT (last closed bar)
# volume_surge detected for MINT_USDT
# Scanning MEXC Futures markets (4h):  59% 430/725 [02:04<01:21,  3.63it/s]volume_surge detected for NKN_USDT (last closed bar)
# volume_surge detected for NKN_USDT
# Scanning MEXC Futures markets (4h):  65% 470/725 [02:16<01:17,  3.28it/s]volume_surge detected for PERP_USDT (last closed bar)
# volume_surge detected for PERP_USDT
# Scanning MEXC Futures markets (4h):  70% 510/725 [02:29<01:07,  3.19it/s]volume_surge detected for RARE_USDT (last closed bar)
# volume_surge detected for RARE_USDT
# Scanning MEXC Futures markets (4h):  81% 590/725 [02:51<00:36,  3.74it/s]volume_surge detected for SUSHI_USDT (last closed bar)
# volume_surge detected for SUSHI_USDT
# Scanning MEXC Futures markets (4h):  84% 610/725 [02:57<00:32,  3.59it/s]volume_surge detected for TLM_USDT (last closed bar)
# volume_surge detected for TLM_USDT
# Scanning MEXC Futures markets (4h):  88% 640/725 [03:05<00:24,  3.52it/s]volume_surge detected for UXLINK_USDT (last closed bar)
# volume_surge detected for UXLINK_USDT
# Scanning MEXC Futures markets (4h):  91% 660/725 [03:11<00:17,  3.64it/s]volume_surge detected for VOXEL_USDT (last closed bar)
# volume_surge detected for VOXEL_USDT
# Scanning MEXC Futures markets (4h):  92% 670/725 [03:13<00:14,  3.83it/s]volume_surge detected for WING_USDT (last closed bar)
# volume_surge detected for WING_USDT
# Scanning MEXC Futures markets (4h):  97% 700/725 [03:21<00:06,  3.60it/s]reversal_bar detected for YZYSOL_USDT
# reversal_bar detected for YZYSOL_USDT
# Scanning MEXC Futures markets (4h): 100% 725/725 [03:30<00:00,  3.45it/s]
# HTTP Request: POST https://api.telegram.org/bot7837067804:AAE1H2XWMlwvogCdhQ7vJpufv6VpXaBFg8Q/getMe "HTTP/1.1 200 OK"
# Application started
# HTTP Request: POST https://api.telegram.org/bot7837067804:AAE1H2XWMlwvogCdhQ7vJpufv6VpXaBFg8Q/sendMessage "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.telegram.org/bot7553154813:AAG4KU9eAEhSpFRgIgNR5vpG05mT8at4Udw/getMe "HTTP/1.1 200 OK"
# Application started
# HTTP Request: POST https://api.telegram.org/bot7553154813:AAG4KU9eAEhSpFRgIgNR5vpG05mT8at4Udw/sendMessage "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.telegram.org/bot7553154813:AAG4KU9eAEhSpFRgIgNR5vpG05mT8at4Udw/sendMessage "HTTP/1.1 200 OK"
# Application is stopping. This might take a moment.
# Application.stop() complete
# Application is stopping. This might take a moment.
# Application.stop() complete
# Cache cleared before processing 1d timeframe
# Scanning binance_spot 1d for breakout_bar
# Processing 1d timeframe...
# Found 402 markets on Binance Spot for 1d timeframe
# Scanning Binance Spot markets (1d): 100% 402/402 [01:27<00:00,  4.61it/s]
# Scanning bybit_spot 1d for breakout_bar
# Found 528 markets on Bybit for 1d timeframe
# Scanning Bybit markets (1d): 100% 528/528 [01:40<00:00,  5.26it/s]
# Scanning gateio_spot 1d for breakout_bar
# Found 2835 markets on Gateio for 1d timeframe
# Scanning Gateio markets (1d): 100% 2835/2835 [06:58<00:00,  6.78it/s]
# Scanning mexc_spot 1d for breakout_bar
# Found 2772 markets on Mexc for 1d timeframe
# Scanning Mexc markets (1d):  95% 2620/2772 [07:38<00:25,  5.97it/s]breakout_bar detected for WPAYUSDT
# breakout_bar detected for WPAYUSDT
# Scanning Mexc markets (1d): 100% 2772/2772 [08:07<00:00,  5.68it/s]
# HTTP Request: POST https://api.telegram.org/bot7501317114:AAHqd8BYNqR81zWEHAuwQhKji1fOM9HxjdQ/getMe "HTTP/1.1 200 OK"
# Application started
# HTTP Request: POST https://api.telegram.org/bot7501317114:AAHqd8BYNqR81zWEHAuwQhKji1fOM9HxjdQ/sendMessage "HTTP/1.1 200 OK"
# Application is stopping. This might take a moment.
# Application.stop() complete
# Scanning kucoin_spot 1d for breakout_bar
# Found 1011 markets on Kucoin for 1d timeframe
# Scanning Kucoin markets (1d): 100% 1011/1011 [03:32<00:00,  4.75it/s]
# Scanning binance_futures 1d for reversal_bar, volume_surge
# Found 384 markets on Binance Futures for 1d timeframe
# Scanning Binance Futures markets (1d): 100% 384/384 [01:22<00:00,  4.67it/s]
# Scanning bybit_futures 1d for reversal_bar, volume_surge
# Found 446 markets on Bybit Futures for 1d timeframe
# Scanning Bybit Futures markets (1d): 100% 446/446 [01:31<00:00,  4.88it/s]
# Scanning gateio_futures 1d for reversal_bar, volume_surge
# Found 564 markets on Gate.io Futures for 1d timeframe
# Scanning Gate.io Futures markets (1d): 100% 564/564 [01:39<00:00,  5.64it/s]
# Scanning mexc_futures 1d for reversal_bar, volume_surge
# Found 725 markets on MEXC Futures for 1d timeframe
# Scanning MEXC Futures markets (1d): 100% 725/725 [02:10<00:00,  5.55it/s]
# Cache cleared before processing 2d timeframe
# Reusing 1d candles for building 2d candles
# Scanning binance_spot 2d for breakout_bar, start_bar
# Processing 2d timeframe...
# Found 402 markets on Binance Spot for 2d timeframe
# Scanning Binance Spot markets (2d):  30% 120/402 [00:27<01:07,  4.16it/s]start_bar detected for ELFUSDT
# start_bar detected for ELFUSDT
# Scanning Binance Spot markets (2d):  32% 130/402 [00:29<01:05,  4.18it/s]start_bar detected for EURIUSDT
# start_bar detected for EURIUSDT
# Scanning Binance Spot markets (2d):  47% 190/402 [00:44<00:51,  4.15it/s]start_bar detected for KAVAUSDT
# start_bar detected for KAVAUSDT
# Scanning Binance Spot markets (2d): 100% 402/402 [01:37<00:00,  4.14it/s]
# HTTP Request: POST https://api.telegram.org/bot7501317114:AAHqd8BYNqR81zWEHAuwQhKji1fOM9HxjdQ/getMe "HTTP/1.1 200 OK"
# Application started
# HTTP Request: POST https://api.telegram.org/bot7501317114:AAHqd8BYNqR81zWEHAuwQhKji1fOM9HxjdQ/sendMessage "HTTP/1.1 200 OK"
# Application is stopping. This might take a moment.
# Application.stop() complete
# Scanning bybit_spot 2d for breakout_bar, start_bar
# Found 528 markets on Bybit for 2d timeframe
# Scanning Bybit markets (2d):  38% 200/528 [00:41<01:06,  4.90it/s]start_bar detected for HVHUSDT
# start_bar detected for HVHUSDT
# Scanning Bybit markets (2d):  40% 210/528 [00:43<01:05,  4.85it/s]start_bar detected for JUSDT
# start_bar detected for JUSDT
# Scanning Bybit markets (2d):  45% 240/528 [00:49<00:58,  4.95it/s]start_bar detected for LUCEUSDT
# start_bar detected for LUCEUSDT
# Scanning Bybit markets (2d):  49% 260/528 [00:53<00:56,  4.74it/s]start_bar detected for MEWUSDT
# start_bar detected for MEWUSDT
# Scanning Bybit markets (2d):  83% 440/528 [01:30<00:18,  4.83it/s]start_bar detected for THNUSDT
# start_bar detected for THNUSDT
# Scanning Bybit markets (2d):  87% 460/528 [01:34<00:13,  4.92it/s]start_bar detected for UXLINKUSDT
# start_bar detected for UXLINKUSDT
# Scanning Bybit markets (2d): 100% 528/528 [01:49<00:00,  4.81it/s]
# HTTP Request: POST https://api.telegram.org/bot7501317114:AAHqd8BYNqR81zWEHAuwQhKji1fOM9HxjdQ/getMe "HTTP/1.1 200 OK"
# Application started
# HTTP Request: POST https://api.telegram.org/bot7501317114:AAHqd8BYNqR81zWEHAuwQhKji1fOM9HxjdQ/sendMessage "HTTP/1.1 200 OK"
# Application is stopping. This might take a moment.
# Application.stop() complete
# Scanning gateio_spot 2d for breakout_bar, start_bar
# Found 2835 markets on Gateio for 2d timeframe
# Scanning Gateio markets (2d):  12% 340/2835 [00:53<07:10,  5.79it/s]start_bar detected for BIGTIME_USDT
# start_bar detected for BIGTIME_USDT
# Scanning Gateio markets (2d):  14% 390/2835 [01:01<07:10,  5.68it/s]start_bar detected for BOME3S_USDT
# start_bar detected for BOME3S_USDT
# Scanning Gateio markets (2d):  44% 1260/2835 [03:18<04:01,  6.52it/s]start_bar detected for J_USDT
# start_bar detected for J_USDT
# Scanning Gateio markets (2d):  91% 2570/2835 [06:39<00:42,  6.18it/s]breakout_bar detected for UXLINK_USDT
# start_bar detected for UXLINK_USDT
# breakout_bar detected for UXLINK_USDT
# start_bar detected for UXLINK_USDT
# Scanning Gateio markets (2d): 100% 2835/2835 [07:24<00:00,  6.37it/s]
# HTTP Request: POST https://api.telegram.org/bot7501317114:AAHqd8BYNqR81zWEHAuwQhKji1fOM9HxjdQ/getMe "HTTP/1.1 200 OK"
# Application started
# HTTP Request: POST https://api.telegram.org/bot7501317114:AAHqd8BYNqR81zWEHAuwQhKji1fOM9HxjdQ/sendMessage "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.telegram.org/bot7501317114:AAHqd8BYNqR81zWEHAuwQhKji1fOM9HxjdQ/getMe "HTTP/1.1 200 OK"
# Application started
# HTTP Request: POST https://api.telegram.org/bot7501317114:AAHqd8BYNqR81zWEHAuwQhKji1fOM9HxjdQ/sendMessage "HTTP/1.1 200 OK"
# Application is stopping. This might take a moment.
# Application.stop() complete
# Application is stopping. This might take a moment.
# Application.stop() complete
# Scanning mexc_spot 2d for breakout_bar, start_bar
# Found 2772 markets on Mexc for 2d timeframe
# Scanning Mexc markets (2d):   5% 140/2772 [00:24<08:02,  5.45it/s]start_bar detected for ANYONEUSDT
# start_bar detected for ANYONEUSDT
# Scanning Mexc markets (2d):  27% 750/2772 [02:13<06:04,  5.54it/s]start_bar detected for ELFUSDT
# start_bar detected for ELFUSDT
# Scanning Mexc markets (2d):  27% 760/2772 [02:15<05:58,  5.62it/s]start_bar detected for ELYSUSDT
# start_bar detected for ELYSUSDT
# Scanning Mexc markets (2d):  43% 1200/2772 [03:32<04:07,  6.35it/s]start_bar detected for JUSDT
# start_bar detected for JUSDT
# Scanning Mexc markets (2d):  49% 1370/2772 [04:01<04:08,  5.64it/s]start_bar detected for LUCEUSDT
# start_bar detected for LUCEUSDT
# Scanning Mexc markets (2d):  53% 1460/2772 [04:18<04:13,  5.17it/s]start_bar detected for MEWUSDT
# start_bar detected for MEWUSDT
# Scanning Mexc markets (2d):  62% 1710/2772 [05:03<03:14,  5.45it/s]start_bar detected for OMZUSDT
# start_bar detected for OMZUSDT
# Scanning Mexc markets (2d):  62% 1720/2772 [05:05<03:14,  5.40it/s]start_bar detected for OOKIUSDT
# start_bar detected for OOKIUSDT
# Scanning Mexc markets (2d):  74% 2040/2772 [06:02<02:10,  5.60it/s]start_bar detected for SARAUSDT
# start_bar detected for SARAUSDT
# Scanning Mexc markets (2d):  90% 2500/2772 [07:25<00:48,  5.56it/s]start_bar detected for UXLINKUSDT
# start_bar detected for UXLINKUSDT
# Scanning Mexc markets (2d):  92% 2550/2772 [07:34<00:40,  5.54it/s]start_bar detected for VSCUSDT
# start_bar detected for VSCUSDT
# Scanning Mexc markets (2d):  96% 2670/2772 [07:56<00:18,  5.44it/s]start_bar detected for XODEXUSDT
# start_bar detected for XODEXUSDT
# Scanning Mexc markets (2d):  98% 2710/2772 [08:03<00:11,  5.56it/s]start_bar detected for YAKAUSDT
# start_bar detected for YAKAUSDT
# Scanning Mexc markets (2d): 100% 2770/2772 [08:14<00:00,  5.53it/s]start_bar detected for ZYNUSDT
# start_bar detected for ZYNUSDT
# Scanning Mexc markets (2d): 100% 2772/2772 [08:16<00:00,  5.58it/s]
# HTTP Request: POST https://api.telegram.org/bot7501317114:AAHqd8BYNqR81zWEHAuwQhKji1fOM9HxjdQ/getMe "HTTP/1.1 200 OK"
# Application started
# HTTP Request: POST https://api.telegram.org/bot7501317114:AAHqd8BYNqR81zWEHAuwQhKji1fOM9HxjdQ/sendMessage "HTTP/1.1 200 OK"
# Application is stopping. This might take a moment.
# Application.stop() complete
# Scanning kucoin_spot 2d for breakout_bar, start_bar
# Found 1011 markets on Kucoin for 2d timeframe
# Scanning Kucoin markets (2d):  11% 110/1011 [00:20<02:50,  5.29it/s]start_bar detected for BIGTIME-USDT
# start_bar detected for BIGTIME-USDT
# Scanning Kucoin markets (2d):  41% 410/1011 [01:16<01:52,  5.36it/s]start_bar detected for J-USDT
# start_bar detected for J-USDT
# Scanning Kucoin markets (2d):  48% 490/1011 [01:31<01:30,  5.78it/s]start_bar detected for LUCE-USDT
# start_bar detected for LUCE-USDT
# Scanning Kucoin markets (2d):  51% 520/1011 [01:36<01:30,  5.40it/s]start_bar detected for MEW-USDT
# start_bar detected for MEW-USDT
# Scanning Kucoin markets (2d):  71% 720/1011 [02:14<00:53,  5.40it/s]start_bar detected for RWA-USDT
# start_bar detected for RWA-USDT
# Scanning Kucoin markets (2d):  88% 890/1011 [02:45<00:21,  5.59it/s]start_bar detected for UXLINK-USDT
# start_bar detected for UXLINK-USDT
# Scanning Kucoin markets (2d): 100% 1011/1011 [03:10<00:00,  5.32it/s]
# HTTP Request: POST https://api.telegram.org/bot7501317114:AAHqd8BYNqR81zWEHAuwQhKji1fOM9HxjdQ/getMe "HTTP/1.1 200 OK"
# Application started
# HTTP Request: POST https://api.telegram.org/bot7501317114:AAHqd8BYNqR81zWEHAuwQhKji1fOM9HxjdQ/sendMessage "HTTP/1.1 200 OK"
# Application is stopping. This might take a moment.
# Application.stop() complete
# Scanning binance_futures 2d for reversal_bar, volume_surge, pin_down
# Found 384 markets on Binance Futures for 2d timeframe
# Scanning Binance Futures markets (2d): 100% 384/384 [01:27<00:00,  4.41it/s]
# Scanning bybit_futures 2d for reversal_bar, volume_surge, pin_down
# Found 446 markets on Bybit Futures for 2d timeframe
# Scanning Bybit Futures markets (2d): 100% 446/446 [01:39<00:00,  4.48it/s]
# Scanning gateio_futures 2d for reversal_bar, volume_surge, pin_down
# Found 564 markets on Gate.io Futures for 2d timeframe
# Scanning Gate.io Futures markets (2d): 100% 564/564 [01:45<00:00,  5.34it/s]
# Scanning mexc_futures 2d for reversal_bar, volume_surge, pin_down
# Found 725 markets on MEXC Futures for 2d timeframe
# Scanning MEXC Futures markets (2d):   3% 20/725 [00:02<01:46,  6.64it/s]reversal_bar detected for AGIXT_USDT
# reversal_bar detected for AGIXT_USDT
# Scanning MEXC Futures markets (2d):  99% 720/725 [02:16<00:00,  5.36it/s]reversal_bar detected for ZKJ_USDT
# reversal_bar detected for ZKJ_USDT
# Scanning MEXC Futures markets (2d): 100% 725/725 [02:19<00:00,  5.20it/s]
# HTTP Request: POST https://api.telegram.org/bot7837067804:AAE1H2XWMlwvogCdhQ7vJpufv6VpXaBFg8Q/getMe "HTTP/1.1 200 OK"
# Application started
# HTTP Request: POST https://api.telegram.org/bot7837067804:AAE1H2XWMlwvogCdhQ7vJpufv6VpXaBFg8Q/sendMessage "HTTP/1.1 200 OK"
# Application is stopping. This might take a moment.
# Application.stop() complete
# Processing 1w timeframe...
# Cache cleared before processing 1w timeframe
# Reusing 1d candles for building weekly candles where needed
# Scanning binance_spot 1w for breakout_bar, start_bar
# Found 402 markets on Binance Spot for 1w timeframe
# Scanning Binance Spot markets (1w):  30% 120/402 [00:25<01:02,  4.49it/s]start_bar detected for EOSUSDT
# start_bar detected for EOSUSDT
# Scanning Binance Spot markets (1w):  37% 150/402 [00:32<00:56,  4.48it/s]start_bar detected for GHSTUSDT
# start_bar detected for GHSTUSDT
# Scanning Binance Spot markets (1w): 100% 402/402 [01:30<00:00,  4.45it/s]
# HTTP Request: POST https://api.telegram.org/bot7501317114:AAHqd8BYNqR81zWEHAuwQhKji1fOM9HxjdQ/getMe "HTTP/1.1 200 OK"
# Application started
# HTTP Request: POST https://api.telegram.org/bot7501317114:AAHqd8BYNqR81zWEHAuwQhKji1fOM9HxjdQ/sendMessage "HTTP/1.1 200 OK"
# Application is stopping. This might take a moment.
# Application.stop() complete
# Scanning bybit_spot 1w for breakout_bar, start_bar
# Found 528 markets on Bybit for 1w timeframe
# Scanning Bybit markets (1w):  25% 130/528 [00:24<01:19,  4.98it/s]start_bar detected for EOSUSDT
# start_bar detected for EOSUSDT
# Scanning Bybit markets (1w):  28% 150/528 [00:28<01:15,  5.01it/s]breakout_bar detected for FIREUSDT
# start_bar detected for FIREUSDT
# breakout_bar detected for FIREUSDT
# start_bar detected for FIREUSDT
# Scanning Bybit markets (1w): 100% 528/528 [01:43<00:00,  5.10it/s]
# HTTP Request: POST https://api.telegram.org/bot7501317114:AAHqd8BYNqR81zWEHAuwQhKji1fOM9HxjdQ/getMe "HTTP/1.1 200 OK"
# Application started
# HTTP Request: POST https://api.telegram.org/bot7501317114:AAHqd8BYNqR81zWEHAuwQhKji1fOM9HxjdQ/sendMessage "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.telegram.org/bot7501317114:AAHqd8BYNqR81zWEHAuwQhKji1fOM9HxjdQ/getMe "HTTP/1.1 200 OK"
# Application started
# HTTP Request: POST https://api.telegram.org/bot7501317114:AAHqd8BYNqR81zWEHAuwQhKji1fOM9HxjdQ/sendMessage "HTTP/1.1 200 OK"
# Application is stopping. This might take a moment.
# Application.stop() complete
# Application is stopping. This might take a moment.
# Application.stop() complete
# Scanning gateio_spot 1w for breakout_bar, start_bar
# Found 2835 markets on Gateio for 1w timeframe
# Scanning Gateio markets (1w):  21% 590/2835 [01:24<05:26,  6.88it/s]start_bar detected for CRO_USDT
# start_bar detected for CRO_USDT
# Scanning Gateio markets (1w):  29% 820/2835 [01:58<04:42,  7.12it/s]start_bar detected for EOS5L_USDT
# start_bar detected for EOS5L_USDT
# Scanning Gateio markets (1w):  29% 830/2835 [01:59<05:09,  6.48it/s]start_bar detected for EOS_USDT
# start_bar detected for EOS_USDT
# Scanning Gateio markets (1w): 100% 2835/2835 [06:57<00:00,  6.79it/s]
# HTTP Request: POST https://api.telegram.org/bot7501317114:AAHqd8BYNqR81zWEHAuwQhKji1fOM9HxjdQ/getMe "HTTP/1.1 200 OK"
# Application started
# HTTP Request: POST https://api.telegram.org/bot7501317114:AAHqd8BYNqR81zWEHAuwQhKji1fOM9HxjdQ/sendMessage "HTTP/1.1 200 OK"
# Application is stopping. This might take a moment.
# Application.stop() complete
# Scanning mexc_spot 1w for breakout_bar, start_bar
# Found 2772 markets on Mexc for 1w timeframe
# Scanning Mexc markets (1w): 100% 2772/2772 [07:42<00:00,  5.99it/s]
# Scanning kucoin_spot 1w for breakout_bar, start_bar
# Found 1011 markets on Kucoin for 1w timeframe
# Scanning Kucoin markets (1w): 100% 1011/1011 [02:57<00:00,  5.69it/s]
# Scanning binance_futures 1w for reversal_bar, volume_surge, pin_down
# Found 384 markets on Binance Futures for 1w timeframe
# Scanning Binance Futures markets (1w):   0% 0/384 [00:00<?, ?it/s]reversal_bar detected for 1000CHEEMSUSDT
# reversal_bar detected for 1000CHEEMSUSDT
# Scanning Binance Futures markets (1w):  10% 40/384 [00:07<01:06,  5.14it/s]pin_down detected for AUCTIONUSDT
# pin_down detected for AUCTIONUSDT
# Scanning Binance Futures markets (1w):  83% 320/384 [01:03<00:12,  4.94it/s]reversal_bar detected for SWELLUSDT
# reversal_bar detected for SWELLUSDT
# Scanning Binance Futures markets (1w): 100% 384/384 [01:18<00:00,  4.89it/s]
# HTTP Request: POST https://api.telegram.org/bot7837067804:AAE1H2XWMlwvogCdhQ7vJpufv6VpXaBFg8Q/getMe "HTTP/1.1 200 OK"
# Application started
# HTTP Request: POST https://api.telegram.org/bot7837067804:AAE1H2XWMlwvogCdhQ7vJpufv6VpXaBFg8Q/sendMessage "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.telegram.org/bot7837067804:AAE1H2XWMlwvogCdhQ7vJpufv6VpXaBFg8Q/getMe "HTTP/1.1 200 OK"
# Application started
# HTTP Request: POST https://api.telegram.org/bot7837067804:AAE1H2XWMlwvogCdhQ7vJpufv6VpXaBFg8Q/sendMessage "HTTP/1.1 200 OK"
# Application is stopping. This might take a moment.
# Application.stop() complete
# Application is stopping. This might take a moment.
# Application.stop() complete
# Scanning bybit_futures 1w for reversal_bar, volume_surge, pin_down
# Found 446 markets on Bybit Futures for 1w timeframe
# Scanning Bybit Futures markets (1w):  13% 60/446 [00:10<01:14,  5.16it/s]pin_down detected for AUCTIONUSDT
# pin_down detected for AUCTIONUSDT
# Scanning Bybit Futures markets (1w):  56% 250/446 [00:48<00:37,  5.16it/s]reversal_bar detected for L3USDT
# reversal_bar detected for L3USDT
# Scanning Bybit Futures markets (1w):  94% 420/446 [01:21<00:05,  5.08it/s]reversal_bar detected for SWELLUSDT
# reversal_bar detected for SWELLUSDT
# Scanning Bybit Futures markets (1w): 100% 446/446 [01:28<00:00,  5.01it/s]
# HTTP Request: POST https://api.telegram.org/bot7837067804:AAE1H2XWMlwvogCdhQ7vJpufv6VpXaBFg8Q/getMe "HTTP/1.1 200 OK"
# Application started
# HTTP Request: POST https://api.telegram.org/bot7837067804:AAE1H2XWMlwvogCdhQ7vJpufv6VpXaBFg8Q/sendMessage "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.telegram.org/bot7837067804:AAE1H2XWMlwvogCdhQ7vJpufv6VpXaBFg8Q/getMe "HTTP/1.1 200 OK"
# Application started
# HTTP Request: POST https://api.telegram.org/bot7837067804:AAE1H2XWMlwvogCdhQ7vJpufv6VpXaBFg8Q/sendMessage "HTTP/1.1 200 OK"
# Application is stopping. This might take a moment.
# Application.stop() complete
# Application is stopping. This might take a moment.
# Application.stop() complete
# Scanning gateio_futures 1w for reversal_bar, volume_surge, pin_down
# Found 564 markets on Gate.io Futures for 1w timeframe
# Scanning Gate.io Futures markets (1w):   7% 40/564 [00:07<01:36,  5.45it/s]pin_down detected for AUCTION_USDT
# pin_down detected for AUCTION_USDT
# Scanning Gate.io Futures markets (1w):  46% 260/564 [00:45<00:52,  5.75it/s]reversal_bar detected for L3_USDT
# reversal_bar detected for L3_USDT
# Scanning Gate.io Futures markets (1w): 100% 564/564 [01:39<00:00,  5.67it/s]
# HTTP Request: POST https://api.telegram.org/bot7837067804:AAE1H2XWMlwvogCdhQ7vJpufv6VpXaBFg8Q/getMe "HTTP/1.1 200 OK"
# Application started
# HTTP Request: POST https://api.telegram.org/bot7837067804:AAE1H2XWMlwvogCdhQ7vJpufv6VpXaBFg8Q/sendMessage "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.telegram.org/bot7837067804:AAE1H2XWMlwvogCdhQ7vJpufv6VpXaBFg8Q/getMe "HTTP/1.1 200 OK"
# Application started
# HTTP Request: POST https://api.telegram.org/bot7837067804:AAE1H2XWMlwvogCdhQ7vJpufv6VpXaBFg8Q/sendMessage "HTTP/1.1 200 OK"
# Application is stopping. This might take a moment.
# Application.stop() complete
# Application is stopping. This might take a moment.
# Application.stop() complete
# Scanning mexc_futures 1w for reversal_bar, volume_surge, pin_down
# Found 725 markets on MEXC Futures for 1w timeframe
# Scanning MEXC Futures markets (1w):  10% 70/725 [00:11<01:57,  5.55it/s]pin_down detected for AUCTION_USDT
# pin_down detected for AUCTION_USDT
# Scanning MEXC Futures markets (1w): 100% 725/725 [02:10<00:00,  5.55it/s]
# HTTP Request: POST https://api.telegram.org/bot7837067804:AAE1H2XWMlwvogCdhQ7vJpufv6VpXaBFg8Q/getMe "HTTP/1.1 200 OK"
# Application started
# HTTP Request: POST https://api.telegram.org/bot7837067804:AAE1H2XWMlwvogCdhQ7vJpufv6VpXaBFg8Q/sendMessage "HTTP/1.1 200 OK"
# Application is stopping. This might take a moment.
# Application.stop() complete
# ================================================================================
#   OPTIMIZED SCAN RESULTS
# ================================================================================
#
# Total signals found: 111
#
# Breakout Bar: 4 signals
#         symbol                date     close        volume  volume_ratio  \
# 3     FIREUSDT 2025-03-24 00:00:00  0.162270  1.279186e+07      1.345520
# 2  UXLINK_USDT 2025-04-03 00:00:00  0.473700  3.754448e+06      4.225196
# 0     DOP-USDT 2025-04-03 08:00:00  0.000356  9.978631e+04      2.358801
# 1     WPAYUSDT 2025-04-02 00:00:00  0.099190  1.822916e+05      1.059461
#
#    close_off_low  current_bar  arctan_ratio timeframe     exchange
# 3      80.437965        False      4.731050        1w   bybit_spot
# 2      84.826762         True      1.041414        2d  gateio_spot
# 0      89.873418        False      2.038462        4h  kucoin_spot
# 1      97.576531        False      0.280013        1d    mexc_spot
# Reversal Bar: 8 signals
#            symbol                date     close        volume  volume_ratio  \
# 3  1000CHEEMSUSDT 2025-03-24 00:00:00  0.001626  3.972953e+08      0.808002
# 4       SWELLUSDT 2025-03-24 00:00:00  0.012000  3.614371e+08      3.255507
# 5          L3USDT 2025-03-24 00:00:00  0.094230  8.675925e+07      1.677316
# 6       SWELLUSDT 2025-03-24 00:00:00  0.011990  1.172186e+08      2.701489
# 7         L3_USDT 2025-03-24 00:00:00  0.094210  6.637821e+05      2.410846
# 1      AGIXT_USDT 2025-04-01 00:00:00  0.008150  1.961453e+05      0.386680
# 2        ZKJ_USDT 2025-04-01 00:00:00  2.236000  5.305849e+05      1.143753
# 0     YZYSOL_USDT 2025-04-03 12:00:00  0.004970  2.789629e+04      1.496789
#
#    close_off_low  current_bar  arctan_ratio timeframe         exchange
# 3      17.438570        False      0.467439        1w  binance_futures
# 4      14.269275        False      6.302406        1w  binance_futures
# 5      14.899853        False      2.796111        1w    bybit_futures
# 6      14.534884        False      7.349377        1w    bybit_futures
# 7      15.011472        False      2.560779        1w   gateio_futures
# 1       7.381616        False      0.108026        2d     mexc_futures
# 2      14.678899        False      0.253469        2d     mexc_futures
# 0       3.658537         True      0.561905        4h     mexc_futures
# Volume Surge: 55 signals
#          symbol                date      close        volume    volume_usd  \
# 0      ASTRUSDT 2025-04-03 08:00:00   0.025785  1.102140e+08  2.841868e+06
# 1       BSWUSDT 2025-04-03 08:00:00   0.016680  2.019670e+09  3.368810e+07
# 2     CHESSUSDT 2025-04-03 08:00:00   0.050900  2.217578e+08  1.128747e+07
# 3     DODOXUSDT 2025-04-03 08:00:00   0.053941  2.160551e+07  1.165423e+06
# 4       FLMUSDT 2025-04-03 08:00:00   0.017800  5.112889e+08  9.100942e+06
# 5      LOKAUSDT 2025-04-03 08:00:00   0.067300  8.119913e+07  5.464702e+06
# 6      MBOXUSDT 2025-04-03 08:00:00   0.051900  1.715160e+08  8.901678e+06
# 7       NKNUSDT 2025-04-03 08:00:00   0.025020  4.113105e+08  1.029099e+07
# 8      PERPUSDT 2025-04-03 08:00:00   0.213500  4.603972e+07  9.829480e+06
# 9      RAREUSDT 2025-04-03 08:00:00   0.069150  2.853145e+09  1.972950e+08
# 10      SYSUSDT 2025-04-03 08:00:00   0.033500  6.274600e+07  2.101991e+06
# 11      TLMUSDT 2025-04-03 08:00:00   0.004353  4.690899e+08  2.041948e+06
# 12    VOXELUSDT 2025-04-03 08:00:00   0.036000  6.774553e+08  2.438839e+07
# 13     ASTRUSDT 2025-04-03 08:00:00   0.025800  3.298441e+07  8.509978e+05
# 14      BSWUSDT 2025-04-03 08:00:00   0.016680  4.221598e+08  7.041625e+06
# 15    CHESSUSDT 2025-04-03 08:00:00   0.050810  2.835443e+07  1.440689e+06
# 16      FLMUSDT 2025-04-03 08:00:00   0.017760  1.017474e+08  1.807033e+06
# 17    FLOCKUSDT 2025-04-03 08:00:00   0.043700  2.103488e+07  9.192245e+05
# 18      HEIUSDT 2025-04-03 08:00:00   0.354200  3.008120e+06  1.065476e+06
# 19     MBOXUSDT 2025-04-03 08:00:00   0.051840  2.547020e+07  1.320375e+06
# 20      NKNUSDT 2025-04-03 08:00:00   0.024980  9.734385e+07  2.431649e+06
# 21      OXTUSDT 2025-04-03 08:00:00   0.061590  5.319780e+06  3.276453e+05
# 22     PERPUSDT 2025-04-03 08:00:00   0.213600  1.130634e+07  2.415034e+06
# 23     RAREUSDT 2025-04-03 08:00:00   0.068970  8.433041e+08  5.816268e+07
# 24      SYSUSDT 2025-04-03 08:00:00   0.033520  1.729582e+07  5.797560e+05
# 25      TLMUSDT 2025-04-03 08:00:00   0.004356  7.214152e+07  3.142485e+05
# 26      TWTUSDT 2025-04-03 08:00:00   0.811900  1.605994e+06  1.303907e+06
# 27   1INCH_USDT 2025-04-03 08:00:00   0.182700  6.239820e+05  1.140015e+05
# 28     AXS_USDT 2025-04-03 08:00:00   2.644000  1.288795e+06  3.407574e+06
# 29     BSW_USDT 2025-04-03 08:00:00   0.016670  1.820715e+07  3.035131e+05
# 30     FLM_USDT 2025-04-03 08:00:00   0.017820  1.854007e+06  3.303840e+04
# 31     NKN_USDT 2025-04-03 08:00:00   0.024900  9.817907e+06  2.444659e+05
# 32    PERP_USDT 2025-04-03 08:00:00   0.213600  1.017450e+07  2.173273e+06
# 33    RARE_USDT 2025-04-03 08:00:00   0.069260  1.174447e+07  8.134220e+05
# 34  UXLINK_USDT 2025-04-03 08:00:00   0.477000  3.776200e+05  1.801247e+05
# 35   VOXEL_USDT 2025-04-03 08:00:00   0.035810  6.843330e+05  2.450596e+04
# 36    WING_USDT 2025-04-03 08:00:00   1.780000  4.534600e+04  8.071588e+04
# 37     XCH_USDT 2025-04-03 12:00:00  10.458000  1.776331e+07  1.857687e+08
# 38    ASTR_USDT 2025-04-03 08:00:00   0.025786  8.747770e+05  2.255700e+04
# 39     BSW_USDT 2025-04-03 08:00:00   0.016710  2.161001e+07  3.611032e+05
# 40   CHESS_USDT 2025-04-03 08:00:00   0.050800  1.144665e+06  5.814898e+04
# 41     FLM_USDT 2025-04-03 08:00:00   0.017700  1.140194e+08  2.018144e+06
# 42     GST_USDT 2025-04-03 08:00:00   0.007290  8.208119e+06  5.983719e+04
# 43   HMSTR_USDT 2025-04-03 08:00:00   0.002285  9.434962e+06  2.155889e+04
# 44    LOKA_USDT 2025-04-03 08:00:00   0.067300  1.395888e+06  9.394326e+04
# 45    MBOX_USDT 2025-04-03 08:00:00   0.051900  1.354715e+07  7.030971e+05
# 46    MINT_USDT 2025-04-03 08:00:00   0.020210  2.456984e+06  4.965565e+04
# 47     NKN_USDT 2025-04-03 08:00:00   0.025040  7.558598e+07  1.892673e+06
# 48    PERP_USDT 2025-04-03 08:00:00   0.213500  1.061081e+06  2.265408e+05
# 49    RARE_USDT 2025-04-03 08:00:00   0.069130  4.136872e+07  2.859819e+06
# 50   SUSHI_USDT 2025-04-03 08:00:00   0.551600  1.728930e+07  9.536780e+06
# 51     TLM_USDT 2025-04-03 08:00:00   0.004352  2.047306e+08  8.909877e+05
# 52  UXLINK_USDT 2025-04-03 08:00:00   0.476700  7.499950e+05  3.575226e+05
# 53   VOXEL_USDT 2025-04-03 08:00:00   0.036000  6.543958e+06  2.355825e+05
# 54    WING_USDT 2025-04-03 08:00:00   1.796000  3.848570e+05  6.912032e+05
#
#     volume_ratio      score           price_extreme  current_bar timeframe  \
# 0       3.700178  -0.401227            Black candle        False        4h
# 1      16.900617  -1.292472  Black candle - new low        False        4h
# 2      25.527901  -6.627119  Black candle - new low        False        4h
# 3       3.930964  -2.839706  Black candle - new low        False        4h
# 4       5.755569  -1.666667  Black candle - new low        False        4h
# 5      19.018269  -8.971154  Black candle - new low        False        4h
# 6      13.628954  -2.483871  Black candle - new low        False        4h
# 7      10.990104  -0.869851  Black candle - new low        False        4h
# 8      10.157543  -1.068485  Black candle - new low        False        4h
# 9      20.289473   1.525046            White candle        False        4h
# 10      5.425456  -1.841693  Black candle - new low        False        4h
# 11      4.709635  -3.936681  Black candle - new low        False        4h
# 12     25.808503  -1.592417  Black candle - new low        False        4h
# 13      4.611221  -0.361789            Black candle        False        4h
# 14     10.859150  -1.286294  Black candle - new low        False        4h
# 15     28.906395  -6.711604  Black candle - new low        False        4h
# 16      4.612539  -1.726904  Black candle - new low        False        4h
# 17      6.054465  -6.204489  Black candle - new low        False        4h
# 18      3.884458  -1.531401  Black candle - new low        False        4h
# 19     26.328576  -2.559693  Black candle - new low        False        4h
# 20      7.876714  -0.881579  Black candle - new low        False        4h
# 21      3.453992   0.011029            White candle        False        4h
# 22      6.230375  -1.057856  Black candle - new low        False        4h
# 23     20.200226   1.448801            White candle        False        4h
# 24      7.364623  -1.872990  Black candle - new low        False        4h
# 25      4.151143  -3.982222  Black candle - new low        False        4h
# 26      5.781928  -1.316176  Black candle - new low        False        4h
# 27      4.272451  -1.096491            Black candle        False        4h
# 28      2.630219  -5.323944  Black candle - new low        False        4h
# 29      5.685463  -1.297436  Black candle - new low        False        4h
# 30      4.645046  -1.727723  Black candle - new low        False        4h
# 31      7.738481  -0.894019  Black candle - new low        False        4h
# 32      6.164519  -1.048662  Black candle - new low        False        4h
# 33     20.172247   1.591337            White candle        False        4h
# 34      4.412242   1.442568            White candle        False        4h
# 35      4.352920  -1.643988  Black candle - new low        False        4h
# 36      6.676089  -0.227961            Black candle        False        4h
# 37      3.621678  -3.115756  Black candle - new low         True        4h
# 38      3.736045  -0.373667            Black candle        False        4h
# 39     21.046085  -1.286660  Black candle - new low        False        4h
# 40     21.130001  -6.827586  Black candle - new low        False        4h
# 41     10.538476  -1.758065  Black candle - new low        False        4h
# 42      2.589730  -2.315789  Black candle - new low        False        4h
# 43      4.988624   0.380952            White candle        False        4h
# 44     28.781849  -8.839623  Black candle - new low        False        4h
# 45      5.397279  -2.505435  Black candle - new low        False        4h
# 46     12.247461  43.593023            White candle        False        4h
# 47     10.499171  -0.865961  Black candle - new low        False        4h
# 48     11.814981  -1.069866  Black candle - new low        False        4h
# 49     35.264926   1.519481            White candle        False        4h
# 50      3.111259  -2.142534            Black candle        False        4h
# 51      6.272514  -3.995595  Black candle - new low        False        4h
# 52      5.899318   1.409548            White candle        False        4h
# 53     30.268748  -1.610048  Black candle - new low        False        4h
# 54      5.911065  -0.205376            Black candle        False        4h
#
#            exchange
# 0   binance_futures
# 1   binance_futures
# 2   binance_futures
# 3   binance_futures
# 4   binance_futures
# 5   binance_futures
# 6   binance_futures
# 7   binance_futures
# 8   binance_futures
# 9   binance_futures
# 10  binance_futures
# 11  binance_futures
# 12  binance_futures
# 13    bybit_futures
# 14    bybit_futures
# 15    bybit_futures
# 16    bybit_futures
# 17    bybit_futures
# 18    bybit_futures
# 19    bybit_futures
# 20    bybit_futures
# 21    bybit_futures
# 22    bybit_futures
# 23    bybit_futures
# 24    bybit_futures
# 25    bybit_futures
# 26    bybit_futures
# 27   gateio_futures
# 28   gateio_futures
# 29   gateio_futures
# 30   gateio_futures
# 31   gateio_futures
# 32   gateio_futures
# 33   gateio_futures
# 34   gateio_futures
# 35   gateio_futures
# 36   gateio_futures
# 37   gateio_futures
# 38     mexc_futures
# 39     mexc_futures
# 40     mexc_futures
# 41     mexc_futures
# 42     mexc_futures
# 43     mexc_futures
# 44     mexc_futures
# 45     mexc_futures
# 46     mexc_futures
# 47     mexc_futures
# 48     mexc_futures
# 49     mexc_futures
# 50     mexc_futures
# 51     mexc_futures
# 52     mexc_futures
# 53     mexc_futures
# 54     mexc_futures
# Start Bar: 40 signals
#           symbol       date     close        volume  volume_ratio  \
# 33       EOSUSDT 2025-03-31  0.820200  3.260908e+08      1.900212
# 34      GHSTUSDT 2025-03-24  0.579000  2.348997e+07      2.694104
# 0        ELFUSDT 2025-04-01  0.248200  1.039280e+07      2.130563
# 1       EURIUSDT 2025-04-01  1.090500  5.569747e+06      1.320872
# 2       KAVAUSDT 2025-04-01  0.392400  3.182621e+07      3.140598
# 35       EOSUSDT 2025-03-31  0.820000  6.818574e+07      2.192077
# 36      FIREUSDT 2025-03-24  0.162270  1.279186e+07      1.345520
# 3        HVHUSDT 2025-04-01  0.001713  1.263816e+05      1.278961
# 4          JUSDT 2025-04-01  0.237300  6.998452e+06      1.956723
# 5       LUCEUSDT 2025-04-01  0.012440  1.107932e+06      1.724562
# 6        MEWUSDT 2025-04-01  0.003051  1.331075e+07      1.127170
# 7        THNUSDT 2025-04-01  0.001349  1.080914e+05      1.849074
# 8     UXLINKUSDT 2025-04-03  0.469600  6.296110e+06      0.563715
# 37      CRO_USDT 2025-03-24  0.101870  5.486526e+06      2.966842
# 38    EOS5L_USDT 2025-03-31  8.069157  1.285619e+08      0.759439
# 39      EOS_USDT 2025-03-31  0.828000  8.719757e+07      3.217777
# 9   BIGTIME_USDT 2025-04-01  0.052240  7.447247e+05      2.132959
# 10   BOME3S_USDT 2025-04-01  1.019610  7.353468e+05      1.611605
# 11        J_USDT 2025-04-01  0.236900  9.143755e+05      2.418683
# 12   UXLINK_USDT 2025-04-03  0.473700  3.754448e+06      4.225196
# 27  BIGTIME-USDT 2025-04-01  0.052240  1.267491e+06      2.440690
# 28        J-USDT 2025-04-01  0.237800  4.983574e+05      1.616960
# 29     LUCE-USDT 2025-04-01  0.012380  3.039153e+05      2.970752
# 30      MEW-USDT 2025-04-01  0.003054  2.241109e+06      1.391434
# 31      RWA-USDT 2025-04-01  0.014444  1.002671e+05      1.164882
# 32   UXLINK-USDT 2025-04-03  0.469400  8.119705e+05      2.380496
# 13    ANYONEUSDT 2025-04-01  0.329100  2.731576e+05      1.254225
# 14       ELFUSDT 2025-04-01  0.248200  3.990567e+06      2.081546
# 15      ELYSUSDT 2025-04-01  0.246500  1.274219e+05      1.199884
# 16         JUSDT 2025-04-01  0.237200  4.536881e+06      1.422934
# 17      LUCEUSDT 2025-04-01  0.012423  2.835917e+05      0.942394
# 18       MEWUSDT 2025-04-01  0.003052  2.827987e+07      1.747110
# 19       OMZUSDT 2025-04-01  0.077400  1.467764e+05      1.366640
# 20      OOKIUSDT 2025-04-01  0.000061  1.375770e+05      1.056064
# 21      SARAUSDT 2025-04-01  0.004780  1.539882e+05      1.234197
# 22    UXLINKUSDT 2025-04-03  0.472600  3.782703e+06      1.890746
# 23       VSCUSDT 2025-04-01  0.005973  1.469012e+05      1.101919
# 24     XODEXUSDT 2025-04-01  0.000078  1.547984e+05      1.234610
# 25      YAKAUSDT 2025-04-01  0.000740  2.019527e+05      1.807344
# 26       ZYNUSDT 2025-04-01  0.015380  2.226165e+05      1.241858
#
#     close_off_low  current_bar  arctan_ratio timeframe      exchange
# 33      81.990679         True           0.0        1w  binance_spot
# 34      52.941176        False           0.0        1w  binance_spot
# 0       58.139535        False           0.0        2d  binance_spot
# 1       85.815603        False           0.0        2d  binance_spot
# 2       50.386847        False           0.0        2d  binance_spot
# 35      81.697613         True           0.0        1w    bybit_spot
# 36      80.437965        False           0.0        1w    bybit_spot
# 3       57.425743        False           0.0        2d    bybit_spot
# 4       53.892216        False           0.0        2d    bybit_spot
# 5       66.216216        False           0.0        2d    bybit_spot
# 6       59.120172        False           0.0        2d    bybit_spot
# 7       65.681818        False           0.0        2d    bybit_spot
# 8       79.594272         True           0.0        2d    bybit_spot
# 37      61.406568        False           0.0        1w   gateio_spot
# 38      76.720109         True           0.0        1w   gateio_spot
# 39      84.851518         True           0.0        1w   gateio_spot
# 9       51.337672        False           0.0        2d   gateio_spot
# 10      94.082317        False           0.0        2d   gateio_spot
# 11      52.988048        False           0.0        2d   gateio_spot
# 12      84.826762         True           0.0        2d   gateio_spot
# 27      50.936599        False           0.0        2d   kucoin_spot
# 28      55.263158        False           0.0        2d   kucoin_spot
# 29      65.482234        False           0.0        2d   kucoin_spot
# 30      59.485531        False           0.0        2d   kucoin_spot
# 31      55.447032        False           0.0        2d   kucoin_spot
# 32      80.929095         True           0.0        2d   kucoin_spot
# 13      50.160772        False           0.0        2d     mexc_spot
# 14      60.060060        False           0.0        2d     mexc_spot
# 15      79.420290        False           0.0        2d     mexc_spot
# 16      53.333333        False           0.0        2d     mexc_spot
# 17      66.153846        False           0.0        2d     mexc_spot
# 18      59.255319        False           0.0        2d     mexc_spot
# 19      92.979719        False           0.0        2d     mexc_spot
# 20      70.464337        False           0.0        2d     mexc_spot
# 21      72.293364        False           0.0        2d     mexc_spot
# 22      84.057971         True           0.0        2d     mexc_spot
# 23      76.359681        False           0.0        2d     mexc_spot
# 24      56.886518        False           0.0        2d     mexc_spot
# 25      86.666667        False           0.0        2d     mexc_spot
# 26      70.796460        False           0.0        2d     mexc_spot
# Pin Down: 4 signals
#         date   close    high     low  volume_ratio  bearishtop_dist  \
# 0 2025-03-24  16.951  22.298  16.301      1.621238                1
# 1 2025-03-24  16.954  22.318  16.312      2.397429                1
# 2 2025-03-24  16.963  22.283  16.316      2.528223                1
# 3 2025-03-24  16.960  22.280  16.300      1.801265                1
#
#    high_wick_ratio  bearish_candle        symbol    volume_usd timeframe  \
# 0         0.421696           False   AUCTIONUSDT  1.701105e+09        1w
# 1         0.429638           False   AUCTIONUSDT  7.149234e+08        1w
# 2         0.421700           False  AUCTION_USDT  8.041084e+08        1w
# 3         0.418667           False  AUCTION_USDT  1.996232e+08        1w
#
#           exchange
# 0  binance_futures
# 1    bybit_futures
# 2   gateio_futures
# 3     mexc_futures

# %%
# Debug ohlcv data of any pair

import asyncio
import sys
import os
import logging
import pandas as pd

logging.basicConfig(level=logging.INFO, format='%(message)s')

project_dir = os.path.join(os.getcwd(), "Project")
sys.path.insert(0, project_dir)
print(f"✓ Added {project_dir} to sys.path")

from exchanges import BybitFuturesClient  # Ensure this matches your exchanges/__init__.py

async def test_fetch():
    client = BybitFuturesClient(timeframe="2d")
    await client.init_session()
    df = await client.fetch_klines("L3USDT")
    await client.close_session()
    if df is not None:
        print("2d Candles for L3:")
        print(df.tail(5))  # Last 5 weeks
        last_row = df.iloc[-1]
        volume_usd = last_row['volume'] * last_row['close']
        print(f"Last Week: volume_usd={volume_usd:.2f}, close={last_row['close']}, volume={last_row['volume']:.2f}")

# Run the async function directly in the notebook
await test_fetch()

# %%
#Direct strategy debug of any pair on any exchange
import asyncio
import sys
import os
import logging
import pandas as pd
import numpy as np
logging.basicConfig(level=logging.DEBUG, format='%(levelname)s: %(message)s')
project_dir = os.path.join(os.getcwd(), "Project")
sys.path.insert(0, project_dir)
print(f"✓ Added {project_dir} to sys.path")
from exchanges import MexcSpotClient, BybitSpotClient, GateioSpotClient, KucoinSpotClient, BinanceSpotClient, BinanceFuturesClient
from breakout_vsa.core import vsa_detector
# from custom_strategies import detect_volume_surge
from breakout_vsa.core import breakout_bar_vsa

async def test_strategy(exchange_client_class, timeframe, symbol, strategy_name):
    client = exchange_client_class(timeframe=timeframe)
    await client.init_session()
    df = await client.fetch_klines(symbol)
    await client.close_session()
    
    if df is None or len(df) < 10:
        print(f"No data fetched for {symbol} or insufficient data (< 10 bars)")
        return
    
    print(f"{timeframe} Candles for {symbol}:")
    print(df.tail(5))
    last_row = df.iloc[-1]
    volume_usd = last_row['volume'] * last_row['close']
    print(f"Last Bar: volume_usd={volume_usd:.2f}, close={last_row['close']}, volume={last_row['volume']:.2f}")
    
    # Different handling based on strategy type
    if strategy_name == "volume_surge":
        # Use detect_volume_surge directly
        detected, result = detect_volume_surge(df)
        
        print(f"\nVolume Surge Detection Results:")
        print(f"Detected: {detected}")
        
        if detected:
            print(f"\nVolume Surge Details:")
            print(f"  Date: {result['timestamp']}")
            print(f"  Close: ${result['close_price']:,.8f}")
            print(f"  Volume: {result['volume']:,.2f}")
            print(f"  Volume USD: ${result['volume_usd']:,.2f}")
            print(f"  Volume Ratio: {result['volume_ratio']:,.2f}x")
            print(f"  Score: {result['score']:,.2f}")
            print(f"  Price Extreme: {result['price_extreme']}")
    
    elif strategy_name == "pin_down":
        from custom_strategies import detect_pin_down
        detected, result = detect_pin_down(df)
        
        print(f"\nPin Down Detection Results:")
        print(f"Detected: {detected}")
        
        if detected:
            print(f"\nPin Down Details:")
            for key, value in result.items():
                if key != 'symbol':  # Skip symbol as we already know it
                    print(f"  {key}: {value}")
    
    elif strategy_name == "weak_uptrend":
        from custom_strategies import detect_weak_uptrend
        detected, result = detect_weak_uptrend(df)
        
        print(f"\nWeak Uptrend Detection Results:")
        print(f"Detected: {detected}")
        
        if detected:
            print(f"\nWeak Uptrend Details:")
            for key, value in result.items():
                if key != 'symbol':  # Skip symbol as we already know it
                    print(f"  {key}: {value}")
    
    else:
        # For VSA strategies, import the appropriate get_params
        if strategy_name == "reversal_bar":
            from breakout_vsa.strategies.reversal_bar import get_params
        elif strategy_name == "breakout_bar":
            from breakout_vsa.strategies.breakout_bar import get_params
        elif strategy_name == "stop_bar":
            from breakout_vsa.strategies.stop_bar import get_params
        elif strategy_name == "start_bar":
            from breakout_vsa.strategies.start_bar import get_params
        else:
            print(f"Unknown strategy: {strategy_name}")
            return
        
        # Use vsa_detector with strategy-specific params
        params = get_params()
        condition, result = vsa_detector(df, params)
        
        strategy_display_name = strategy_name.replace('_vsa', '').replace('_', ' ').title()
        print(f"\n{strategy_display_name} Detection Results:")
        print(f"Current Bar (index -1): {condition.iloc[-1]}")
        if len(df) > 1:
            print(f"Last Closed Bar (index -2): {condition.iloc[-2]}")
        
        if condition.iloc[-1] or (len(df) > 1 and condition.iloc[-2]):
            detected_idx = -1 if condition.iloc[-1] else -2
            volume_mean = df['volume'].rolling(7).mean().iloc[detected_idx]
            bar_range = df['high'].iloc[detected_idx] - df['low'].iloc[detected_idx]
            close_off_low = (df['close'].iloc[detected_idx] - df['low'].iloc[detected_idx]) / bar_range * 100 if bar_range > 0 else 0
            volume_usd_detected = df['volume'].iloc[detected_idx] * df['close'].iloc[detected_idx]
            
            arctan_ratio = result['arctan_ratio'].iloc[detected_idx]  # From result DataFrame
            
            print(f"\nDetected at index {detected_idx} ({'Current' if detected_idx == -1 else 'Last Closed'} Bar):")
            print(f"  Date: {df.index[detected_idx]}")
            print(f"  Close: ${df['close'].iloc[detected_idx]:,.8f}")
            print(f"  Volume Ratio: {df['volume'].iloc[detected_idx] / volume_mean if volume_mean > 0 else 0:.2f}x")
            print(f"  {timeframe} Volume: ${volume_usd_detected:.2f}")
            print(f"  Close Off Low: {close_off_low:.1f}%")
            print(f"  Angular Ratio: {arctan_ratio:.2f}")

# Define the test case
exchange_client = BinanceFuturesClient
timeframe = "4h"
symbol = "BTCUSDT"
strategy = "breakout_bar"
await test_strategy(exchange_client, timeframe, symbol, strategy)

# %%
#zip the project

import shutil
import os

# Go to parent directory of your project
os.chdir("/home/jovyan/work/Crypto/sevenfigures-bot/hbs_2025")

# Create the zip file (this will include everything inside 'hbs_2025')
shutil.make_archive("Project_VSA_2025_backup", 'zip', "Project")
