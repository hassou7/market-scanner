# %%
import os
print("Current working directory:", os.getcwd())

# %%
#!/usr/bin/env python3
"""
Run Simple Parallel Scan for Test Bar

This script runs the test bar scan across multiple exchanges in parallel
using a simplified parallel scanning approach that avoids console output issues.
"""

import asyncio
import sys
import os
import logging

# Setup logging
logging.basicConfig(level=logging.INFO, format='%(message)s')

# Add project directory to path
project_dir = os.path.join(os.getcwd(), "Project")
sys.path.insert(0, project_dir)
print(f"✓ Added {project_dir} to sys.path")

# Add current directory to path
sys.path.append(os.getcwd())
print(f"✓ Added {os.getcwd()} to sys.path")

# Import the simple parallel scanner
from run_parallel_scanner import run_parallel_exchanges, run_parallel_multi_timeframes_all_exchanges
from scanner.main import kline_cache

# Define exchanges
futures_exchanges = ["binance_futures", "bybit_futures", "mexc_futures", "gateio_futures"]
spot_exchanges = ["binance_spot", "bybit_spot", "kucoin_spot", "mexc_spot", "gateio_spot"]
spot_exchanges_1w = ["binance_spot", "bybit_spot", "gateio_spot"]

async def main():
    # Clear cache for fresh data
    kline_cache.clear()
    
    """
    # Run parallel scan for test bar strategy on spot exchanges
    result = await run_parallel_exchanges(
        timeframe="4h",                    # Example timeframe
        strategies=["confluence", "test_bar", "consolidation"],
        # strategies=["reversal_bar"],       
        exchanges=spot_exchanges,          # Spot exchanges to scan
        users=["default"],                 # Recipients for Telegram notifications
        send_telegram=True,                # Enable Telegram notifications
        min_volume_usd=None                # Use default volume threshold
    )
    """
    # Run multi-timeframe parallel scan
    result = await run_parallel_multi_timeframes_all_exchanges(
        timeframes=["2d", "3d", "1w"],     # Multiple timeframes
        strategies=["consolidation"],        # Strategies to scan
        exchanges=["binance_spot", "binance_futures", "bybit_spot", "kucoin_spot", "mexc_spot", "gateio_spot"],          # Exchanges to scan
        users=["default"],                 # Recipients for notifications
        send_telegram=True,                # Enable notifications
        min_volume_usd=None                # Use default volume threshold
    )
     #"""
    
    print("Scan completed!")
    return result

if __name__ == "__main__":
    asyncio.run(main())
# Out:
# ================================================================================
#   RUNNING PARALLEL MULTI-TIMEFRAME SCAN ON ALL EXCHANGES
# ================================================================================
#
# • Exchanges: binance_spot, binance_futures, bybit_spot, kucoin_spot, mexc_spot, gateio_spot
# • Timeframes: 2d, 3d, 1w
# • Strategies: consolidation
# • Notifications: Enabled
# • Recipients: default
# • Start time: 12:11:08
#
# Fetching market data...
#
# Processing 2d timeframe
# [12:11:08] Starting scan on binance_spot for 2d timeframe...
# [12:11:08] Starting scan on binance_futures for 2d timeframe...
# [12:11:08] Starting scan on bybit_spot for 2d timeframe...
# [12:11:08] Starting scan on kucoin_spot for 2d timeframe...
# [12:11:08] Starting scan on mexc_spot for 2d timeframe...
# [12:11:08] Starting scan on gateio_spot for 2d timeframe...
# ✓ Added /home/jovyan/work/Crypto/sevenfigures-bot/hbs_2025/Project/Project to sys.path
# ✓ Added /home/jovyan/work/Crypto/sevenfigures-bot/hbs_2025/Project to sys.path
# Found 2000 markets on Mexc for 2d timeframe
# Processing 2000 symbols for Mexc...
# Found 516 markets on Bybit for 2d timeframe
# Processing 516 symbols for Bybit...
# Found 1068 markets on Kucoin for 2d timeframe
# Processing 1068 symbols for Kucoin...
# Found 469 markets on Binance Futures for 2d timeframe
# Processing 469 symbols for Binance Futures...
# consolidation detected for A47USDT (last closed bar)
# consolidation detected for A47USDT (current bar)
# Found 409 markets on Binance Spot for 2d timeframe
# Processing 409 symbols for Binance Spot...
# consolidation detected for A47USDT
# Found 2512 markets on Gateio for 2d timeframe
# Processing 2512 symbols for Gateio...
# consolidation detected for ALCHUSDT (last closed bar)
# consolidation detected for ALCHUSDT (current bar)
# consolidation detected for ALCHUSDT
# consolidation detected for ABUSDT (last closed bar)
# consolidation detected for ABUSDT (current bar)
# consolidation detected for AERGO-USDT (last closed bar)
# consolidation detected for AERGO-USDT (current bar)
# consolidation detected for ABUSDT
# consolidation detected for AERGO-USDT
# consolidation detected for ANIMEUSDT (last closed bar)
# consolidation detected for ANIMEUSDT (current bar)
# consolidation detected for ANIMEUSDT
# consolidation detected for ACSUSDT (current bar)
# consolidation detected for AERGOUSDT (last closed bar)
# consolidation detected for AERGOUSDT (current bar)
# consolidation detected for ACSUSDT
# consolidation detected for AERGOUSDT
# consolidation detected for AERGOUSDT (last closed bar)
# consolidation detected for AERGOUSDT (current bar)
# consolidation detected for ANIMEUSDT (last closed bar)
# consolidation detected for ANIMEUSDT (current bar)
# consolidation detected for AERGOUSDT
# consolidation detected for ANIMEUSDT
# consolidation detected for ARTYUSDT (last closed bar)
# consolidation detected for ARTYUSDT (current bar)
# consolidation detected for ARTYUSDT
# consolidation detected for ALU-USDT (last closed bar)
# consolidation detected for ALU-USDT (current bar)
# consolidation detected for ALU-USDT
# consolidation detected for ALCHUSDT (last closed bar)
# consolidation detected for ALCHUSDT (current bar)
# consolidation detected for ALPHAUSDT (last closed bar)
# consolidation detected for ALPHAUSDT (current bar)
# consolidation detected for ARDRUSDT (last closed bar)
# consolidation detected for ARDRUSDT (current bar)
# consolidation detected for ALCHUSDT
# consolidation detected for ALPHAUSDT
# consolidation detected for ARDRUSDT
# consolidation detected for AVAILUSDT (last closed bar)
# consolidation detected for AVAILUSDT (current bar)
# consolidation detected for AVLUSDT (last closed bar)
# consolidation detected for AVLUSDT (current bar)
# consolidation detected for AVAILUSDT
# consolidation detected for AVLUSDT
# consolidation detected for ANIMEUSDT (last closed bar)
# consolidation detected for ANIMEUSDT (current bar)
# consolidation detected for ANIMEUSDT
# consolidation detected for AINETWORKUSDT (current bar)
# consolidation detected for AINETWORKUSDT
# consolidation detected for BANANAS31USDT (last closed bar)
# consolidation detected for BANANAS31USDT (current bar)
# consolidation detected for BANANAS31USDT
# consolidation detected for BOBAUSDT (last closed bar)
# consolidation detected for BOBAUSDT
# consolidation detected for ALEUSDT (last closed bar)
# consolidation detected for ALEUSDT (current bar)
# consolidation detected for ALEUSDT
# consolidation detected for ARTY-USDT (last closed bar)
# consolidation detected for ARTY-USDT (current bar)
# consolidation detected for ARTY-USDT
# consolidation detected for BRUSDT (last closed bar)
# consolidation detected for BRUSDT (current bar)
# consolidation detected for BRUSDT
# consolidation detected for ALLINUSDT (last closed bar)
# consolidation detected for ALLINUSDT (current bar)
# consolidation detected for ALTUSDT (last closed bar)
# consolidation detected for ALTUSDT (current bar)
# consolidation detected for ALPHAUSDT (last closed bar)
# consolidation detected for ALPHAUSDT (current bar)
# consolidation detected for ALLINUSDT
# consolidation detected for ALPHAUSDT
# consolidation detected for ALTUSDT
# consolidation detected for BANANAS31USDT (last closed bar)
# consolidation detected for BANANAS31USDT (current bar)
# consolidation detected for BANANAS31USDT
# consolidation detected for CBKUSDT (last closed bar)
# consolidation detected for CBKUSDT (current bar)
# consolidation detected for CBKUSDT
# consolidation detected for ANITAUSDT (last closed bar)
# consolidation detected for ANITAUSDT (current bar)
# consolidation detected for ANDRUSDT (last closed bar)
# consolidation detected for ANDRUSDT (current bar)
# consolidation detected for ANIMEUSDT (last closed bar)
# consolidation detected for ANIMEUSDT (current bar)
# consolidation detected for ANDRUSDT
# consolidation detected for ANIMEUSDT
# consolidation detected for ANITAUSDT
# consolidation detected for BIDUSDT (last closed bar)
# consolidation detected for BIDUSDT (current bar)
# consolidation detected for BIDUSDT
# consolidation detected for COINXUSDT (last closed bar)
# consolidation detected for COINXUSDT (current bar)
# consolidation detected for COINXUSDT
# consolidation detected for BRUSDT (last closed bar)
# consolidation detected for BRUSDT (current bar)
# consolidation detected for BRUSDT
# consolidation detected for DAIUSDT (last closed bar)
# consolidation detected for DAIUSDT (current bar)
# consolidation detected for DAIUSDT
# consolidation detected for BCHSV-USDT (last closed bar)
# consolidation detected for BCHSV-USDT (current bar)
# consolidation detected for BCHSV-USDT
# consolidation detected for ARIUSDT (last closed bar)
# consolidation detected for ARIUSDT (current bar)
# consolidation detected for ARIUSDT
# consolidation detected for ARTYUSDT (last closed bar)
# consolidation detected for ARTYUSDT (current bar)
# consolidation detected for ARTYUSDT
# consolidation detected for BMX-USDT (last closed bar)
# consolidation detected for BMX-USDT (current bar)
# consolidation detected for BMX-USDT
# consolidation detected for ASSUSDT (last closed bar)
# consolidation detected for ASSUSDT (current bar)
# consolidation detected for ASSUSDT
# consolidation detected for FISUSDT (current bar)
# consolidation detected for FISUSDT
# consolidation detected for AUCUSDT (last closed bar)
# consolidation detected for AUCUSDT (current bar)
# consolidation detected for ATRUSDT (last closed bar)
# consolidation detected for ATRUSDT (current bar)
# consolidation detected for ATRUSDT
# consolidation detected for AUCUSDT
# consolidation detected for FLOCKUSDT (last closed bar)
# consolidation detected for FLOCKUSDT (current bar)
# consolidation detected for FLOCKUSDT
# consolidation detected for EPTUSDT (last closed bar)
# consolidation detected for EPTUSDT (current bar)
# consolidation detected for AURUSDT (last closed bar)
# consolidation detected for AURUSDT (current bar)
# consolidation detected for EPTUSDT
# consolidation detected for AVAILUSDT (last closed bar)
# consolidation detected for AVAILUSDT (current bar)
# consolidation detected for AURUSDT
# consolidation detected for AVAILUSDT
# consolidation detected for FUELUSDT (last closed bar)
# consolidation detected for FUELUSDT (current bar)
# consolidation detected for FUELUSDT
# consolidation detected for AZEROUSDT (last closed bar)
# consolidation detected for AZEROUSDT (current bar)
# consolidation detected for AXMUSDT (last closed bar)
# consolidation detected for AXMUSDT (current bar)
# consolidation detected for AZITUSDT (last closed bar)
# consolidation detected for AZITUSDT (current bar)
# consolidation detected for AXMUSDT
# consolidation detected for AZEROUSDT
# consolidation detected for AZITUSDT
# consolidation detected for GODSUSDT (last closed bar)
# consolidation detected for GODSUSDT (current bar)
# consolidation detected for HMSTRUSDT (last closed bar)
# consolidation detected for HMSTRUSDT (current bar)
# consolidation detected for GODSUSDT
# consolidation detected for HMSTRUSDT
# consolidation detected for BANANAS31USDT (last closed bar)
# consolidation detected for BANANAS31USDT (current bar)
# consolidation detected for BANANAS31USDT
# consolidation detected for HMSTRUSDT (last closed bar)
# consolidation detected for HMSTRUSDT (current bar)
# consolidation detected for HMSTRUSDT
# consolidation detected for HUMAUSDT (last closed bar)
# consolidation detected for HUMAUSDT (current bar)
# consolidation detected for HUMAUSDT
# consolidation detected for CHIRP-USDT (last closed bar)
# consolidation detected for CHIRP-USDT (current bar)
# consolidation detected for CHIRP-USDT
# consolidation detected for HUMAUSDT (last closed bar)
# consolidation detected for HUMAUSDT (current bar)
# consolidation detected for HUSDT (last closed bar)
# consolidation detected for HUSDT (current bar)
# consolidation detected for HUMAUSDT
# consolidation detected for HUSDT
# consolidation detected for INITUSDT (last closed bar)
# consolidation detected for INITUSDT (current bar)
# consolidation detected for INITUSDT
# consolidation detected for HMSTRUSDT (last closed bar)
# consolidation detected for HMSTRUSDT (current bar)
# consolidation detected for HMSTRUSDT
# consolidation detected for BBTUSDT (current bar)
# consolidation detected for BDPUSDT (current bar)
# consolidation detected for BBTUSDT
# consolidation detected for BDPUSDT
# consolidation detected for INITUSDT (last closed bar)
# consolidation detected for INITUSDT (current bar)
# consolidation detected for INITUSDT
# consolidation detected for KAITOUSDT (last closed bar)
# consolidation detected for KAITOUSDT (current bar)
# consolidation detected for HUSDT (last closed bar)
# consolidation detected for HUSDT (current bar)
# consolidation detected for HUMAUSDT (last closed bar)
# consolidation detected for HUMAUSDT (current bar)
# consolidation detected for KAITOUSDT
# consolidation detected for HUMAUSDT
# consolidation detected for HUSDT
# consolidation detected for LAYERUSDT (last closed bar)
# consolidation detected for LAYERUSDT (current bar)
# consolidation detected for LAYERUSDT
# consolidation detected for KAVAUSDT (last closed bar)
# consolidation detected for KAVAUSDT
# consolidation detected for BIDUSDT (last closed bar)
# consolidation detected for BIDUSDT (current bar)
# consolidation detected for BFTUSDT (last closed bar)
# consolidation detected for BFTUSDT (current bar)
# consolidation detected for BFTUSDT
# consolidation detected for BIDUSDT
# consolidation detected for LSKUSDT (last closed bar)
# consolidation detected for LSKUSDT (current bar)
# consolidation detected for KAITOUSDT (last closed bar)
# consolidation detected for KAITOUSDT (current bar)
# consolidation detected for LSKUSDT
# consolidation detected for KAITOUSDT
# consolidation detected for LAYERUSDT (last closed bar)
# consolidation detected for LAYERUSDT (current bar)
# consolidation detected for LAYERUSDT
# consolidation detected for BIT1USDT (last closed bar)
# consolidation detected for BIT1USDT (current bar)
# consolidation detected for BIT1USDT
# consolidation detected for LAYERUSDT (last closed bar)
# consolidation detected for LAYERUSDT (current bar)
# consolidation detected for LAYERUSDT
# consolidation detected for LUNAIUSDT (current bar)
# consolidation detected for MAJORUSDT (last closed bar)
# consolidation detected for MAJORUSDT (current bar)
# consolidation detected for LUNAIUSDT
# consolidation detected for MAJORUSDT
# consolidation detected for AUCTION_USDT (last closed bar)
# consolidation detected for AUCTION_USDT (current bar)
# consolidation detected for AUCTION_USDT
# consolidation detected for NEWTUSDT (last closed bar)
# consolidation detected for NEWTUSDT (current bar)
# consolidation detected for NEWTUSDT
# consolidation detected for MCRTUSDT (last closed bar)
# consolidation detected for MCRTUSDT (current bar)
# consolidation detected for MCRTUSDT
# consolidation detected for MELANIAUSDT (last closed bar)
# consolidation detected for MELANIAUSDT (current bar)
# consolidation detected for NXPCUSDT (last closed bar)
# consolidation detected for NXPCUSDT (current bar)
# consolidation detected for MELANIAUSDT
# consolidation detected for NXPCUSDT
# consolidation detected for MODEUSDT (current bar)
# consolidation detected for MONUSDT (last closed bar)
# consolidation detected for MONUSDT (current bar)
# consolidation detected for MOVEUSDT (last closed bar)
# consolidation detected for MOVEUSDT (current bar)
# consolidation detected for MODEUSDT
# consolidation detected for MONUSDT
# consolidation detected for MOVEUSDT
# consolidation detected for A_USDT (last closed bar)
# consolidation detected for A_USDT (current bar)
# consolidation detected for DOP-USDT (current bar)
# consolidation detected for DOP-USDT
# consolidation detected for A_USDT
# consolidation detected for NEWTUSDT (last closed bar)
# consolidation detected for NEWTUSDT (current bar)
# consolidation detected for PSGUSDT (last closed bar)
# consolidation detected for PSGUSDT (current bar)
# consolidation detected for PSGUSDT
# consolidation detected for NEWTUSDT
# consolidation detected for NEONUSDT (last closed bar)
# consolidation detected for NEONUSDT (current bar)
# consolidation detected for NEWTUSDT (last closed bar)
# consolidation detected for NEWTUSDT (current bar)
# consolidation detected for BTCBAMUSDT (last closed bar)
# consolidation detected for BTCBAMUSDT (current bar)
# consolidation detected for NEONUSDT
# consolidation detected for NEWTUSDT
# consolidation detected for BRUSDT (last closed bar)
# consolidation detected for BRUSDT (current bar)
# consolidation detected for BRUSDT
# consolidation detected for BTCBAMUSDT
# consolidation detected for NXPCUSDT (last closed bar)
# consolidation detected for NXPCUSDT (current bar)
# consolidation detected for NXPCUSDT
# consolidation detected for OASUSDT (last closed bar)
# consolidation detected for OASUSDT (current bar)
# consolidation detected for NXPCUSDT (last closed bar)
# consolidation detected for NXPCUSDT (current bar)
# consolidation detected for OBTUSDT (last closed bar)
# consolidation detected for OBTUSDT (current bar)
# consolidation detected for NXPCUSDT
# consolidation detected for OASUSDT
# consolidation detected for OBTUSDT
# consolidation detected for BULLSUSDT (last closed bar)
# consolidation detected for BULLSUSDT (current bar)
# consolidation detected for BULLSUSDT
# consolidation detected for EPT-USDT (last closed bar)
# consolidation detected for EPT-USDT (current bar)
# consolidation detected for EPT-USDT
# consolidation detected for REIUSDT (last closed bar)
# consolidation detected for REIUSDT (current bar)
# consolidation detected for OMGUSDT (last closed bar)
# consolidation detected for OMGUSDT (current bar)
# consolidation detected for OMUSDT (last closed bar)
# consolidation detected for OMUSDT (current bar)
# consolidation detected for REIUSDT
# consolidation detected for OMGUSDT
# consolidation detected for OMUSDT
# consolidation detected for BXBTUSDT (last closed bar)
# consolidation detected for BXBTUSDT (current bar)
# consolidation detected for BXBTUSDT
# consolidation detected for SAHARAUSDT (last closed bar)
# consolidation detected for SAHARAUSDT (current bar)
# consolidation detected for SAHARAUSDT
# consolidation detected for EYWA-USDT (last closed bar)
# consolidation detected for EYWA-USDT (current bar)
# consolidation detected for BEEFI_USDT (last closed bar)
# consolidation detected for BEEFI_USDT (current bar)
# consolidation detected for EYWA-USDT
# consolidation detected for BEEFI_USDT
# consolidation detected for PIRATEUSDT (current bar)
# consolidation detected for PIRATEUSDT
# consolidation detected for SCUSDT (current bar)
# consolidation detected for SLFUSDT (last closed bar)
# consolidation detected for SCUSDT
# consolidation detected for SLFUSDT
# consolidation detected for CASUSDT (last closed bar)
# consolidation detected for CASUSDT (current bar)
# consolidation detected for FLOCK-USDT (last closed bar)
# consolidation detected for FLOCK-USDT (current bar)
# consolidation detected for FLAME-USDT (last closed bar)
# consolidation detected for CASUSDT
# consolidation detected for FLAME-USDT
# consolidation detected for FLOCK-USDT
# consolidation detected for PSGUSDT (last closed bar)
# consolidation detected for PSGUSDT (current bar)
# consolidation detected for PSTAKEUSDT (last closed bar)
# consolidation detected for PSTAKEUSDT (current bar)
# consolidation detected for PUFFUSDT (last closed bar)
# consolidation detected for PSGUSDT
# consolidation detected for PSTAKEUSDT
# consolidation detected for PUFFUSDT
# consolidation detected for SOLVUSDT (last closed bar)
# consolidation detected for SOLVUSDT (current bar)
# consolidation detected for SOLVUSDT
# consolidation detected for CAUUSDT (last closed bar)
# consolidation detected for CAUUSDT (current bar)
# consolidation detected for CBKUSDT (last closed bar)
# consolidation detected for CBKUSDT (current bar)
# consolidation detected for CAUUSDT
# consolidation detected for CBKUSDT
# consolidation detected for PYUSDUSDT (last closed bar)
# consolidation detected for PYUSDUSDT (current bar)
# consolidation detected for PYUSDUSDT
# consolidation detected for REIUSDT (last closed bar)
# consolidation detected for REIUSDT (current bar)
# consolidation detected for RESOLVUSDT (current bar)
# consolidation detected for STRAXUSDT (last closed bar)
# consolidation detected for STRAXUSDT (current bar)
# consolidation detected for REIUSDT
# consolidation detected for RESOLVUSDT
# consolidation detected for STRAXUSDT
# consolidation detected for RESOLVUSDT (last closed bar)
# consolidation detected for RESOLVUSDT (current bar)
# consolidation detected for ROOTUSDT (last closed bar)
# consolidation detected for ROOTUSDT (current bar)
# consolidation detected for RVNUSDT (last closed bar)
# consolidation detected for RVNUSDT (current bar)
# consolidation detected for RESOLVUSDT
# consolidation detected for ROOTUSDT
# consolidation detected for RVNUSDT
# consolidation detected for RVNUSDT (last closed bar)
# consolidation detected for RVNUSDT (current bar)
# consolidation detected for SAHARAUSDT (last closed bar)
# consolidation detected for SAHARAUSDT (current bar)
# consolidation detected for RVNUSDT
# consolidation detected for SAHARAUSDT
# consolidation detected for SAHARAUSDT (last closed bar)
# consolidation detected for SAHARAUSDT (current bar)
# consolidation detected for SCUSDT (current bar)
# consolidation detected for SCAUSDT (last closed bar)
# consolidation detected for SCAUSDT (current bar)
# consolidation detected for SAHARAUSDT
# consolidation detected for SCAUSDT
# consolidation detected for SCUSDT
# consolidation detected for CHMPZUSDT (last closed bar)
# consolidation detected for CHMPZUSDT (current bar)
# consolidation detected for CHMPZUSDT
# consolidation detected for SERAPHUSDT (last closed bar)
# consolidation detected for SERAPHUSDT (current bar)
# consolidation detected for SIDUSUSDT (current bar)
# consolidation detected for TUTUSDT (last closed bar)
# consolidation detected for TUTUSDT (current bar)
# consolidation detected for USD1USDT (last closed bar)
# consolidation detected for USD1USDT (current bar)
# consolidation detected for SOLVUSDT (last closed bar)
# consolidation detected for SOLVUSDT (current bar)
# consolidation detected for TUSDUSDT (last closed bar)
# consolidation detected for TUSDUSDT (current bar)
# consolidation detected for SERAPHUSDT
# consolidation detected for SIDUSUSDT
# consolidation detected for TUSDUSDT
# consolidation detected for TUTUSDT
# consolidation detected for USD1USDT
# consolidation detected for SOLVUSDT
# consolidation detected for SMILEUSDT (last closed bar)
# consolidation detected for SMILEUSDT (current bar)
# consolidation detected for SMILEUSDT
# consolidation detected for USDPUSDT (last closed bar)
# consolidation detected for USDPUSDT (current bar)
# consolidation detected for USDPUSDT
# consolidation detected for CLXUSDT (last closed bar)
# consolidation detected for CLXUSDT (current bar)
# consolidation detected for H-USDT (last closed bar)
# consolidation detected for H-USDT (current bar)
# consolidation detected for H-USDT
# consolidation detected for CLXUSDT
# consolidation detected for STARUSDT (last closed bar)
# consolidation detected for STARUSDT (current bar)
# consolidation detected for STARUSDT
# consolidation detected for SXTUSDT (last closed bar)
# consolidation detected for SXTUSDT (current bar)
# consolidation detected for WCTUSDT (last closed bar)
# consolidation detected for WCTUSDT (current bar)
# consolidation detected for WCTUSDT
# consolidation detected for SXTUSDT
# consolidation detected for HEART-USDT (current bar)
# consolidation detected for COMBOUSDT (last closed bar)
# consolidation detected for COMBOUSDT (current bar)
# consolidation detected for HAPPY-USDT (last closed bar)
# consolidation detected for HAPPY-USDT (current bar)
# consolidation detected for HAPPY-USDT
# consolidation detected for HEART-USDT
# consolidation detected for COMBOUSDT
# consolidation detected for XUSDUSDT (last closed bar)
# consolidation detected for XUSDUSDT (current bar)
# consolidation detected for XUSDUSDT
# consolidation detected for HMSTR-USDT (last closed bar)
# consolidation detected for HMSTR-USDT (current bar)
# consolidation detected for HONEY-USDT (last closed bar)
# consolidation detected for HONEY-USDT (current bar)
# consolidation detected for HMSTR-USDT
# consolidation detected for HONEY-USDT
# consolidation detected for CRETAUSDT (last closed bar)
# consolidation detected for CRETAUSDT (current bar)
# consolidation detected for CRTAIUSDT (last closed bar)
# consolidation detected for CRTAIUSDT (current bar)
# consolidation detected for HUMA-USDT (last closed bar)
# consolidation detected for HUMA-USDT (current bar)
# consolidation detected for HUMA-USDT
# consolidation detected for CRETAUSDT
# consolidation detected for CRTAIUSDT
# [12:12:22] ✓ Completed binance_spot scan: 25 signals found
# consolidation detected for TUTUSDT (last closed bar)
# consolidation detected for TUTUSDT (current bar)
# consolidation detected for USDCUSDT (last closed bar)
# consolidation detected for USDCUSDT (current bar)
# consolidation detected for TUTUSDT
# consolidation detected for USDCUSDT
# consolidation detected for CSPRUSDT (last closed bar)
# consolidation detected for CSPRUSDT (current bar)
# consolidation detected for CSPRUSDT
# consolidation detected for INIT-USDT (last closed bar)
# consolidation detected for INIT-USDT (current bar)
# consolidation detected for USDCUSDT (last closed bar)
# consolidation detected for USDCUSDT (current bar)
# consolidation detected for INIT-USDT
# consolidation detected for USDCUSDT
# consolidation detected for XCNUSDT (last closed bar)
# consolidation detected for XCNUSDT (current bar)
# consolidation detected for WCTUSDT (last closed bar)
# consolidation detected for WCTUSDT (current bar)
# consolidation detected for WCTUSDT
# consolidation detected for XCNUSDT
# consolidation detected for WCTUSDT (last closed bar)
# consolidation detected for WCTUSDT (current bar)
# consolidation detected for WCTUSDT
# consolidation detected for ZEREBROUSDT (last closed bar)
# consolidation detected for ZEREBROUSDT (current bar)
# consolidation detected for ZEREBROUSDT
# consolidation detected for KAITO-USDT (last closed bar)
# consolidation detected for KAITO-USDT (current bar)
# consolidation detected for KAITO-USDT
# [12:12:30] ✓ Completed binance_futures scan: 27 signals found
# consolidation detected for XEMUSDT (last closed bar)
# consolidation detected for XEMUSDT (current bar)
# consolidation detected for XOUSDT (last closed bar)
# consolidation detected for XOUSDT (current bar)
# consolidation detected for XEMUSDT
# consolidation detected for XOUSDT
# consolidation detected for DEGOUSDT (last closed bar)
# consolidation detected for DEGOUSDT (current bar)
# consolidation detected for DEGOUSDT
# consolidation detected for ZEREBROUSDT (last closed bar)
# consolidation detected for ZEREBROUSDT (current bar)
# consolidation detected for ZEREBROUSDT
# consolidation detected for DIKOUSDT (last closed bar)
# consolidation detected for DIKOUSDT (current bar)
# consolidation detected for DIKOUSDT
# consolidation detected for ZTXUSDT (current bar)
# consolidation detected for ZTXUSDT
# [12:12:34] ✓ Completed bybit_spot scan: 53 signals found
# consolidation detected for LVVA-USDT (last closed bar)
# consolidation detected for LVVA-USDT (current bar)
# consolidation detected for LVVA-USDT
# consolidation detected for DYNAUSDT (last closed bar)
# consolidation detected for DYNAUSDT (current bar)
# consolidation detected for DYNAUSDT
# consolidation detected for MAJOR-USDT (last closed bar)
# consolidation detected for MAJOR-USDT (current bar)
# consolidation detected for MAJOR-USDT
# consolidation detected for MASK-USDT (last closed bar)
# consolidation detected for MASK-USDT (current bar)
# consolidation detected for MASK-USDT
# consolidation detected for ELONSOLUSDT (last closed bar)
# consolidation detected for ELONSOLUSDT (current bar)
# consolidation detected for ELFUSDT (last closed bar)
# consolidation detected for ELFUSDT (current bar)
# consolidation detected for ELFUSDT
# consolidation detected for ELONSOLUSDT
# consolidation detected for MELANIA-USDT (last closed bar)
# consolidation detected for MELANIA-USDT (current bar)
# consolidation detected for MELANIA-USDT
# consolidation detected for EPILEPTICUSDT (last closed bar)
# consolidation detected for EPILEPTICUSDT (current bar)
# consolidation detected for EPILEPTICUSDT
# consolidation detected for FLOCKUSDT (last closed bar)
# consolidation detected for FLOCKUSDT (current bar)
# consolidation detected for NEWT-USDT (last closed bar)
# consolidation detected for NEWT-USDT (current bar)
# consolidation detected for FLOCKUSDT
# consolidation detected for NEWT-USDT
# consolidation detected for DIGG_USDT (last closed bar)
# consolidation detected for DIGG_USDT (current bar)
# consolidation detected for DIGG_USDT
# consolidation detected for FUSEUSDT (last closed bar)
# consolidation detected for FUSEUSDT (current bar)
# consolidation detected for FUSDUSDT (last closed bar)
# consolidation detected for FUSDUSDT (current bar)
# consolidation detected for FUTUREUSDT (last closed bar)
# consolidation detected for FUTUREUSDT (current bar)
# consolidation detected for FUSDUSDT
# consolidation detected for FUSEUSDT
# consolidation detected for FUTUREUSDT
# consolidation detected for NXPC-USDT (last closed bar)
# consolidation detected for NXPC-USDT (current bar)
# consolidation detected for NXPC-USDT
# consolidation detected for ORBS-USDT (last closed bar)
# consolidation detected for ORBS-USDT (current bar)
# consolidation detected for ORBS-USDT
# consolidation detected for GHXUSDT (last closed bar)
# consolidation detected for GHXUSDT (current bar)
# consolidation detected for GHXUSDT
# consolidation detected for PAXG-USDT (last closed bar)
# consolidation detected for PAXG-USDT (current bar)
# consolidation detected for PAXG-USDT
# consolidation detected for GMEUSDT (last closed bar)
# consolidation detected for GMEUSDT (current bar)
# consolidation detected for GINIUSDT (last closed bar)
# consolidation detected for GINIUSDT (current bar)
# consolidation detected for GINIUSDT
# consolidation detected for GMEUSDT
# consolidation detected for PEN-USDT (last closed bar)
# consolidation detected for PEN-USDT (current bar)
# consolidation detected for PEN-USDT
# consolidation detected for GMRTUSDT (last closed bar)
# consolidation detected for GMRTUSDT (current bar)
# consolidation detected for GOHOMEUSDT (last closed bar)
# consolidation detected for GOHOMEUSDT (current bar)
# consolidation detected for GMRTUSDT
# consolidation detected for GOHOMEUSDT
# consolidation detected for PMG-USDT (last closed bar)
# consolidation detected for PMG-USDT (current bar)
# consolidation detected for PIX-USDT (last closed bar)
# consolidation detected for PIX-USDT (current bar)
# consolidation detected for PIX-USDT
# consolidation detected for PMG-USDT
# consolidation detected for PNUT-USDT (last closed bar)
# consolidation detected for PNUT-USDT (current bar)
# consolidation detected for PNUT-USDT
# consolidation detected for PSTAKE-USDT (current bar)
# consolidation detected for PSTAKE-USDT
# consolidation detected for GVNRUSDT (last closed bar)
# consolidation detected for GVNRUSDT (current bar)
# consolidation detected for GVNRUSDT
# consolidation detected for PZP-USDT (last closed bar)
# consolidation detected for PZP-USDT (current bar)
# consolidation detected for HAPPYUSDT (last closed bar)
# consolidation detected for HAPPYUSDT (current bar)
# consolidation detected for HAPIUSDT (last closed bar)
# consolidation detected for HAPIUSDT (current bar)
# consolidation detected for HAPIUSDT
# consolidation detected for HAPPYUSDT
# consolidation detected for PZP-USDT
# consolidation detected for HMSTRUSDT (last closed bar)
# consolidation detected for HMSTRUSDT (current bar)
# consolidation detected for RESOLV-USDT (last closed bar)
# consolidation detected for RESOLV-USDT (current bar)
# consolidation detected for HMSTRUSDT
# consolidation detected for RESOLV-USDT
# consolidation detected for HOPRUSDT (current bar)
# consolidation detected for HOPRUSDT
# consolidation detected for HTMUSDT (last closed bar)
# consolidation detected for HTMUSDT (current bar)
# consolidation detected for RVN-USDT (last closed bar)
# consolidation detected for RVN-USDT (current bar)
# consolidation detected for HTMUSDT
# consolidation detected for RVN-USDT
# consolidation detected for HYDRAUSDT (last closed bar)
# consolidation detected for HYDRAUSDT (current bar)
# consolidation detected for HUMAUSDT (last closed bar)
# consolidation detected for HUMAUSDT (current bar)
# consolidation detected for HUSDT (last closed bar)
# consolidation detected for HUSDT (current bar)
# consolidation detected for SAHARA-USDT (last closed bar)
# consolidation detected for SAHARA-USDT (current bar)
# consolidation detected for HUMAUSDT
# consolidation detected for HUSDT
# consolidation detected for HYDRAUSDT
# consolidation detected for SAHARA-USDT
# consolidation detected for ICECREAMUSDT (last closed bar)
# consolidation detected for ICECREAMUSDT (current bar)
# consolidation detected for SFI-USDT (last closed bar)
# consolidation detected for SFI-USDT (current bar)
# consolidation detected for ICECREAMUSDT
# consolidation detected for SFI-USDT
# consolidation detected for FDUSD_USDT (last closed bar)
# consolidation detected for FDUSD_USDT (current bar)
# consolidation detected for FB_USDT (last closed bar)
# consolidation detected for FB_USDT (current bar)
# consolidation detected for FB_USDT
# consolidation detected for FDUSD_USDT
# consolidation detected for SKEY-USDT (last closed bar)
# consolidation detected for SKEY-USDT (current bar)
# consolidation detected for SKEY-USDT
# consolidation detected for ITHACAUSDT (last closed bar)
# consolidation detected for ITHACAUSDT (current bar)
# consolidation detected for ITHACAUSDT
# consolidation detected for SOLV-USDT (last closed bar)
# consolidation detected for SOLV-USDT (current bar)
# consolidation detected for SOLV-USDT
# consolidation detected for FLOCK_USDT (last closed bar)
# consolidation detected for FLOCK_USDT (current bar)
# consolidation detected for FLOCK_USDT
# consolidation detected for JOYSTREAMUSDT (current bar)
# consolidation detected for JOYSTREAMUSDT
# consolidation detected for KAITOUSDT (last closed bar)
# consolidation detected for KAITOUSDT (current bar)
# consolidation detected for KARATUSDT (last closed bar)
# consolidation detected for KARATUSDT (current bar)
# consolidation detected for KAITOUSDT
# consolidation detected for KARATUSDT
# consolidation detected for KDXUSDT (last closed bar)
# consolidation detected for KDXUSDT (current bar)
# consolidation detected for KDXUSDT
# consolidation detected for SWASH-USDT (last closed bar)
# consolidation detected for SWASH-USDT (current bar)
# consolidation detected for SWASH-USDT
# consolidation detected for SYLO-USDT (last closed bar)
# consolidation detected for SYLO-USDT (current bar)
# consolidation detected for SYLO-USDT
# consolidation detected for LAUNCHCOINUSDT (current bar)
# consolidation detected for LAUNCHCOINUSDT
# consolidation detected for LGCTUSDT (last closed bar)
# consolidation detected for LGCTUSDT (current bar)
# consolidation detected for LINGOUSDT (last closed bar)
# consolidation detected for LINGOUSDT (current bar)
# consolidation detected for LGCTUSDT
# consolidation detected for LINGOUSDT
# consolidation detected for LIQUIDIUMUSDT (last closed bar)
# consolidation detected for LIQUIDIUMUSDT (current bar)
# consolidation detected for LLUSDT (last closed bar)
# consolidation detected for LLUSDT (current bar)
# consolidation detected for LIQUIDIUMUSDT
# consolidation detected for LLUSDT
# consolidation detected for LOOMUSDT (last closed bar)
# consolidation detected for LOOMUSDT (current bar)
# consolidation detected for LOOMUSDT
# consolidation detected for LOTUSDT (last closed bar)
# consolidation detected for LOTUSDT (current bar)
# consolidation detected for LRDSUSDT (current bar)
# consolidation detected for LOTUSDT
# consolidation detected for LRDSUSDT
# consolidation detected for USDD-USDT (last closed bar)
# consolidation detected for USDD-USDT (current bar)
# consolidation detected for USDD-USDT
# consolidation detected for LUNAIUSDT (current bar)
# consolidation detected for LUNAIUSDT
# consolidation detected for GOHOME_USDT (last closed bar)
# consolidation detected for GOHOME_USDT (current bar)
# consolidation detected for GOHOME_USDT
# consolidation detected for LVVAUSDT (last closed bar)
# consolidation detected for LVVAUSDT (current bar)
# consolidation detected for LVVAUSDT
# consolidation detected for MAJORUSDT (last closed bar)
# consolidation detected for MAJORUSDT (current bar)
# consolidation detected for MAJORUSDT
# consolidation detected for MASKUSDT (last closed bar)
# consolidation detected for MASKUSDT (current bar)
# consolidation detected for MASKUSDT
# consolidation detected for MBXUSDT (last closed bar)
# consolidation detected for MBXUSDT (current bar)
# consolidation detected for MBXUSDT
# consolidation detected for WCT-USDT (last closed bar)
# consolidation detected for WCT-USDT (current bar)
# consolidation detected for WCT-USDT
# consolidation detected for MEERUSDT (last closed bar)
# consolidation detected for MEERUSDT
# consolidation detected for WOD-USDT (last closed bar)
# consolidation detected for WOD-USDT (current bar)
# consolidation detected for WOD-USDT
# consolidation detected for METANIAUSDT (current bar)
# consolidation detected for MENGOUSDT (last closed bar)
# consolidation detected for MENGOUSDT (current bar)
# consolidation detected for MENGOUSDT
# consolidation detected for METANIAUSDT
# consolidation detected for XCN-USDT (last closed bar)
# consolidation detected for XCN-USDT (current bar)
# consolidation detected for XCN-USDT
# consolidation detected for METUSDT (current bar)
# consolidation detected for MFTUSDT (last closed bar)
# consolidation detected for MFTUSDT (current bar)
# consolidation detected for METUSDT
# consolidation detected for MFTUSDT
# consolidation detected for XOXO-USDT (last closed bar)
# consolidation detected for XOXO-USDT (current bar)
# consolidation detected for XR-USDT (last closed bar)
# consolidation detected for XR-USDT (current bar)
# consolidation detected for XOXO-USDT
# consolidation detected for XR-USDT
# consolidation detected for MINIMAUSDT (current bar)
# consolidation detected for MINIMAUSDT
# consolidation detected for HOLDSTATION_USDT (last closed bar)
# consolidation detected for HOLDSTATION_USDT
# consolidation detected for MIUUSDT (current bar)
# consolidation detected for MIUUSDT
# consolidation detected for ZEREBRO-USDT (last closed bar)
# consolidation detected for ZEREBRO-USDT (current bar)
# consolidation detected for ZEREBRO-USDT
# consolidation detected for MNSRYUSDT (last closed bar)
# consolidation detected for MNSRYUSDT (current bar)
# consolidation detected for MNSRYUSDT
# consolidation detected for ZEUS-USDT (last closed bar)
# consolidation detected for ZEUS-USDT (current bar)
# consolidation detected for ZEUS-USDT
# consolidation detected for MODEUSDT (current bar)
# consolidation detected for H_USDT (last closed bar)
# consolidation detected for H_USDT (current bar)
# consolidation detected for MODEUSDT
# consolidation detected for H_USDT
# consolidation detected for MOREUSDT (last closed bar)
# consolidation detected for MOREUSDT (current bar)
# consolidation detected for MOREUSDT
# [12:14:07] ✓ Completed kucoin_spot scan: 49 signals found
# consolidation detected for MSQUSDT (last closed bar)
# consolidation detected for MSQUSDT (current bar)
# consolidation detected for MSQUSDT
# consolidation detected for MYSTUSDT (last closed bar)
# consolidation detected for MYSTUSDT (current bar)
# consolidation detected for MXNAUSDT (last closed bar)
# consolidation detected for MXNAUSDT (current bar)
# consolidation detected for MXNAUSDT
# consolidation detected for MYSTUSDT
# consolidation detected for NCUSDT (last closed bar)
# consolidation detected for NCUSDT (current bar)
# consolidation detected for NCUSDT
# consolidation detected for NEONUSDT (last closed bar)
# consolidation detected for NEONUSDT (current bar)
# consolidation detected for NEWTUSDT (last closed bar)
# consolidation detected for NEWTUSDT (current bar)
# consolidation detected for NEONUSDT
# consolidation detected for NEWTUSDT
# consolidation detected for NOWUSDT (current bar)
# consolidation detected for NRWAUSDT (last closed bar)
# consolidation detected for NRWAUSDT (current bar)
# consolidation detected for NRNUSDT (last closed bar)
# consolidation detected for NRNUSDT (current bar)
# consolidation detected for NOWUSDT
# consolidation detected for NRNUSDT
# consolidation detected for NRWAUSDT
# consolidation detected for KAITO_USDT (last closed bar)
# consolidation detected for KAITO_USDT (current bar)
# consolidation detected for KAITO_USDT
# consolidation detected for NUMUSDT (last closed bar)
# consolidation detected for NUMUSDT (current bar)
# consolidation detected for NULSUSDT (last closed bar)
# consolidation detected for NULSUSDT (current bar)
# consolidation detected for NULSUSDT
# consolidation detected for NUMUSDT
# consolidation detected for OBTUSDT (last closed bar)
# consolidation detected for OBTUSDT (current bar)
# consolidation detected for NXPCUSDT (last closed bar)
# consolidation detected for NXPCUSDT (current bar)
# consolidation detected for NXPCUSDT
# consolidation detected for OBTUSDT
# consolidation detected for OGYUSDT (last closed bar)
# consolidation detected for OGYUSDT (current bar)
# consolidation detected for OGYUSDT
# consolidation detected for OMAXUSDT (current bar)
# consolidation detected for OMAXUSDT
# consolidation detected for OMZUSDT (last closed bar)
# consolidation detected for OMZUSDT (current bar)
# consolidation detected for OMZUSDT
# consolidation detected for OVRUSDT (last closed bar)
# consolidation detected for OVRUSDT
# consolidation detected for LAYER_USDT (last closed bar)
# consolidation detected for LAYER_USDT (current bar)
# consolidation detected for LAYER_USDT
# consolidation detected for PARTUSDT (last closed bar)
# consolidation detected for PARTUSDT (current bar)
# consolidation detected for PARTUSDT
# consolidation detected for PBUXUSDT (current bar)
# consolidation detected for PBUXUSDT
# consolidation detected for PEPUUSDT (current bar)
# consolidation detected for PHILUSDT (last closed bar)
# consolidation detected for PHILUSDT (current bar)
# consolidation detected for PEPUUSDT
# consolidation detected for PHILUSDT
# consolidation detected for PLBUSDT (last closed bar)
# consolidation detected for PLBUSDT (current bar)
# consolidation detected for PLMSUSDT (last closed bar)
# consolidation detected for PLMSUSDT (current bar)
# consolidation detected for PLBUSDT
# consolidation detected for PLMSUSDT
# consolidation detected for PMTUSDT (last closed bar)
# consolidation detected for PMTUSDT (current bar)
# consolidation detected for PMTUSDT
# consolidation detected for PPCUSDT (last closed bar)
# consolidation detected for PPCUSDT (current bar)
# consolidation detected for PPCUSDT
# consolidation detected for PSGUSDT (last closed bar)
# consolidation detected for PSGUSDT (current bar)
# consolidation detected for PROUSDT (last closed bar)
# consolidation detected for PROUSDT (current bar)
# consolidation detected for PROUSDT
# consolidation detected for PSGUSDT
# consolidation detected for PSTAKEUSDT (last closed bar)
# consolidation detected for PSTAKEUSDT (current bar)
# consolidation detected for PSUSDT (last closed bar)
# consolidation detected for PSUSDT (current bar)
# consolidation detected for PSTAKEUSDT
# consolidation detected for PSUSDT
# consolidation detected for PUSSUSDT (current bar)
# consolidation detected for PUSSUSDT
# consolidation detected for QAIUSDT (last closed bar)
# consolidation detected for QAIUSDT (current bar)
# consolidation detected for QAIUSDT
# consolidation detected for MELANIA_USDT (last closed bar)
# consolidation detected for MELANIA_USDT (current bar)
# consolidation detected for MELANIA_USDT
# consolidation detected for REIUSDT (last closed bar)
# consolidation detected for REIUSDT (current bar)
# consolidation detected for REIUSDT
# consolidation detected for RESOLVUSDT (last closed bar)
# consolidation detected for RESOLVUSDT (current bar)
# consolidation detected for RESOLVUSDT
# consolidation detected for RKNEUSDT (last closed bar)
# consolidation detected for RKNEUSDT (current bar)
# consolidation detected for RKNEUSDT
# consolidation detected for RTFUSDT (last closed bar)
# consolidation detected for RTFUSDT (current bar)
# consolidation detected for RTFUSDT
# consolidation detected for MORE_USDT (last closed bar)
# consolidation detected for MORE_USDT (current bar)
# consolidation detected for SAHARAUSDT (last closed bar)
# consolidation detected for SAHARAUSDT (current bar)
# consolidation detected for SAHARAUSDT
# consolidation detected for SCARCITYUSDT (last closed bar)
# consolidation detected for SCARCITYUSDT (current bar)
# consolidation detected for SCARCITYUSDT
# consolidation detected for MORE_USDT
# consolidation detected for SCUSDT (current bar)
# consolidation detected for SCUSDT
# consolidation detected for MOVE_USDT (last closed bar)
# consolidation detected for MOVE_USDT (current bar)
# consolidation detected for MOVE_USDT
# consolidation detected for SEEDUSDT (last closed bar)
# consolidation detected for SEEDUSDT (current bar)
# consolidation detected for SEEDUSDT
# consolidation detected for SERAPHUSDT (last closed bar)
# consolidation detected for SERAPHUSDT (current bar)
# consolidation detected for SERAPHUSDT
# consolidation detected for SFLUSDT (current bar)
# consolidation detected for SFLUSDT
# consolidation detected for SLFUSDT (last closed bar)
# consolidation detected for SLCUSDT (last closed bar)
# consolidation detected for SLCUSDT (current bar)
# consolidation detected for SKYAUSDT (current bar)
# consolidation detected for SKYAUSDT
# consolidation detected for SLCUSDT
# consolidation detected for SLFUSDT
# consolidation detected for SNTUSDT (last closed bar)
# consolidation detected for SNTUSDT (current bar)
# consolidation detected for SNTUSDT
# consolidation detected for SOONXUSDT (current bar)
# consolidation detected for SOLVUSDT (last closed bar)
# consolidation detected for SOLVUSDT (current bar)
# consolidation detected for SOPHUSDT (last closed bar)
# consolidation detected for SOPHUSDT (current bar)
# consolidation detected for SOLVUSDT
# consolidation detected for SOONXUSDT
# consolidation detected for SOPHUSDT
# consolidation detected for NEWT_USDT (last closed bar)
# consolidation detected for NEWT_USDT (current bar)
# consolidation detected for NEWT_USDT
# consolidation detected for SPAUSDT (last closed bar)
# consolidation detected for SPAUSDT (current bar)
# consolidation detected for SPAUSDT
# consolidation detected for SQTUSDT (last closed bar)
# consolidation detected for SQTUSDT (current bar)
# consolidation detected for SQTUSDT
# consolidation detected for STARUSDT (last closed bar)
# consolidation detected for STARUSDT (current bar)
# consolidation detected for STARUSDT
# consolidation detected for NUMI_USDT (last closed bar)
# consolidation detected for NUMI_USDT (current bar)
# consolidation detected for NUMI_USDT
# consolidation detected for STRDUSDT (last closed bar)
# consolidation detected for STRDUSDT (current bar)
# consolidation detected for NXPC_USDT (last closed bar)
# consolidation detected for NXPC_USDT (current bar)
# consolidation detected for STRDUSDT
# consolidation detected for NXPC_USDT
# consolidation detected for SUP1USDT (last closed bar)
# consolidation detected for SUP1USDT (current bar)
# consolidation detected for SUKUUSDT (last closed bar)
# consolidation detected for SUKUUSDT (current bar)
# consolidation detected for SUKUUSDT
# consolidation detected for SUP1USDT
# consolidation detected for OM_USDT (last closed bar)
# consolidation detected for OM_USDT (current bar)
# consolidation detected for OM_USDT
# consolidation detected for TESUSDT (last closed bar)
# consolidation detected for TESUSDT (current bar)
# consolidation detected for TESUSDT
# consolidation detected for TRIASUSDT (last closed bar)
# consolidation detected for TRIASUSDT (current bar)
# consolidation detected for TRIASUSDT
# consolidation detected for TRUUUSDT (last closed bar)
# consolidation detected for TRUUUSDT (current bar)
# consolidation detected for TRUUUSDT
# consolidation detected for TUSDUSDT (last closed bar)
# consolidation detected for TUSDUSDT (current bar)
# consolidation detected for TUTUSDT (last closed bar)
# consolidation detected for TUTUSDT (current bar)
# consolidation detected for TUSDUSDT
# consolidation detected for TUTUSDT
# consolidation detected for UNILAPSEUSDT (last closed bar)
# consolidation detected for UNILAPSEUSDT (current bar)
# consolidation detected for UNILAPSEUSDT
# consolidation detected for USDDUSDT (last closed bar)
# consolidation detected for USDDUSDT (current bar)
# consolidation detected for USD1USDT (last closed bar)
# consolidation detected for USD1USDT (current bar)
# consolidation detected for USD1USDT
# consolidation detected for USDDUSDT
# consolidation detected for USDPUSDT (last closed bar)
# consolidation detected for USDPUSDT (current bar)
# consolidation detected for USDPUSDT
# consolidation detected for VERSEWORLDUSDT (last closed bar)
# consolidation detected for VERSEWORLDUSDT (current bar)
# consolidation detected for VGXUSDT (last closed bar)
# consolidation detected for VGXUSDT (current bar)
# consolidation detected for VERSEUSDT (last closed bar)
# consolidation detected for VERSEUSDT (current bar)
# consolidation detected for VERSEUSDT
# consolidation detected for VERSEWORLDUSDT
# consolidation detected for VGXUSDT
# consolidation detected for VPRUSDT (last closed bar)
# consolidation detected for VPRUSDT (current bar)
# consolidation detected for VPRUSDT
# consolidation detected for PSG_USDT (last closed bar)
# consolidation detected for PSG_USDT (current bar)
# consolidation detected for PSG_USDT
# consolidation detected for WCTUSDT (last closed bar)
# consolidation detected for WCTUSDT (current bar)
# consolidation detected for WCTUSDT
# consolidation detected for WINGUSDT (last closed bar)
# consolidation detected for WINGUSDT (current bar)
# consolidation detected for WINGUSDT
# consolidation detected for WODUSDT (last closed bar)
# consolidation detected for WODUSDT (current bar)
# consolidation detected for WODUSDT
# consolidation detected for WRKXUSDT (last closed bar)
# consolidation detected for WRKXUSDT (current bar)
# consolidation detected for WRKXUSDT
# consolidation detected for XCNUSDT (last closed bar)
# consolidation detected for XCNUSDT (current bar)
# consolidation detected for XCNUSDT
# consolidation detected for XELSUSDT (last closed bar)
# consolidation detected for XELSUSDT (current bar)
# consolidation detected for XELSUSDT
# consolidation detected for XHPUSDT (last closed bar)
# consolidation detected for XHPUSDT
# consolidation detected for XOUSDT (last closed bar)
# consolidation detected for XOUSDT (current bar)
# consolidation detected for XOUSDT
# consolidation detected for RESOLV_USDT (last closed bar)
# consolidation detected for RESOLV_USDT (current bar)
# consolidation detected for RESOLV_USDT
# consolidation detected for ZEREBROUSDT (last closed bar)
# consolidation detected for ZEREBROUSDT (current bar)
# ...
# consolidation detected for WAMPL_USDT
# consolidation detected for WBTC_USDT
# consolidation detected for WCT_USDT (last closed bar)
# consolidation detected for WCT_USDT (current bar)
# consolidation detected for WCT_USDT
# consolidation detected for WOD_USDT (last closed bar)
# consolidation detected for WOD_USDT (current bar)
# consolidation detected for WOD_USDT
# consolidation detected for ZBU_USDT (current bar)
# consolidation detected for ZBU_USDT
# consolidation detected for ZEREBRO_USDT (last closed bar)
# consolidation detected for ZEREBRO_USDT (current bar)
# consolidation detected for ZEREBRO_USDT
# [12:24:39] ✓ Completed gateio_spot scan: 53 signals found
# Processing 1w timeframe
# [12:24:41] Starting scan on binance_spot for 1w timeframe...
# [12:24:41] Starting scan on binance_futures for 1w timeframe...
# [12:24:41] Starting scan on bybit_spot for 1w timeframe...
# [12:24:41] Starting scan on kucoin_spot for 1w timeframe...
# [12:24:41] Starting scan on mexc_spot for 1w timeframe...
# [12:24:41] Starting scan on gateio_spot for 1w timeframe...
# Found 2000 markets on Mexc for 1w timeframe
# Processing 2000 symbols for Mexc...
# Found 409 markets on Binance Spot for 1w timeframe
# Processing 409 symbols for Binance Spot...
# Found 469 markets on Binance Futures for 1w timeframe
# Processing 469 symbols for Binance Futures...
# Found 516 markets on Bybit for 1w timeframe
# Processing 516 symbols for Bybit...
# consolidation detected for 1000LUNCUSDT (last closed bar)
# consolidation detected for 1000LUNCUSDT (current bar)
# consolidation detected for 1000LUNCUSDT
# Found 1068 markets on Kucoin for 1w timeframe
# Processing 1068 symbols for Kucoin...
# Found 2512 markets on Gateio for 1w timeframe
# Processing 2512 symbols for Gateio...
# consolidation detected for ALCHUSDT (current bar)
# consolidation detected for ALCHUSDT
# consolidation detected for AMPUSDT (current bar)
# consolidation detected for AMPUSDT
# consolidation detected for ALCHUSDT (current bar)
# consolidation detected for ALCHUSDT
# consolidation detected for B3USDT (last closed bar)
# consolidation detected for B3USDT (current bar)
# consolidation detected for B3USDT
# consolidation detected for BANUSDT (last closed bar)
# consolidation detected for BANUSDT (current bar)
# consolidation detected for BANUSDT
# consolidation detected for B3USDT (last closed bar)
# consolidation detected for B3USDT (current bar)
# consolidation detected for B3USDT
# consolidation detected for BANUSDT (last closed bar)
# consolidation detected for BANUSDT (current bar)
# consolidation detected for BANUSDT
# consolidation detected for CSPRUSDT (last closed bar)
# consolidation detected for CSPRUSDT (current bar)
# consolidation detected for DAIUSDT (last closed bar)
# consolidation detected for DAIUSDT (current bar)
# consolidation detected for CSPRUSDT
# consolidation detected for DAIUSDT
# consolidation detected for DEXEUSDT (current bar)
# consolidation detected for DEGOUSDT (current bar)
# consolidation detected for DFUSDT (current bar)
# consolidation detected for DEGOUSDT
# consolidation detected for DEXEUSDT
# consolidation detected for DFUSDT
# consolidation detected for DFUSDT (current bar)
# consolidation detected for DEXEUSDT (current bar)
# consolidation detected for FDUSDUSDT (last closed bar)
# consolidation detected for FDUSDUSDT (current bar)
# consolidation detected for DEXEUSDT
# consolidation detected for DFUSDT
# consolidation detected for FDUSDUSDT
# consolidation detected for FORTUSDT (current bar)
# consolidation detected for FORTUSDT
# consolidation detected for GALAXISUSDT (last closed bar)
# consolidation detected for GALAXISUSDT (current bar)
# consolidation detected for GALAXISUSDT
# consolidation detected for GODSUSDT (last closed bar)
# consolidation detected for GODSUSDT (current bar)
# consolidation detected for GODSUSDT
# consolidation detected for IQUSDT (last closed bar)
# consolidation detected for IQUSDT (current bar)
# consolidation detected for IQUSDT
# consolidation detected for KAVAUSDT (last closed bar)
# consolidation detected for KAVAUSDT
# consolidation detected for INTERUSDT (last closed bar)
# consolidation detected for INTERUSDT (current bar)
# consolidation detected for INTERUSDT
# consolidation detected for JSTUSDT (last closed bar)
# consolidation detected for JSTUSDT (current bar)
# consolidation detected for JSTUSDT
# consolidation detected for MASKUSDT (last closed bar)
# consolidation detected for MASKUSDT (current bar)
# consolidation detected for MASKUSDT
# consolidation detected for KAVAUSDT (last closed bar)
# consolidation detected for KAVAUSDT (current bar)
# consolidation detected for KAVAUSDT
# consolidation detected for LAVAUSDT (last closed bar)
# consolidation detected for LAVAUSDT (current bar)
# consolidation detected for LAYERUSDT (last closed bar)
# consolidation detected for LAYERUSDT (current bar)
# consolidation detected for LAVAUSDT
# consolidation detected for LAYERUSDT
# consolidation detected for KAVAUSDT (last closed bar)
# consolidation detected for KAVAUSDT
# consolidation detected for LUNCUSDT (last closed bar)
# consolidation detected for LUNCUSDT (current bar)
# consolidation detected for MAJORUSDT (last closed bar)
# consolidation detected for MAJORUSDT (current bar)
# consolidation detected for LUNCUSDT
# consolidation detected for MAJORUSDT
# consolidation detected for MASKUSDT (last closed bar)
# consolidation detected for MASKUSDT (current bar)
# consolidation detected for MCRTUSDT (last closed bar)
# consolidation detected for MCRTUSDT (current bar)
# consolidation detected for MASKUSDT
# consolidation detected for MCRTUSDT
# consolidation detected for MASKUSDT (last closed bar)
# consolidation detected for MASKUSDT (current bar)
# consolidation detected for MASKUSDT
# consolidation detected for OXTUSDT (last closed bar)
# consolidation detected for OXTUSDT (current bar)
# consolidation detected for OXTUSDT
# consolidation detected for PAXGUSDT (current bar)
# consolidation detected for PAXGUSDT
# consolidation detected for PONDUSDT (last closed bar)
# consolidation detected for PONDUSDT (current bar)
# consolidation detected for PONDUSDT
# consolidation detected for MVLUSDT (last closed bar)
# consolidation detected for MVLUSDT (current bar)
# consolidation detected for MVLUSDT
# consolidation detected for RADUSDT (last closed bar)
# consolidation detected for RADUSDT (current bar)
# consolidation detected for BADGER_USDT (current bar)
# consolidation detected for RADUSDT
# consolidation detected for BADGER_USDT
# consolidation detected for NLKUSDT (last closed bar)
# consolidation detected for NEXOUSDT (last closed bar)
# consolidation detected for NEXOUSDT (current bar)
# consolidation detected for NEXOUSDT
# consolidation detected for NLKUSDT
# consolidation detected for NYMUSDT (last closed bar)
# consolidation detected for ODOSUSDT (current bar)
# consolidation detected for NYMUSDT
# consolidation detected for ODOSUSDT
# consolidation detected for OXTUSDT (last closed bar)
# consolidation detected for OXTUSDT (current bar)
# consolidation detected for OXTUSDT
# consolidation detected for OMGUSDT (last closed bar)
# consolidation detected for OMGUSDT (current bar)
# consolidation detected for OMGUSDT
# consolidation detected for SOLVUSDT (last closed bar)
# consolidation detected for SOLVUSDT (current bar)
# consolidation detected for STGUSDT (last closed bar)
# consolidation detected for STGUSDT (current bar)
# consolidation detected for SOLVUSDT
# consolidation detected for STGUSDT
# consolidation detected for PUFFUSDT (last closed bar)
# consolidation detected for PUFFUSDT (current bar)
# consolidation detected for PUFFUSDT
# consolidation detected for PYUSDUSDT (last closed bar)
# consolidation detected for PYUSDUSDT (current bar)
# consolidation detected for PYUSDUSDT
# consolidation detected for TRUMPUSDT (last closed bar)
# consolidation detected for TRUMPUSDT (current bar)
# consolidation detected for TONUSDT (last closed bar)
# consolidation detected for TONUSDT (current bar)
# consolidation detected for TONUSDT
# consolidation detected for TRUMPUSDT
# consolidation detected for TUSDUSDT (last closed bar)
# consolidation detected for TUSDUSDT (current bar)
# consolidation detected for USDCUSDT (last closed bar)
# consolidation detected for USDCUSDT (current bar)
# consolidation detected for TUSDUSDT
# consolidation detected for USDCUSDT
# consolidation detected for SOLVUSDT (last closed bar)
# consolidation detected for SOLVUSDT (current bar)
# consolidation detected for SOLVUSDT
# consolidation detected for USDPUSDT (last closed bar)
# consolidation detected for USDPUSDT (current bar)
# consolidation detected for USDPUSDT
# consolidation detected for STGUSDT (last closed bar)
# consolidation detected for STGUSDT (current bar)
# consolidation detected for STGUSDT
# consolidation detected for SOSOUSDT (last closed bar)
# consolidation detected for SOSOUSDT (current bar)
# consolidation detected for SOLVUSDT (last closed bar)
# consolidation detected for SOLVUSDT (current bar)
# consolidation detected for SOLVUSDT
# consolidation detected for SOSOUSDT
# consolidation detected for VTHOUSDT (current bar)
# consolidation detected for WINUSDT (last closed bar)
# consolidation detected for VTHOUSDT
# consolidation detected for WINUSDT
# consolidation detected for STGUSDT (last closed bar)
# consolidation detected for STGUSDT (current bar)
# consolidation detected for STGUSDT
# consolidation detected for TRUMPUSDT (last closed bar)
# consolidation detected for TRUMPUSDT (current bar)
# consolidation detected for TRUMPUSDT
# [12:25:40] ✓ Completed binance_spot scan: 21 signals found
# consolidation detected for USDCUSDT (last closed bar)
# consolidation detected for USDCUSDT (current bar)
# consolidation detected for USDCUSDT
# consolidation detected for TONUSDT (last closed bar)
# consolidation detected for TONUSDT (current bar)
# consolidation detected for TRUMPUSDT (last closed bar)
# consolidation detected for TRUMPUSDT (current bar)
# consolidation detected for TONUSDT
# consolidation detected for TRUMPUSDT
# consolidation detected for VTHOUSDT (current bar)
# consolidation detected for TUSDUSDT (last closed bar)
# consolidation detected for TUSDUSDT (current bar)
# consolidation detected for VTHOUSDT
# consolidation detected for TUSDUSDT
# consolidation detected for USDCUSDT (last closed bar)
# consolidation detected for USDCUSDT (current bar)
# consolidation detected for USDDUSDT (last closed bar)
# consolidation detected for USDDUSDT (current bar)
# consolidation detected for USDEUSDT (last closed bar)
# consolidation detected for USDEUSDT (current bar)
# consolidation detected for USDCUSDT
# consolidation detected for USDDUSDT
# consolidation detected for USDEUSDT
# [12:25:48] ✓ Completed binance_futures scan: 14 signals found
# [12:25:53] ✓ Completed bybit_spot scan: 34 signals found
# consolidation detected for DAO_USDT (last closed bar)
# consolidation detected for DAO_USDT (current bar)
# consolidation detected for DAI_USDT (last closed bar)
# consolidation detected for DAI_USDT (current bar)
# consolidation detected for DAI_USDT
# consolidation detected for DAO_USDT
# consolidation detected for DEGO_USDT (last closed bar)
# consolidation detected for DEGO_USDT (current bar)
# consolidation detected for DEGO_USDT
# consolidation detected for DEXE_USDT (current bar)
# consolidation detected for DEXE_USDT
# consolidation detected for ELA_USDT (last closed bar)
# consolidation detected for ELA_USDT (current bar)
# consolidation detected for ELA_USDT
# consolidation detected for FDUSD_USDT (last closed bar)
# consolidation detected for FDUSD_USDT (current bar)
# consolidation detected for FDUSD_USDT
# consolidation detected for INTER_USDT (last closed bar)
# consolidation detected for INTER_USDT (current bar)
# consolidation detected for INTER_USDT
# consolidation detected for KAVA_USDT (last closed bar)
# consolidation detected for KAVA_USDT
# [12:27:43] ✓ Completed kucoin_spot scan: 0 signals found
# consolidation detected for LEO_USDT (last closed bar)
# consolidation detected for LEO_USDT (current bar)
# consolidation detected for LEO_USDT
# consolidation detected for MASK_USDT (last closed bar)
# consolidation detected for MASK_USDT (current bar)
# consolidation detected for MASK_USDT
# consolidation detected for OMG_USDT (last closed bar)
# consolidation detected for OMG_USDT (current bar)
# consolidation detected for OMG_USDT
# consolidation detected for PUFF_USDT (last closed bar)
# consolidation detected for PUFF_USDT (current bar)
# consolidation detected for PUFF_USDT
# consolidation detected for RAD_USDT (last closed bar)
# consolidation detected for RAD_USDT (current bar)
# consolidation detected for RAD_USDT
# [12:29:22] ✓ Completed mexc_spot scan: 0 signals found
# consolidation detected for TON_USDT (last closed bar)
# consolidation detected for TON_USDT (current bar)
# consolidation detected for TON_USDT
# consolidation detected for TRUMP_USDT (last closed bar)
# consolidation detected for TRUMP_USDT (current bar)
# consolidation detected for TRUMP_USDT
# consolidation detected for TUSD_USDT (last closed bar)
# consolidation detected for TUSD_USDT (current bar)
# consolidation detected for TUSD_USDT
# consolidation detected for XTTA_USDT (last closed bar)
# consolidation detected for XTTA_USDT (current bar)
# consolidation detected for XTTA_USDT
# [12:31:01] ✓ Completed gateio_spot scan: 18 signals found
#
# ================================================================================
#   PARALLEL MULTI-TIMEFRAME MULTI-EXCHANGE SCAN RESULTS
# ================================================================================
#
# Total signals found across all exchanges and timeframes: 913
# Start time: 12:11:08
# End time: 12:31:03
# Duration: 0:19:54
#
# Consolidation: 913 signals
#            symbol       date         close  current_bar  bars_inside  \
# 847  1000LUNCUSDT 2025-08-11  6.092000e-02         True          7.0
# 848      ALCHUSDT 2025-08-11  1.390700e-01         True          7.0
# 849        B3USDT 2025-08-11  3.236000e-03         True          7.0
# 850       BANUSDT 2025-08-11  6.930000e-02         True          7.0
# 851      DEXEUSDT 2025-08-11  7.284000e+00         True          7.0
# ..            ...        ...           ...          ...          ...
# 768      YOLOUSDT 2025-08-14  9.141000e-09         True          7.0
# 769       ZBUUSDT 2025-08-14  2.005900e+00         True          7.0
# 770   ZEREBROUSDT 2025-08-14  2.828000e-02         True          7.0
# 771       ZKPUSDT 2025-08-14  7.590000e-03         True          7.0
# 772     ZYPTOUSDT 2025-08-14  5.990000e-03         True          7.0
#
#      min_bars_inside_req  height_pct  max_height_pct_req  atr_ok  \
# 847                    4   29.476519                35.0   False
# 848                    4   32.377567                35.0    True
# 849                    4   44.998422                35.0    True
# 850                    4   32.816728                35.0   False
# 851                    4   26.282790                35.0    True
# ..                   ...         ...                 ...     ...
# 768                    4    1.092896                35.0    True
# 769                    4   23.399133                35.0    True
# 770                    4   24.478442                35.0   False
# 771                    4   17.708333                35.0   False
# 772                    4   29.861111                35.0    True
#
#        range_high     range_low     range_mid timeframe         exchange
# 847  7.244000e-02  5.383000e-02  6.313500e-02        1w  binance_futures
# 848  1.699900e-01  1.226200e-01  1.463050e-01        1w  binance_futures
# 849  3.882000e-03  2.456000e-03  3.169000e-03        1w  binance_futures
# 850  7.098000e-02  5.097000e-02  6.097500e-02        1w  binance_futures
# 851  8.842000e+00  6.788000e+00  7.815000e+00        1w  binance_futures
# ..            ...           ...           ...       ...              ...
# 768  9.200000e-09  9.100000e-09  9.150000e-09        3d        mexc_spot
# 769  2.320000e+00  1.834000e+00  2.077000e+00        3d        mexc_spot
# 770  3.228000e-02  2.524000e-02  2.876000e-02        3d        mexc_spot
# 771  8.360000e-03  7.000000e-03  7.680000e-03        3d        mexc_spot
# 772  6.620000e-03  4.900000e-03  5.760000e-03        3d        mexc_spot
#
# [913 rows x 14 columns]
# Scan completed!

# %%
# Seven Figures API Confluence Scanner with bar offset and quote currency options

from telegram.ext import Application
import logging
import pandas as pd
import numpy as np
import asyncio
import logging
import nest_asyncio
from datetime import datetime
from tqdm.asyncio import tqdm
import sys
import os
import html

# Add project path
project_dir = os.path.join(os.getcwd(), "Project")
sys.path.insert(0, project_dir)

from exchanges.sf_pairs_service import SFPairsService
from custom_strategies import detect_confluence

class ConfluenceScanner:
    def __init__(self, telegram_token, telegram_chat_id, exchange, timeframe, quote_currency="USDT", offset=1):
        self.telegram_token = telegram_token
        self.telegram_chat_id = telegram_chat_id
        self.telegram_app = None
        self.exchange = exchange
        self.timeframe = timeframe
        self.quote_currency = quote_currency.upper()  # USDT or BTC
        self.offset = offset  # Added offset parameter
        self.sf_service = SFPairsService()
        
    async def init_telegram(self):
        if self.telegram_app is None:
            self.telegram_app = Application.builder().token(self.telegram_token).build()

    async def send_telegram_alert(self, results):
        if not results:
            return
            
        try:
            message = f"🚨 Confluence Detection - {self.exchange} {self.timeframe} ({self.quote_currency})\n\n"
            
            # Map timeframe to TradingView format
            tv_timeframe_map = {
                "1d": "1D",
                "2d": "2D",
                "1w": "1W"
            }
            tv_timeframe = tv_timeframe_map.get(self.timeframe.lower(), self.timeframe)
            
            for result in results:
                exchange_name = self.exchange.upper()
                formatted_symbol = f"{result['symbol']}"
                tv_link = f"https://www.tradingview.com/chart/?symbol={exchange_name}:{formatted_symbol}&interval={tv_timeframe}"
                
                # Escape HTML entities in the URL
                escaped_link = html.escape(tv_link)
                
                # Format price value based on quote currency
                price_prefix = "₿" if self.quote_currency == "BTC" else "$"
                price_decimals = 8 if self.quote_currency == "BTC" else 4
                
                # Format according to specified requirements
                time_str = ""
                if result.get('timestamp') is not None:
                    time_str = f"Time: {result['timestamp'].strftime('%Y-%m-%d %H:%M:%S')}\n"
                
                message += (
                    f"Symbol: {result['symbol']}\n"
                    f"{time_str}"
                    f"Volume: {price_prefix}{result['volume_quote']:,.2f}\n"
                    f"Close: <a href='{escaped_link}'>{price_prefix}{result['close']:.{price_decimals}f}</a>\n"
                    f"Volume Ratio: {result['volume_ratio']:.2f}x\n"
                    f"Close Off Low: {result['close_off_low']:.1f}%\n"
                    f"{'='*30}\n"
                )
            
            # Split message more carefully to avoid breaking HTML tags
            max_length = 4000  # Reduced from 4096 to be safer
            
            if len(message) > max_length:
                # Split at natural breaks (between results) to avoid breaking HTML
                sections = message.split('='*30 + '\n')
                current_chunk = ""
                
                for section in sections:
                    if len(current_chunk + section + '='*30 + '\n') > max_length:
                        if current_chunk:
                            await self.telegram_app.bot.send_message(
                                chat_id=self.telegram_chat_id,
                                text=current_chunk.strip(),
                                parse_mode='HTML',
                                disable_web_page_preview=True
                            )
                        current_chunk = section + '\n'
                    else:
                        current_chunk += section + '='*30 + '\n'
                
                # Send remaining chunk
                if current_chunk.strip():
                    await self.telegram_app.bot.send_message(
                        chat_id=self.telegram_chat_id,
                        text=current_chunk.strip(),
                        parse_mode='HTML',
                        disable_web_page_preview=True
                    )
            else:
                await self.telegram_app.bot.send_message(
                    chat_id=self.telegram_chat_id,
                    text=message,
                    parse_mode='HTML',
                    disable_web_page_preview=True
                )
                
        except Exception as e:
            logging.error(f"Error sending Telegram alert: {str(e)}")
            
            # Fallback: send without HTML formatting
            try:
                price_prefix = "₿" if self.quote_currency == "BTC" else "$"
                simple_message = f"🚨 Confluence Detection - {self.exchange} {self.timeframe} ({self.quote_currency})\n\n"
                for result in results:
                    simple_message += (
                        f"Symbol: {result['symbol']}\n"
                        f"Volume: {price_prefix}{result['volume_quote']:,.2f}\n"
                        f"Close: {price_prefix}{result['close']:,.8f}\n"
                        f"Volume Ratio: {result['volume_ratio']:.2f}x\n"
                        f"Components: Vol={result['high_volume']}, Spread={result['spread_breakout']}, Mom={result['momentum_breakout']}\n\n"
                    )
                
                await self.telegram_app.bot.send_message(
                    chat_id=self.telegram_chat_id,
                    text=simple_message,
                    disable_web_page_preview=True
                )
            except Exception as fallback_error:
                logging.error(f"Fallback Telegram send also failed: {str(fallback_error)}")

    def prepare_sf_data(self, raw_df):
        """Convert SF data to confluence-compatible format"""
        if raw_df is None or len(raw_df) == 0:
            return None
        
        df = pd.DataFrame(raw_df)
        
        # Convert datetime column to pandas datetime and set as index
        if 'datetime' in df.columns:
            df['datetime'] = pd.to_datetime(df['datetime'])
            df = df.set_index('datetime')
        elif 'time' in df.columns:
            # Convert Unix timestamp to datetime
            df['time'] = pd.to_datetime(df['time'], unit='ms')
            df = df.set_index('time')
        
        # Select only OHLCV columns needed for confluence
        required_cols = ['open', 'high', 'low', 'close', 'volume']
        available_cols = [col for col in required_cols if col in df.columns]
        
        if len(available_cols) != 5:
            return None
        
        # Select and clean data
        result_df = df[required_cols].copy()
        
        # Ensure numeric types
        for col in required_cols:
            result_df[col] = pd.to_numeric(result_df[col], errors='coerce')
        
        # Drop any NaN rows
        result_df = result_df.dropna()
        
        return result_df

    def scan_single_market(self, pair, ohlcv_data):
        """Scan a single market for Confluence pattern in the specified bar"""
        try:
            # Prepare data for confluence analysis
            df = self.prepare_sf_data(ohlcv_data)
            
            if df is None or len(df) < 50:  # Need enough data for confluence
                return None
            
            # Calculate which bar to check based on offset
            check_bar = -(self.offset + 1)  # offset=0 means current bar (-1), offset=1 means last closed (-2), etc.
            
            # Run confluence detection
            detected, result = detect_confluence(df, check_bar=check_bar)
            
            if detected:
                # Calculate volume in quote currency for the target bar
                target_close = df['close'].iloc[check_bar]
                target_volume = df['volume'].iloc[check_bar]
                volume_quote = float(target_close) * float(target_volume)
                
                confluence_result = {
                    'symbol': f"{pair['Token']}{self.quote_currency}",
                    'volume_quote': volume_quote,
                    'close': float(target_close),
                    'volume': float(target_volume),
                    'volume_ratio': result['volume_ratio'],
                    'close_off_low': result['close_off_low'],
                    'momentum_score': result['momentum_score'],
                    'high_volume': result['high_volume'],
                    'spread_breakout': result['spread_breakout'],
                    'momentum_breakout': result['momentum_breakout'],
                    'bar_range': result['bar_range']
                }
                return confluence_result
                
        except Exception as e:
            logging.error(f"Error processing {pair['Token']}{self.quote_currency}: {str(e)}")
        return None

    async def scan_all_markets(self):
        """Scan all markets for Confluence pattern"""
        await self.init_telegram()
        try:
            # Define volume thresholds based on quote currency
            if self.quote_currency == "USDT":
                volume_thresholds = {
                    "1w": 300000,
                    "2d": 100000,
                    "1d": 50000
                }
            else:  # BTC
                volume_thresholds = {
                    "1w": 3,
                    "2d": 1,
                    "1d": 0.5
                }
                
            min_volume = volume_thresholds.get(self.timeframe.lower(), 50000 if self.quote_currency == "USDT" else 0.5)
            currency_symbol = "$" if self.quote_currency == "USDT" else "₿"
            
            # Create offset description
            if self.offset == 0:
                offset_desc = "current candle"
            elif self.offset == 1:
                offset_desc = "last closed candle"
            else:
                offset_desc = f"{self.offset} candles ago"
            
            print(f"Scanning for Confluence patterns in {offset_desc}...")
            print(f"Quote currency: {self.quote_currency}")
            print(f"Minimum volume threshold: {currency_symbol}{min_volume:,.2f}")
            
            # Get all pairs from SF service
            print(f"Fetching pairs from {self.exchange}...")
            all_pairs = self.sf_service.get_pairs_of_exchange(self.exchange)
            
            # Filter pairs based on quote currency
            if self.quote_currency == "USDT":
                quote_filtered_pairs = [
                    pair for pair in all_pairs 
                    if 'Quote' in pair and pair['Quote'].upper() == "USDT"
                ]
                print(f"Found {len(quote_filtered_pairs)} USDT pairs to scan")
            else:  # BTC pairs
                usdt_pairs = [
                    pair for pair in all_pairs 
                    if 'Quote' in pair and pair['Quote'].upper() == "USDT"
                ]
                # Create BTC pairs by replacing Quote field in USDT pairs
                quote_filtered_pairs = []
                for pair in usdt_pairs:
                    btc_pair = pair.copy()
                    btc_pair['Quote'] = 'BTC'
                    quote_filtered_pairs.append(btc_pair)
                print(f"Created {len(quote_filtered_pairs)} BTC pairs from USDT pairs")
            
            # Process all pairs with progress bar
            all_results = []
            with tqdm(total=len(quote_filtered_pairs), desc="Scanning markets") as pbar:
                for pair in quote_filtered_pairs:
                    try:
                        # Skip stable coins for BTC pairs (they likely don't have BTC pairs)
                        if self.quote_currency == "BTC" and pair['Token'].upper() in ['USDT', 'USDC', 'BUSD', 'DAI', 'TUSD']:
                            pbar.update(1)
                            continue
                            
                        # Skip certain tokens for BTC pairs (they likely don't have BTC pairs)
                        if self.quote_currency == "BTC" and len(pair['Token']) >= 10:
                            # Skip very long token names (likely newer tokens that won't have BTC pairs)
                            pbar.update(1)
                            continue
                        
                        # Get OHLCV data from SF service
                        try:
                            ohlcv_data = self.sf_service.get_ohlcv_for_pair(
                                pair['Token'], 
                                pair['Quote'], 
                                self.exchange, 
                                self.timeframe, 
                                100  # Get more data for confluence analysis
                            )
                        except Exception:
                            # If error, just skip this pair silently
                            pbar.update(1)
                            continue
                        
                        if ohlcv_data is None or len(ohlcv_data) == 0:
                            pbar.update(1)
                            continue
                        
                        df = pd.DataFrame(ohlcv_data)
                        
                        # Check if we have enough data
                        if len(df) >= 50:  # Need enough for confluence analysis
                            target_idx = -(self.offset + 1)  # Adjust index based on offset
                            
                            # Only display when we have enough data
                            pbar.set_description(f"Scanning: {pair['Token']}/{pair['Quote']} ({len(df)} candles)")
                            
                            # Check volume threshold for the target candle
                            try:
                                target_candle_volume = float(df['close'].iloc[target_idx]) * float(df['volume'].iloc[target_idx])
                                
                                # Only process if volume meets threshold
                                if target_candle_volume >= min_volume:
                                    result = self.scan_single_market(pair, ohlcv_data)
                                    if result:
                                        all_results.append(result)
                                        print(f"Found Confluence: {pair['Token']}/{pair['Quote']} 🎯")
                            except (IndexError, ValueError):
                                pass  # Skip if we can't calculate volume
                                    
                    except Exception:
                        pass  # Skip errors silently
                    finally:
                        pbar.update(1)
            
            # Sort by volume
            all_results.sort(key=lambda x: x['volume_quote'], reverse=True)
            
            # Send Telegram alert if we found any patterns
            if all_results:
                await self.send_telegram_alert(all_results)
            
            return all_results
            
        except Exception as e:
            logging.error(f"Error scanning markets: {str(e)}")
            return []

async def run_confluence_scanner(exchange, timeframe, quote_currency="USDT", offset=1):
    """
    Run the Confluence scanner
    
    Parameters:
    exchange (str): Exchange name (Kucoin, Mexc, Binance)
    timeframe (str): Time period (1d, 2d, 1w)
    quote_currency (str): Quote currency to scan (USDT or BTC)
    offset (int): Bar offset (0=current, 1=last closed, 2=two bars ago, etc.)
    """
    
    if offset == 0:
        offset_desc = "current candle"
    elif offset == 1:
        offset_desc = "last closed candle"
    else:
        offset_desc = f"{offset} candles ago"
    
    print(f"Starting Confluence scan for {offset_desc} on {exchange} {timeframe} ({quote_currency} pairs)...")
    
    # Use the confluence telegram token from your big project config
    # You should replace this with the actual token from utils/config.py TELEGRAM_TOKENS["confluence"]
    telegram_token = "8066329517:AAHVr6kufZWe8UqCKPfmsRhSPleNlt_7G-g"  # Replace with confluence token
    telegram_chat_id = "375812423"  # Your chat ID
    
    scanner = ConfluenceScanner(telegram_token, telegram_chat_id, exchange, timeframe, quote_currency, offset)
    results = await scanner.scan_all_markets()
    
    if results:
        print(f"\nFound {len(results)} Confluence patterns:")
        
        # Convert results to DataFrame for console display
        df_results = pd.DataFrame(results)
        
        # Determine decimals based on quote currency
        price_decimals = 8 if quote_currency == "BTC" else 4
        
        # Round numeric columns
        df_results['volume_quote'] = df_results['volume_quote'].round(2)
        df_results['close'] = df_results['close'].round(price_decimals)
        df_results['volume'] = df_results['volume'].round(2)
        df_results['volume_ratio'] = df_results['volume_ratio'].round(2)
        df_results['close_off_low'] = df_results['close_off_low'].round(1)
        df_results['momentum_score'] = df_results['momentum_score'].round(4)
        
        # Reorder columns for better display
        display_cols = ['symbol', 'close', 'volume_quote', 'volume_ratio', 'close_off_low', 
                       'momentum_score', 'high_volume', 'spread_breakout', 'momentum_breakout']
        available_cols = [col for col in display_cols if col in df_results.columns]
        
        # Display the results
        print(df_results[available_cols])
        
        # Show component analysis
        print(f"\n🔧 COMPONENT ANALYSIS:")
        vol_count = df_results['high_volume'].sum()
        spread_count = df_results['spread_breakout'].sum()
        momentum_count = df_results['momentum_breakout'].sum()
        
        print(f"High Volume signals: {vol_count}/{len(results)} ({vol_count/len(results)*100:.1f}%)")
        print(f"Spread Breakout signals: {spread_count}/{len(results)} ({spread_count/len(results)*100:.1f}%)")
        print(f"Momentum Breakout signals: {momentum_count}/{len(results)} ({momentum_count/len(results)*100:.1f}%)")
        
    else:
        print(f"\nNo Confluence patterns found in {offset_desc}")

# Set up logging
logging.basicConfig(level=logging.ERROR)

# Apply nest_asyncio to allow async operations in Jupyter
nest_asyncio.apply()

# Example usage functions
async def scan_current_confluence_usdt():
    """Scan current candle for confluence - USDT pairs"""
    await run_confluence_scanner("Kucoin", "1w", "USDT", offset=0)

async def scan_closed_confluence_usdt():
    """Scan last closed candle for confluence - USDT pairs"""
    await run_confluence_scanner("Kucoin", "1w", "USDT", offset=1)

async def scan_current_confluence_btc():
    """Scan current candle for confluence - BTC pairs"""
    await run_confluence_scanner("Kucoin", "1w", "BTC", offset=0)

async def scan_closed_confluence_btc():
    """Scan last closed candle for confluence - BTC pairs"""
    await run_confluence_scanner("Kucoin", "1w", "BTC", offset=1)

# Main execution function
async def main():
    """
    Main execution - modify parameters here
    """
    exchange = "Mexc"        # Binance, Kucoin, Mexc, Gateio
    timeframe = "1w"         # 1d, 2d, 1w
    quote_currency = "USDT"  # USDT or BTC
    offset = 1               # 0 = current candle, 1 = last closed candle, 2 = two candles ago
    
    await run_confluence_scanner(exchange, timeframe, quote_currency, offset)

# Run the async main function
print("🔍 CONFLUENCE SCANNER WITH QUOTE CURRENCY OPTIONS")
print("=" * 50)
print("Available functions:")
print("• await main() - Run with default settings")
print("• await scan_current_confluence_usdt() - Scan current candle (USDT)")
print("• await scan_closed_confluence_usdt() - Scan last closed candle (USDT)")
print("• await scan_current_confluence_btc() - Scan current candle (BTC)")
print("• await scan_closed_confluence_btc() - Scan last closed candle (BTC)")
print("• await run_confluence_scanner('Exchange', 'timeframe', 'quote_currency', offset) - Custom scan")
print("\nExample: await run_confluence_scanner('Mexc', '1w', 'BTC', 1)")

# Uncomment to auto-run:
await main()
# Out:
# 🔍 CONFLUENCE SCANNER WITH QUOTE CURRENCY OPTIONS
# ==================================================
# Available functions:
# • await main() - Run with default settings
# • await scan_current_confluence_usdt() - Scan current candle (USDT)
# • await scan_closed_confluence_usdt() - Scan last closed candle (USDT)
# • await scan_current_confluence_btc() - Scan current candle (BTC)
# • await scan_closed_confluence_btc() - Scan last closed candle (BTC)
# • await run_confluence_scanner('Exchange', 'timeframe', 'quote_currency', offset) - Custom scan
#
# Example: await run_confluence_scanner('Mexc', '1w', 'BTC', 1)
# Starting Confluence scan for last closed candle on Mexc 1w (USDT pairs)...
# Scanning for Confluence patterns in last closed candle...
# Quote currency: USDT
# Minimum volume threshold: $300,000.00
# Fetching pairs from Mexc...
# Fetching pairs for exchange: Mexc
# Found 1669 USDT pairs to scan
# Scanning: NEXM/USDT (75 candles):   4% 73/1669 [00:04<02:08, 12.46it/s]
# Found Confluence: DCB/USDT 🎯
# Scanning: HYPC/USDT (101 candles):  15% 246/1669 [00:15<01:44, 13.66it/s]
# Found Confluence: VISTA/USDT 🎯
# Scanning: VIA/USDT (78 candles):  15% 258/1669 [00:17<02:13, 10.60it/s]
# Found Confluence: PKR/USDT 🎯
# Scanning: DEXTF/USDT (101 candles):  24% 400/1669 [00:27<01:29, 14.16it/s]
# Found Confluence: DEXTF/USDT 🎯
# Scanning: KALIS/USDT (74 candles):  24% 407/1669 [00:28<01:38, 12.80it/s]
# Found Confluence: LNQ/USDT 🎯
# Scanning: WRKX/USDT (94 candles):  25% 412/1669 [00:28<01:58, 10.58it/s]
# Found Confluence: DDMT/USDT 🎯
# Scanning: PNK/USDT (101 candles):  31% 516/1669 [00:37<01:43, 11.12it/s]
# Found Confluence: UBX/USDT 🎯
# Scanning: SWAP/USDT (101 candles):  40% 674/1669 [00:49<01:11, 13.99it/s]
# Error 500:
# Scanning: UNP/USDT (82 candles):  42% 703/1669 [00:51<01:46,  9.05it/s]
# Found Confluence: APEX/USDT 🎯
# Scanning: HKTM/USDT (53 candles):  44% 731/1669 [00:54<01:20, 11.60it/s]
# Found Confluence: SNEK/USDT 🎯
# Scanning: OG/USDT (101 candles):  45% 756/1669 [00:56<01:20, 11.36it/s]
# Found Confluence: AUKI/USDT 🎯
# Found Confluence: OG/USDT 🎯
# Scanning: ATRS/USDT (50 candles):  48% 807/1669 [01:00<01:17, 11.19it/s]
# Found Confluence: MBD/USDT 🎯
# Scanning: SXCH/USDT (64 candles):  51% 856/1669 [01:04<01:08, 11.93it/s]
# Found Confluence: PORTO/USDT 🎯
# Scanning: NEXA/USDT (101 candles):  52% 875/1669 [01:06<01:01, 12.99it/s]
# Found Confluence: ITGR/USDT 🎯
# Scanning: HANDY/USDT (101 candles):  53% 885/1669 [01:07<01:11, 10.90it/s]
# Found Confluence: SMX/USDT 🎯
# Scanning: FOR/USDT (101 candles):  54% 901/1669 [01:08<01:11, 10.73it/s]
# Found Confluence: ALVA/USDT 🎯
# Scanning: MOTHER/USDT (64 candles):  62% 1043/1669 [01:21<00:56, 11.16it/s]
# Found Confluence: MAS/USDT 🎯
# Scanning: JUNO/USDT (101 candles):  65% 1079/1669 [01:25<00:56, 10.51it/s]
# Found Confluence: SIX/USDT 🎯
# Scanning: 5IRE/USDT (86 candles):  67% 1119/1669 [01:28<00:38, 14.32it/s]
# Error 500:
# Scanning: EL/USDT (101 candles):  72% 1196/1669 [01:35<00:56,  8.34it/s]
# Found Confluence: JUSTICE/USDT 🎯
# Scanning: BICITY/USDT (62 candles):  72% 1210/1669 [01:36<00:39, 11.73it/s]
# Found Confluence: CAW/USDT 🎯
# Scanning: SHARKCAT/USDT (63 candles):  75% 1245/1669 [01:38<00:30, 14.03it/s]
# Found Confluence: TAONU/USDT 🎯
# Scanning: WSM/USDT (99 candles):  79% 1320/1669 [01:44<00:22, 15.47it/s]
# Found Confluence: DEAI/USDT 🎯
# Scanning: K21/USDT (101 candles):  91% 1523/1669 [02:01<00:14,  9.86it/s]
# Found Confluence: DSYNC/USDT 🎯
# Scanning: ORT/USDT (101 candles):  93% 1553/1669 [02:03<00:08, 13.57it/s]
# Found Confluence: CITY/USDT 🎯
# Scanning: METO/USDT (101 candles):  96% 1595/1669 [02:07<00:06, 11.43it/s]
# Found Confluence: PROPS/USDT 🎯
# Scanning: WWY/USDT (101 candles): : 1674it [02:13, 12.52it/s]
# HTTP Request: POST https://api.telegram.org/bot8066329517:AAHVr6kufZWe8UqCKPfmsRhSPleNlt_7G-g/sendMessage "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.telegram.org/bot8066329517:AAHVr6kufZWe8UqCKPfmsRhSPleNlt_7G-g/sendMessage "HTTP/1.1 200 OK"
# Found 25 Confluence patterns:
#          symbol    close  volume_quote  volume_ratio  close_off_low  \
# 0        OGUSDT  12.5520   53936377.92          2.63           70.5
# 1     DSYNCUSDT   0.1501   17833325.21          2.25           71.2
# 2     PROPSUSDT   0.0343    9136369.38          0.85           72.5
# 3      CITYUSDT   1.2006    8346011.19          1.69           75.3
# 4     PORTOUSDT   1.0576    4139855.45          2.00           70.5
# 5      DDMTUSDT   0.1338    2999383.71          0.94           99.4
# 6      ALVAUSDT   0.2593    1574609.02          0.91           75.5
# 7      DEAIUSDT   0.0778    1401766.89          1.15           84.4
# 8      SNEKUSDT   0.0044    1268968.43          0.65           77.0
# 9       CAWUSDT   0.0000    1129642.45          0.88           79.6
# 10    DEXTFUSDT   0.1602    1002163.47          1.00           81.4
# 11    VISTAUSDT   8.6050     893260.96          0.66           88.7
# 12      UBXUSDT   0.0000     794220.30          1.09           91.8
# 13      LNQUSDT   0.0428     775906.34          0.90           93.8
# 14      DCBUSDT   0.0122     734048.92          1.24           82.9
# 15      MBDUSDT   0.0000     718755.27          1.31           91.1
# 16     APEXUSDT   0.3601     619019.80          0.61           78.4
# 17     ITGRUSDT   0.0049     517808.27          1.22           91.9
# 18      PKRUSDT   0.0013     514084.80          1.58           90.7
# 19    TAONUUSDT   0.0019     501510.13          1.57           70.7
# 20  JUSTICEUSDT   0.0001     448800.07          0.90           92.7
# 21      SIXUSDT   0.0272     439207.19          0.38           70.3
# 22     AUKIUSDT   0.0140     436628.86          1.35           72.0
# 23      SMXUSDT   0.0015     404533.34          1.29           75.5
# 24      MASUSDT   0.0166     391380.95          0.99           97.6
#
#     momentum_score  high_volume  spread_breakout  momentum_breakout
# 0           0.2493         True             True               True
# 1           0.1486         True             True               True
# 2           0.2246         True             True               True
# 3           0.2467         True             True               True
# 4           0.1658         True             True               True
# 5           1.3192         True             True               True
# 6           0.2612         True             True               True
# 7           0.2202         True             True               True
# 8           0.1555         True             True               True
# 9           0.2842         True             True               True
# 10          0.2223         True             True               True
# 11          0.4205         True             True               True
# 12          1.0520         True             True               True
# 13          0.5024         True             True               True
# 14          0.5070         True             True               True
# 15          1.0585         True             True               True
# 16          0.3223         True             True               True
# 17          1.1717         True             True               True
# 18          0.8495         True             True               True
# 19          0.0552         True             True               True
# 20          0.8653         True             True               True
# 21          0.1888         True             True               True
# 22          0.1438         True             True               True
# 23          0.0438         True             True               True
# 24          1.4470         True             True               True
#
# 🔧 COMPONENT ANALYSIS:
# High Volume signals: 25/25 (100.0%)
# Spread Breakout signals: 25/25 (100.0%)
# Momentum Breakout signals: 25/25 (100.0%)

# %%
# Binance BTC dominated pairs - Confluence Scanner with Direct API

from telegram.ext import Application
import logging
import pandas as pd
import numpy as np
import asyncio
import nest_asyncio
from datetime import datetime
from tqdm.asyncio import tqdm
import sys
import os
import html
import aiohttp
import time

# Add project path
project_dir = os.path.join(os.getcwd(), "Project")
sys.path.insert(0, project_dir)

from custom_strategies import detect_confluence

class BinanceBTCConfluenceScanner:
    def __init__(self, telegram_token, telegram_chat_id, timeframe, offset=1):
        self.telegram_token = telegram_token
        self.telegram_chat_id = telegram_chat_id
        self.telegram_app = None
        self.exchange = "Binance"
        self.timeframe = timeframe
        self.quote_currency = "BTC"
        self.offset = offset
        self.base_url = "https://api.binance.com"
        self.session = None
        
        # Binance timeframe mapping - All available intervals
        self.timeframe_map = {
            # Minutes
            "1m": "1m",
            "3m": "3m", 
            "5m": "5m",
            "15m": "15m",
            "30m": "30m",
            # Hours
            "1h": "1h",
            "2h": "2h",
            "4h": "4h",
            "6h": "6h",
            "8h": "8h",
            "12h": "12h",
            # Days
            "1d": "1d",
            "2d": "2d",
            "3d": "3d",
            # Weeks/Months
            "1w": "1w",
            "1M": "1M"
        }
        
    async def init_session(self):
        """Initialize aiohttp session"""
        if self.session is None:
            self.session = aiohttp.ClientSession()
            
    async def close_session(self):
        """Close aiohttp session"""
        if self.session:
            await self.session.close()
            self.session = None
        
    async def init_telegram(self):
        if self.telegram_app is None:
            self.telegram_app = Application.builder().token(self.telegram_token).build()

    async def get_btc_pairs(self):
        """Get all BTC trading pairs from Binance"""
        await self.init_session()
        
        try:
            url = f"{self.base_url}/api/v3/exchangeInfo"
            async with self.session.get(url) as response:
                if response.status == 200:
                    data = await response.json()
                    
                    # Filter for BTC pairs that are actively trading
                    btc_pairs = []
                    for symbol_info in data['symbols']:
                        if (symbol_info['quoteAsset'] == 'BTC' and 
                            symbol_info['status'] == 'TRADING' and
                            symbol_info['isSpotTradingAllowed']):
                            
                            btc_pairs.append({
                                'symbol': symbol_info['symbol'],
                                'baseAsset': symbol_info['baseAsset'],
                                'quoteAsset': symbol_info['quoteAsset']
                            })
                    
                    return btc_pairs
                else:
                    logging.error(f"Error fetching exchange info: {response.status}")
                    return []
        except Exception as e:
            logging.error(f"Error fetching BTC pairs: {str(e)}")
            return []

    async def get_klines(self, symbol, interval, limit=100):
        """Get kline/candlestick data from Binance"""
        await self.init_session()
        
        try:
            url = f"{self.base_url}/api/v3/klines"
            params = {
                'symbol': symbol,
                'interval': interval,
                'limit': limit
            }
            
            async with self.session.get(url, params=params) as response:
                if response.status == 200:
                    data = await response.json()
                    
                    # Convert to DataFrame
                    df = pd.DataFrame(data, columns=[
                        'open_time', 'open', 'high', 'low', 'close', 'volume',
                        'close_time', 'quote_asset_volume', 'number_of_trades',
                        'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore'
                    ])
                    
                    # Convert timestamps to datetime
                    df['open_time'] = pd.to_datetime(df['open_time'], unit='ms')
                    df['close_time'] = pd.to_datetime(df['close_time'], unit='ms')
                    
                    # Convert OHLCV to numeric
                    for col in ['open', 'high', 'low', 'close', 'volume', 'quote_asset_volume']:
                        df[col] = pd.to_numeric(df[col], errors='coerce')
                    
                    # Set datetime index
                    df.set_index('open_time', inplace=True)
                    
                    # Select only OHLCV columns needed for confluence
                    # Note: Using quote_asset_volume as it's the volume in BTC
                    result_df = df[['open', 'high', 'low', 'close', 'quote_asset_volume']].copy()
                    result_df.rename(columns={'quote_asset_volume': 'volume'}, inplace=True)
                    
                    return result_df
                    
                elif response.status == 429:
                    # Rate limit hit, wait a bit
                    await asyncio.sleep(1)
                    return None
                else:
                    return None
                    
        except Exception as e:
            logging.error(f"Error fetching klines for {symbol}: {str(e)}")
            return None

    async def send_telegram_alert(self, results):
        if not results:
            return
            
        try:
            message = f"🚨 Confluence Detection - Binance BTC Pairs {self.timeframe}\n\n"
            
            # Map timeframe to TradingView format - Extended mapping
            tv_timeframe_map = {
                # Minutes
                "1m": "1", "3m": "3", "5m": "5", "15m": "15", "30m": "30",
                # Hours  
                "1h": "60", "2h": "120", "4h": "240", "6h": "360", "8h": "480", "12h": "720",
                # Days
                "1d": "1D", "2d": "2D", "3d": "3D",
                # Weeks/Months
                "1w": "1W", "1M": "1M"
            }
            tv_timeframe = tv_timeframe_map.get(self.timeframe.lower(), self.timeframe)
            
            for result in results:
                formatted_symbol = result['symbol']
                tv_link = f"https://www.tradingview.com/chart/?symbol=BINANCE:{formatted_symbol}&interval={tv_timeframe}"
                
                # Escape HTML entities in the URL
                escaped_link = html.escape(tv_link)
                
                # Format according to BTC specifications
                time_str = ""
                if result.get('timestamp') is not None:
                    time_str = f"Time: {result['timestamp'].strftime('%Y-%m-%d %H:%M:%S')}\n"
                
                message += (
                    f"Symbol: {result['symbol']}\n"
                    f"{time_str}"
                    f"Volume BTC: ₿{result['volume_btc']:,.4f}\n"
                    f"Close: <a href='{escaped_link}'>₿{result['close']:.8f}</a>\n"
                    f"Volume Ratio: {result['volume_ratio']:.2f}x\n"
                    f"Close Off Low: {result['close_off_low']:.1f}%\n"
                    f"Momentum: {result['momentum_score']:.4f}\n"
                    f"{'='*30}\n"
                )
            
            # Split message more carefully to avoid breaking HTML tags
            max_length = 4000
            
            if len(message) > max_length:
                # Split at natural breaks (between results) to avoid breaking HTML
                sections = message.split('='*30 + '\n')
                current_chunk = ""
                
                for section in sections:
                    if len(current_chunk + section + '='*30 + '\n') > max_length:
                        if current_chunk:
                            await self.telegram_app.bot.send_message(
                                chat_id=self.telegram_chat_id,
                                text=current_chunk.strip(),
                                parse_mode='HTML',
                                disable_web_page_preview=True
                            )
                        current_chunk = section + '\n'
                    else:
                        current_chunk += section + '='*30 + '\n'
                
                # Send remaining chunk
                if current_chunk.strip():
                    await self.telegram_app.bot.send_message(
                        chat_id=self.telegram_chat_id,
                        text=current_chunk.strip(),
                        parse_mode='HTML',
                        disable_web_page_preview=True
                    )
            else:
                await self.telegram_app.bot.send_message(
                    chat_id=self.telegram_chat_id,
                    text=message,
                    parse_mode='HTML',
                    disable_web_page_preview=True
                )
                
        except Exception as e:
            logging.error(f"Error sending Telegram alert: {str(e)}")
            
            # Fallback: send without HTML formatting
            try:
                simple_message = f"🚨 Confluence Detection - Binance BTC Pairs {self.timeframe}\n\n"
                for result in results:
                    simple_message += (
                        f"Symbol: {result['symbol']}\n"
                        f"Volume BTC: ₿{result['volume_btc']:,.4f}\n"
                        f"Close: ₿{result['close']:.8f}\n"
                        f"Volume Ratio: {result['volume_ratio']:.2f}x\n"
                        f"Components: Vol={result['high_volume']}, Spread={result['spread_breakout']}, Mom={result['momentum_breakout']}\n\n"
                    )
                
                await self.telegram_app.bot.send_message(
                    chat_id=self.telegram_chat_id,
                    text=simple_message,
                    disable_web_page_preview=True
                )
            except Exception as fallback_error:
                logging.error(f"Fallback Telegram send also failed: {str(fallback_error)}")

    def scan_single_market(self, pair, df):
        """Scan a single market for Confluence pattern in the specified bar"""
        try:
            if df is None or len(df) < 50:  # Need enough data for confluence
                return None
            
            # Calculate which bar to check based on offset
            check_bar = -(self.offset + 1)  # offset=0 means current bar (-1), offset=1 means last closed (-2), etc.
            
            # Run confluence detection
            detected, result = detect_confluence(df, check_bar=check_bar)
            
            if detected:
                # Get the target bar values
                target_close = df['close'].iloc[check_bar]
                target_volume = df['volume'].iloc[check_bar]  # This is already in BTC
                
                confluence_result = {
                    'symbol': pair['symbol'],
                    'volume_btc': float(target_volume),
                    'close': float(target_close),
                    'volume': float(target_volume),
                    'volume_ratio': result['volume_ratio'],
                    'close_off_low': result['close_off_low'],
                    'momentum_score': result['momentum_score'],
                    'high_volume': result['high_volume'],
                    'spread_breakout': result['spread_breakout'],
                    'momentum_breakout': result['momentum_breakout'],
                    'bar_range': result['bar_range'],
                    'timestamp': df.index[check_bar] if hasattr(df.index, '__getitem__') else None
                }
                return confluence_result
                
        except Exception as e:
            logging.error(f"Error processing {pair['symbol']}: {str(e)}")
        return None

    async def scan_all_markets(self):
        """Scan all BTC markets for Confluence pattern"""
        await self.init_telegram()
        
        try:
            # Define volume thresholds for BTC pairs based on timeframe
            volume_thresholds = {
                # Minutes - higher volume needed for shorter timeframes
                "1m": 0.01,   "3m": 0.02,   "5m": 0.03,
                "15m": 0.05,  "30m": 0.08,
                # Hours
                "1h": 0.1,    "2h": 0.15,   "4h": 0.2,
                "6h": 0.25,   "8h": 0.3,    "12h": 0.35,
                # Days
                "1d": 0.4,    "2d": 0.8,    "3d": 1.2,
                # Weeks/Months
                "1w": 2.0,    "1M": 8.0
            }
            min_volume = volume_thresholds.get(self.timeframe.lower(), 0.1)  # Default 0.1 BTC
            
            # Create offset description
            if self.offset == 0:
                offset_desc = "current candle"
            elif self.offset == 1:
                offset_desc = "last closed candle"
            else:
                offset_desc = f"{self.offset} candles ago"
            
            print(f"Scanning Binance BTC pairs for Confluence patterns in {offset_desc}...")
            print(f"Timeframe: {self.timeframe}")
            print(f"Minimum volume threshold: ₿{min_volume:.2f}")
            
            # Get all BTC pairs from Binance
            print("Fetching BTC pairs from Binance...")
            btc_pairs = await self.get_btc_pairs()
            
            if not btc_pairs:
                print("No BTC pairs found or error fetching pairs")
                return []
            
            print(f"Found {len(btc_pairs)} BTC pairs to scan")
            
            # Filter out stablecoins and obvious non-trading pairs
            filtered_pairs = []
            skip_tokens = ['USDT', 'USDC', 'BUSD', 'DAI', 'TUSD', 'USDD', 'FDUSD']
            
            for pair in btc_pairs:
                if pair['baseAsset'] not in skip_tokens:
                    filtered_pairs.append(pair)
            
            print(f"After filtering: {len(filtered_pairs)} pairs to scan")
            
            # Get Binance timeframe - fallback to 1d if not found
            binance_interval = self.timeframe_map.get(self.timeframe.lower(), "1d")
            
            # Process all pairs with progress bar
            all_results = []
            successful_scans = 0
            
            with tqdm(total=len(filtered_pairs), desc="Scanning markets") as pbar:
                for pair in filtered_pairs:
                    try:
                        # Get OHLCV data from Binance
                        df = await self.get_klines(pair['symbol'], binance_interval, 100)
                        
                        if df is None or len(df) < 50:
                            pbar.update(1)
                            continue
                        
                        successful_scans += 1
                        target_idx = -(self.offset + 1)
                        
                        # Update progress bar with current symbol
                        pbar.set_description(f"Scanning: {pair['symbol']} ({len(df)} candles)")
                        
                        # Check volume threshold for the target candle
                        try:
                            target_candle_volume = float(df['volume'].iloc[target_idx])  # Already in BTC
                            
                            # Only process if volume meets threshold
                            if target_candle_volume >= min_volume:
                                result = self.scan_single_market(pair, df)
                                if result:
                                    all_results.append(result)
                                    print(f"Found Confluence: {pair['symbol']} 🎯")
                        except (IndexError, ValueError):
                            pass  # Skip if we can't calculate volume
                        
                        # Add small delay to respect rate limits
                        await asyncio.sleep(0.1)
                                
                    except Exception as e:
                        if "429" in str(e):
                            # Rate limit - add longer delay
                            await asyncio.sleep(2)
                    finally:
                        pbar.update(1)
            
            print(f"Successfully scanned {successful_scans}/{len(filtered_pairs)} pairs")
            
            # Sort by volume
            all_results.sort(key=lambda x: x['volume_btc'], reverse=True)
            
            # Send Telegram alert if we found any patterns
            if all_results:
                await self.send_telegram_alert(all_results)
            
            return all_results
            
        except Exception as e:
            logging.error(f"Error scanning markets: {str(e)}")
            return []
        finally:
            await self.close_session()

async def run_binance_btc_confluence_scanner(timeframe, offset=1):
    """
    Run the Binance BTC Confluence scanner
    
    Parameters:
    timeframe (str): Time period - Available options:
                    Minutes: 1m, 3m, 5m, 15m, 30m
                    Hours: 1h, 2h, 4h, 6h, 8h, 12h  
                    Days: 1d, 2d, 3d
                    Weeks/Months: 1w, 1M
    offset (int): Bar offset (0=current, 1=last closed, 2=two bars ago, etc.)
    """
    
    if offset == 0:
        offset_desc = "current candle"
    elif offset == 1:
        offset_desc = "last closed candle"
    else:
        offset_desc = f"{offset} candles ago"
    
    print(f"Starting Binance BTC Confluence scan for {offset_desc} on {timeframe}...")
    
    # Use the confluence telegram token
    telegram_token = "8066329517:AAHVr6kufZWe8UqCKPfmsRhSPleNlt_7G-g"
    telegram_chat_id = "375812423"
    
    scanner = BinanceBTCConfluenceScanner(telegram_token, telegram_chat_id, timeframe, offset)
    results = await scanner.scan_all_markets()
    
    if results:
        print(f"\nFound {len(results)} Confluence patterns:")
        
        # Convert results to DataFrame for console display
        df_results = pd.DataFrame(results)
        
        # Round numeric columns for BTC precision
        df_results['volume_btc'] = df_results['volume_btc'].round(4)
        df_results['close'] = df_results['close'].round(8)
        df_results['volume'] = df_results['volume'].round(4)
        df_results['volume_ratio'] = df_results['volume_ratio'].round(2)
        df_results['close_off_low'] = df_results['close_off_low'].round(1)
        df_results['momentum_score'] = df_results['momentum_score'].round(4)
        
        # Reorder columns for better display
        display_cols = ['symbol', 'close', 'volume_btc', 'volume_ratio', 'close_off_low', 
                       'momentum_score', 'high_volume', 'spread_breakout', 'momentum_breakout']
        available_cols = [col for col in display_cols if col in df_results.columns]
        
        # Display the results
        print(df_results[available_cols])
        
        # Show component analysis
        print(f"\n🔧 COMPONENT ANALYSIS:")
        vol_count = df_results['high_volume'].sum()
        spread_count = df_results['spread_breakout'].sum()
        momentum_count = df_results['momentum_breakout'].sum()
        
        print(f"High Volume signals: {vol_count}/{len(results)} ({vol_count/len(results)*100:.1f}%)")
        print(f"Spread Breakout signals: {spread_count}/{len(results)} ({spread_count/len(results)*100:.1f}%)")
        print(f"Momentum Breakout signals: {momentum_count}/{len(results)} ({momentum_count/len(results)*100:.1f}%)")
        
    else:
        print(f"\nNo Confluence patterns found in {offset_desc}")

# Set up logging
logging.basicConfig(level=logging.ERROR)

# Apply nest_asyncio to allow async operations in Jupyter
nest_asyncio.apply()

# Example usage functions
async def scan_binance_btc_current():
    """Scan current candle for confluence - Binance BTC pairs"""
    await run_binance_btc_confluence_scanner("1w", offset=0)

async def scan_binance_btc_closed():
    """Scan last closed candle for confluence - Binance BTC pairs"""
    await run_binance_btc_confluence_scanner("1w", offset=1)

async def scan_binance_btc_previous():
    """Scan two candles ago for confluence - Binance BTC pairs"""
    await run_binance_btc_confluence_scanner("1w", offset=2)

# Main execution function
async def main():
    """
    Main execution - modify parameters here
    """
    timeframe = "1w"  # 1d, 2d, 3d, 1w
    offset = 0        # 0 = current candle, 1 = last closed candle, 2 = two candles ago
    
    await run_binance_btc_confluence_scanner(timeframe, offset)

# Run the async main function
print("🔍 BINANCE BTC CONFLUENCE SCANNER")
print("=" * 40)
print("Available timeframes:")
print("• Minutes: 1m, 3m, 5m, 15m, 30m")
print("• Hours: 1h, 2h, 4h, 6h, 8h, 12h") 
print("• Days: 1d, 2d, 3d")
print("• Weeks/Months: 1w, 1M")
print("\nAvailable functions:")
print("• await main() - Run with default settings")
print("• await scan_binance_btc_current() - Scan current candle")
print("• await scan_binance_btc_closed() - Scan last closed candle")
print("• await scan_binance_btc_previous() - Scan two candles ago")
print("• await run_binance_btc_confluence_scanner('timeframe', offset) - Custom scan")
print("\nExamples:")
print("• await run_binance_btc_confluence_scanner('4h', 1)  # 4-hour last closed")
print("• await run_binance_btc_confluence_scanner('15m', 0) # 15-min current")
print("• await run_binance_btc_confluence_scanner('1M', 1)  # Monthly last closed")
print("This scanner uses REAL Binance BTC pair volumes!")

# Uncomment to auto-run:
await main()

# %%
# Debug ohlcv data of any pair

import asyncio
import sys
import os
import logging
import pandas as pd

logging.basicConfig(level=logging.INFO, format='%(message)s')

project_dir = os.path.join(os.getcwd(), "Project")
sys.path.insert(0, project_dir)
print(f"✓ Added {project_dir} to sys.path")

from exchanges import BybitFuturesClient  # Ensure this matches your exchanges/__init__.py

async def test_fetch():
    client = BybitFuturesClient(timeframe="2d")
    await client.init_session()
    df = await client.fetch_klines("L3USDT")
    await client.close_session()
    if df is not None:
        print("2d Candles for L3:")
        print(df.tail(5))  # Last 5 weeks
        last_row = df.iloc[-1]
        volume_usd = last_row['volume'] * last_row['close']
        print(f"Last Week: volume_usd={volume_usd:.2f}, close={last_row['close']}, volume={last_row['volume']:.2f}")

# Run the async function directly in the notebook
await test_fetch()

# %%
#Direct strategy debug of any pair on any exchange
import asyncio
import sys
import os
import logging
import pandas as pd
import numpy as np
logging.basicConfig(level=logging.DEBUG, format='%(levelname)s: %(message)s')
project_dir = os.path.join(os.getcwd(), "Project")
sys.path.insert(0, project_dir)
print(f"✓ Added {project_dir} to sys.path")
from exchanges import MexcSpotClient, BybitSpotClient, GateioSpotClient, KucoinSpotClient, BinanceSpotClient, BinanceFuturesClient, BybitFuturesClient
from custom_strategies import detect_volume_surge, detect_weak_uptrend, detect_pin_down
from breakout_vsa import vsa_detector, breakout_bar_vsa, stop_bar_vsa, reversal_bar_vsa, start_bar_vsa, loaded_bar_vsa, test_bar_vsa

async def test_strategy(exchange_client_class, timeframe, symbol, strategy_name):
    client = exchange_client_class(timeframe=timeframe)
    await client.init_session()
    df = await client.fetch_klines(symbol)
    await client.close_session()
    
    if df is None or len(df) < 10:
        print(f"No data fetched for {symbol} or insufficient data (< 10 bars)")
        return
    
    print(f"{timeframe} Candles for {symbol}:")
    print(df.tail(5))
    last_row = df.iloc[-1]
    volume_usd = last_row['volume'] * last_row['close']
    print(f"Last Bar: volume_usd={volume_usd:.2f}, close={last_row['close']}, volume={last_row['volume']:.2f}")
    
    # Different handling based on strategy type
    if strategy_name == "volume_surge":
        # Use detect_volume_surge directly
        detected, result = detect_volume_surge(df)
        
        print(f"\nVolume Surge Detection Results:")
        print(f"Detected: {detected}")
        
        if detected:
            print(f"\nVolume Surge Details:")
            print(f"  Date: {result['timestamp']}")
            print(f"  Close: ${result['close_price']:,.8f}")
            print(f"  Volume: {result['volume']:,.2f}")
            print(f"  Volume USD: ${result['volume_usd']:,.2f}")
            print(f"  Volume Ratio: {result['volume_ratio']:,.2f}x")
            print(f"  Score: {result['score']:,.2f}")
            print(f"  Price Extreme: {result['price_extreme']}")
    
    elif strategy_name == "pin_down":
        from custom_strategies import detect_pin_down
        detected, result = detect_pin_down(df)
        
        print(f"\nPin Down Detection Results:")
        print(f"Detected: {detected}")
        
        if detected:
            print(f"\nPin Down Details:")
            for key, value in result.items():
                if key != 'symbol':  # Skip symbol as we already know it
                    print(f"  {key}: {value}")
    
    elif strategy_name == "weak_uptrend":
        from custom_strategies import detect_weak_uptrend
        detected, result = detect_weak_uptrend(df)
        
        print(f"\nWeak Uptrend Detection Results:")
        print(f"Detected: {detected}")
        
        if detected:
            print(f"\nWeak Uptrend Details:")
            for key, value in result.items():
                if key != 'symbol':  # Skip symbol as we already know it
                    print(f"  {key}: {value}")
    
    else:
        # For VSA strategies, import the appropriate get_params
        if strategy_name == "reversal_bar":
            from breakout_vsa.strategies.reversal_bar import get_params
        elif strategy_name == "breakout_bar":
            from breakout_vsa.strategies.breakout_bar import get_params
        elif strategy_name == "loaded_bar":
            from breakout_vsa.strategies.loaded_bar import get_params
        elif strategy_name == "stop_bar":
            from breakout_vsa.strategies.stop_bar import get_params
        elif strategy_name == "start_bar":
            from breakout_vsa.strategies.start_bar import get_params
        else:
            print(f"Unknown strategy: {strategy_name}")
            return
        
        # Use vsa_detector with strategy-specific params
        params = get_params()
        condition, result = vsa_detector(df, params)
        
        strategy_display_name = strategy_name.replace('_vsa', '').replace('_', ' ').title()
        print(f"\n{strategy_display_name} Detection Results:")
        print(f"Current Bar (index -1): {condition.iloc[-1]}")
        if len(df) > 1:
            print(f"Last Closed Bar (index -2): {condition.iloc[-2]}")
        
        if condition.iloc[-1] or (len(df) > 1 and condition.iloc[-2]):
            detected_idx = -1 if condition.iloc[-1] else -2
            volume_mean = df['volume'].rolling(7).mean().iloc[detected_idx]
            bar_range = df['high'].iloc[detected_idx] - df['low'].iloc[detected_idx]
            close_off_low = (df['close'].iloc[detected_idx] - df['low'].iloc[detected_idx]) / bar_range * 100 if bar_range > 0 else 0
            volume_usd_detected = df['volume'].iloc[detected_idx] * df['close'].iloc[detected_idx]
            
            arctan_ratio = result['arctan_ratio'].iloc[detected_idx]  # From result DataFrame
            
            print(f"\nDetected at index {detected_idx} ({'Current' if detected_idx == -1 else 'Last Closed'} Bar):")
            print(f"  Date: {df.index[detected_idx]}")
            print(f"  Close: ${df['close'].iloc[detected_idx]:,.8f}")
            print(f"  Volume Ratio: {df['volume'].iloc[detected_idx] / volume_mean if volume_mean > 0 else 0:.2f}x")
            print(f"  {timeframe} Volume: ${volume_usd_detected:.2f}")
            print(f"  Close Off Low: {close_off_low:.1f}%")
            print(f"  Angular Ratio: {arctan_ratio:.2f}")

# Define the test case
exchange_client = GateioSpotClient
timeframe = "1w"
symbol = "PRCL_USDT"
strategy = "loaded_bar"
await test_strategy(exchange_client, timeframe, symbol, strategy)

# %%
#zip the project

import shutil
import os

# Go to parent directory of your project
os.chdir("/home/jovyan/work/Crypto/sevenfigures-bot/hbs_2025")

# Create the zip file (this will include everything inside 'hbs_2025')
shutil.make_archive("Project_VSA_2025_backup", 'zip', "Project")

# %%
#!/usr/bin/env python3 -> Debug built weekly candles for mexc and kucoin 
import sys
import os
project_dir = os.path.join(os.getcwd(), "Project")
sys.path.insert(0, project_dir)
print(f"✓ Added {project_dir} to sys.path")
import asyncio
import logging
import pandas as pd
import numpy as np
from exchanges.kucoin_client import KucoinClient
from breakout_vsa.core import calculate_start_bar

from scanner.main import kline_cache
kline_cache.clear()  # Clear cache for fresh data

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s: %(message)s')

async def debug_start_bar_detection():
    # Initialize client
    client = KucoinClient(timeframe="1w")
    await client.init_session()
    
    # Symbol to debug
    symbol = "TAO-USDT"
    
    try:
        # Fetch data
        df = await client.fetch_klines(symbol)
        
        if df is not None:
            print(f"Weekly candles for {symbol}:")
            print(df.tail())
            
            # Add intermediate calculations to see what's happening
            # This is a modified version of calculate_start_bar that adds debugging
            lookback = 5
            volume_lookback = 30
            volume_percentile = 50
            low_percentile = 75
            range_percentile = 75
            close_off_lows_percent = 50
            prev_close_range = 75
            
            # Calculate basic bar characteristics
            df['bar_range'] = df['high'] - df['low']
            df['volume_rank'] = df['volume'].rolling(lookback).apply(
                lambda x: sum(1.0 for val in x if val <= x[-1]) / len(x) * 100, 
                raw=True
            )
            
            # Calculate rolling values
            df['macro_low'] = df['low'].rolling(volume_lookback).min()
            df['macro_high'] = df['high'].rolling(volume_lookback).max()
            df['highest_high'] = df['high'].rolling(lookback).max()
            
            # Volume conditions
            df['volume_sma'] = df['volume'].rolling(volume_lookback).mean()
            df['volume_std'] = df['volume'].rolling(volume_lookback).std()
            df['excess_volume'] = df['volume'] > (df['volume_sma'] + 3.0 * df['volume_std'])
            
            # Range conditions
            df['range_sma'] = df['bar_range'].rolling(volume_lookback).mean()
            df['range_std'] = df['bar_range'].rolling(volume_lookback).std()
            df['excess_range'] = df['bar_range'] > (df['range_sma'] + 3.0 * df['range_std'])
            
            # Volume percentile condition
            def is_in_top_percent(series, length, percent):
                ranks = series.rolling(length).apply(
                    lambda x: sum(1.0 for val in x if val <= x[-1]) / len(x) * 100, 
                    raw=True
                )
                return ranks >= percent
            
            def is_in_bottom_percent(series, length, percent):
                ranks = series.rolling(length).apply(
                    lambda x: sum(1.0 for val in x if val <= x[-1]) / len(x) * 100, 
                    raw=True
                )
                return ranks <= percent
            
            # Volume conditions
            df['is_higher_volume'] = is_in_top_percent(df['volume'], lookback, volume_percentile)
            df['is_high_volume'] = (df['volume'] > 0.75 * df['volume_sma']) & (df['volume'] > df['volume'].shift(1))
            
            # Price action conditions
            df['has_higher_high'] = df['high'] > df['high'].shift(1)
            df['no_narrow_range'] = is_in_top_percent(df['bar_range'], lookback, range_percentile)
            
            # Low price condition
            df['is_in_the_lows'] = (
                (df['low'] - df['macro_low']).abs() < df['bar_range']
            ) | is_in_bottom_percent(df['low'], volume_lookback, low_percentile)
            
            # Close position conditions
            df['close_in_the_highs'] = (
                (df['close'] - df['low']) / df['bar_range']
            ) >= (close_off_lows_percent / 100)
            
            # Previous close distance condition
            df['far_prev_close'] = (
                (df['close'] - df['close'].shift(1)).abs() >=
                (df['bar_range'].shift(1) * (prev_close_range / 100))
            )
            
            # New highs condition
            df['new_highs'] = df['high'] >= 0.75 * df['highest_high']
            
            # Optional strength condition
            df['strong_close'] = df['close'] >= df['highest_high'].shift(1)
            
            # Now check the actual values for the last few bars
            last_rows = df.tail(3)
            
            print("\nAnalyzing last 3 bars:")
            for idx, row in last_rows.iterrows():
                print(f"\nBar at {idx.strftime('%Y-%m-%d')}:")
                print(f"  is_high_volume: {row['is_high_volume']}")
                print(f"  has_higher_high: {row['has_higher_high']}")
                print(f"  no_narrow_range: {row['no_narrow_range']}")
                print(f"  close_in_the_highs: {row['close_in_the_highs']}")
                print(f"  far_prev_close: {row['far_prev_close']}")
                print(f"  excess_range: {row['excess_range']}")
                print(f"  excess_volume: {row['excess_volume']}")
                print(f"  new_highs: {row['new_highs']}")
                print(f"  is_in_the_lows: {row['is_in_the_lows']}")
                print(f"  volume: {row['volume']}, volume_sma: {row['volume_sma']}")
                print(f"  bar_range: {row['bar_range']}, range_sma: {row['range_sma']}")
                
            # Run the original function to confirm
            start_bar_pattern = calculate_start_bar(df)
            print(f"\nFinal Start Bar detection result:")
            print(start_bar_pattern.tail(3))
            
    except Exception as e:
        print(f"Error in debug: {str(e)}")
    finally:
        await client.close_session()

# Replace the last part of your script with this:
if __name__ == "__main__":
    try:
        # For Jupyter/IPython environments
        import nest_asyncio
        nest_asyncio.apply()
        asyncio.run(debug_start_bar_detection())
    except ImportError:
        # For regular Python environments
        asyncio.run(debug_start_bar_detection())

# %%
#zip the project

import shutil
import os

# Go to parent directory of your project
os.chdir("/home/jovyan/work/Crypto/sevenfigures-bot/hbs_2025")

# Create the zip file (this will include everything inside 'hbs_2025')
shutil.make_archive("Project_VSA_2025_backup", 'zip', "Project")

# %%
# ARCHIVE - Confluence Scanner with bar offset

from telegram.ext import Application
import logging
import pandas as pd
import numpy as np
import asyncio
import logging
import nest_asyncio
from datetime import datetime
from tqdm.asyncio import tqdm
import sys
import os
import html

# Add project path
project_dir = os.path.join(os.getcwd(), "Project")
sys.path.insert(0, project_dir)

from exchanges.sf_pairs_service import SFPairsService
from custom_strategies import detect_confluence

class ConfluenceScanner:
    def __init__(self, telegram_token, telegram_chat_id, exchange, timeframe, offset=1):
        self.telegram_token = telegram_token
        self.telegram_chat_id = telegram_chat_id
        self.telegram_app = None
        self.exchange = exchange
        self.timeframe = timeframe
        self.offset = offset  # Added offset parameter
        self.sf_service = SFPairsService()
        
    async def init_telegram(self):
        if self.telegram_app is None:
            self.telegram_app = Application.builder().token(self.telegram_token).build()

    async def send_telegram_alert(self, results):
        if not results:
            return
            
        try:
            message = f"🚨 Confluence Detection - {self.exchange} {self.timeframe}\n\n"
            
            # Map timeframe to TradingView format
            tv_timeframe_map = {
                "1d": "1D",
                "2d": "2D",
                "1w": "1W"
            }
            tv_timeframe = tv_timeframe_map.get(self.timeframe.lower(), self.timeframe)
            
            for result in results:
                exchange_name = self.exchange.upper()
                formatted_symbol = f"{result['symbol']}"
                tv_link = f"https://www.tradingview.com/chart/?symbol={exchange_name}:{formatted_symbol}&interval={tv_timeframe}"
                
                # Escape HTML entities in the URL
                escaped_link = html.escape(tv_link)
                
                # Format according to specified requirements
                time_str = ""
                if result.get('timestamp') is not None:
                    time_str = f"Time: {result['timestamp'].strftime('%Y-%m-%d %H:%M:%S')}\n"
                
                message += (
                    f"Symbol: {result['symbol']}\n"
                    f"{time_str}"
                    f"Volume USD: ${result['volume_usd']:,.2f}\n"
                    f"Close: <a href='{escaped_link}'>${result['close']:,.8f}</a>\n"
                    f"Volume Ratio: {result['volume_ratio']:.2f}x\n"
                    f"Close Off Low: {result['close_off_low']:.1f}%\n"
                    f"{'='*30}\n"
                )
            
            # Split message more carefully to avoid breaking HTML tags
            max_length = 4000  # Reduced from 4096 to be safer
            
            if len(message) > max_length:
                # Split at natural breaks (between results) to avoid breaking HTML
                sections = message.split('='*30 + '\n')
                current_chunk = ""
                
                for section in sections:
                    if len(current_chunk + section + '='*30 + '\n') > max_length:
                        if current_chunk:
                            await self.telegram_app.bot.send_message(
                                chat_id=self.telegram_chat_id,
                                text=current_chunk.strip(),
                                parse_mode='HTML',
                                disable_web_page_preview=True
                            )
                        current_chunk = section + '\n'
                    else:
                        current_chunk += section + '='*30 + '\n'
                
                # Send remaining chunk
                if current_chunk.strip():
                    await self.telegram_app.bot.send_message(
                        chat_id=self.telegram_chat_id,
                        text=current_chunk.strip(),
                        parse_mode='HTML',
                        disable_web_page_preview=True
                    )
            else:
                await self.telegram_app.bot.send_message(
                    chat_id=self.telegram_chat_id,
                    text=message,
                    parse_mode='HTML',
                    disable_web_page_preview=True
                )
                
        except Exception as e:
            logging.error(f"Error sending Telegram alert: {str(e)}")
            
            # Fallback: send without HTML formatting
            try:
                simple_message = f"🚨 Confluence Detection - {self.exchange} {self.timeframe}\n\n"
                for result in results:
                    simple_message += (
                        f"Symbol: {result['symbol']}\n"
                        f"Volume USD: ${result['volume_usd']:,.2f}\n"
                        f"Close: ${result['close']:,.8f}\n"
                        f"Volume Ratio: {result['volume_ratio']:.2f}x\n"
                        f"Components: Vol={result['high_volume']}, Spread={result['spread_breakout']}, Mom={result['momentum_breakout']}\n\n"
                    )
                
                await self.telegram_app.bot.send_message(
                    chat_id=self.telegram_chat_id,
                    text=simple_message,
                    disable_web_page_preview=True
                )
            except Exception as fallback_error:
                logging.error(f"Fallback Telegram send also failed: {str(fallback_error)}")

    def prepare_sf_data(self, raw_df):
        """Convert SF data to confluence-compatible format"""
        if raw_df is None or len(raw_df) == 0:
            return None
        
        df = pd.DataFrame(raw_df)
        
        # Convert datetime column to pandas datetime and set as index
        if 'datetime' in df.columns:
            df['datetime'] = pd.to_datetime(df['datetime'])
            df = df.set_index('datetime')
        elif 'time' in df.columns:
            # Convert Unix timestamp to datetime
            df['time'] = pd.to_datetime(df['time'], unit='ms')
            df = df.set_index('time')
        
        # Select only OHLCV columns needed for confluence
        required_cols = ['open', 'high', 'low', 'close', 'volume']
        available_cols = [col for col in required_cols if col in df.columns]
        
        if len(available_cols) != 5:
            return None
        
        # Select and clean data
        result_df = df[required_cols].copy()
        
        # Ensure numeric types
        for col in required_cols:
            result_df[col] = pd.to_numeric(result_df[col], errors='coerce')
        
        # Drop any NaN rows
        result_df = result_df.dropna()
        
        return result_df

    def scan_single_market(self, pair, ohlcv_data):
        """Scan a single market for Confluence pattern in the specified bar"""
        try:
            # Prepare data for confluence analysis
            df = self.prepare_sf_data(ohlcv_data)
            
            if df is None or len(df) < 50:  # Need enough data for confluence
                return None
            
            # Calculate which bar to check based on offset
            check_bar = -(self.offset + 1)  # offset=0 means current bar (-1), offset=1 means last closed (-2), etc.
            
            # Run confluence detection
            detected, result = detect_confluence(df, check_bar=check_bar)
            
            if detected:
                # Calculate volume in USD for the target bar
                target_close = df['close'].iloc[check_bar]
                target_volume = df['volume'].iloc[check_bar]
                volume_usd = float(target_close) * float(target_volume)
                
                confluence_result = {
                    'symbol': f"{pair['Token']}{pair['Quote']}",
                    'volume_usd': volume_usd,
                    'close': float(target_close),
                    'volume': float(target_volume),
                    'volume_ratio': result['volume_ratio'],
                    'close_off_low': result['close_off_low'],
                    'momentum_score': result['momentum_score'],
                    'high_volume': result['high_volume'],
                    'spread_breakout': result['spread_breakout'],
                    'momentum_breakout': result['momentum_breakout'],
                    'bar_range': result['bar_range']
                }
                return confluence_result
                
        except Exception as e:
            logging.error(f"Error processing {pair['Token']}{pair['Quote']}: {str(e)}")
        return None

    async def scan_all_markets(self):
        """Scan all markets for Confluence pattern"""
        await self.init_telegram()
        try:
            # Define volume thresholds
            volume_thresholds = {
                "1w": 300000,
                "2d": 100000,
                "1d": 50000
            }
            min_volume = volume_thresholds.get(self.timeframe.lower(), 50000)
            
            # Create offset description
            if self.offset == 0:
                offset_desc = "current candle"
            elif self.offset == 1:
                offset_desc = "last closed candle"
            else:
                offset_desc = f"{self.offset} candles ago"
            
            print(f"Scanning for Confluence patterns in {offset_desc}...")
            print(f"Minimum volume threshold: ${min_volume:,.0f}")
            
            # Get all pairs from SF service
            pairs = self.sf_service.get_pairs_of_exchange(self.exchange)
            print(f"Found {len(pairs)} markets to scan...")
            
            # Process all pairs with progress bar
            all_results = []
            with tqdm(total=len(pairs), desc="Scanning markets") as pbar:
                for pair in pairs:
                    try:
                        # Get OHLCV data from SF service
                        ohlcv_data = self.sf_service.get_ohlcv_for_pair(
                            pair['Token'], 
                            pair['Quote'], 
                            self.exchange, 
                            self.timeframe, 
                            100  # Get more data for confluence analysis
                        )
                        
                        if ohlcv_data is None or len(ohlcv_data) == 0:
                            pbar.update(1)
                            continue
                        
                        df = pd.DataFrame(ohlcv_data)
                        
                        # Check if we have enough data
                        if len(df) >= 50:  # Need enough for confluence analysis
                            target_idx = -(self.offset + 1)  # Adjust index based on offset
                            
                            # Check volume threshold for the target candle
                            try:
                                target_candle_volume = float(df['close'].iloc[target_idx]) * float(df['volume'].iloc[target_idx])
                                
                                # Only process if volume meets threshold
                                if target_candle_volume >= min_volume:
                                    result = self.scan_single_market(pair, ohlcv_data)
                                    if result:
                                        all_results.append(result)
                                        print(f"Found Confluence: {pair['Token']}{pair['Quote']} 🎯")
                            except (IndexError, ValueError):
                                pass  # Skip if we can't calculate volume
                                    
                    except Exception as e:
                        if "500" not in str(e):  # Don't log 500 errors
                            logging.error(f"Error processing {pair['Token']}{pair['Quote']}: {str(e)}")
                    finally:
                        pbar.update(1)
            
            # Sort by volume
            all_results.sort(key=lambda x: x['volume_usd'], reverse=True)
            
            # Send Telegram alert if we found any patterns
            if all_results:
                await self.send_telegram_alert(all_results)
            
            return all_results
            
        except Exception as e:
            logging.error(f"Error scanning markets: {str(e)}")
            return []

async def run_confluence_scanner(exchange, timeframe, offset=1):
    """
    Run the Confluence scanner
    
    Parameters:
    exchange (str): Exchange name (Kucoin, Mexc, Binance)
    timeframe (str): Time period (1d, 2d, 1w)
    offset (int): Bar offset (0=current, 1=last closed, 2=two bars ago, etc.)
    """
    
    if offset == 0:
        offset_desc = "current candle"
    elif offset == 1:
        offset_desc = "last closed candle"
    else:
        offset_desc = f"{offset} candles ago"
    
    print(f"Starting Confluence scan for {offset_desc} on {exchange} {timeframe}...")
    
    # Use the confluence telegram token from your big project config
    # You should replace this with the actual token from utils/config.py TELEGRAM_TOKENS["confluence"]
    telegram_token = "8066329517:AAHVr6kufZWe8UqCKPfmsRhSPleNlt_7G-g"  # Replace with confluence token
    telegram_chat_id = "375812423"  # Your chat ID
    
    scanner = ConfluenceScanner(telegram_token, telegram_chat_id, exchange, timeframe, offset)
    results = await scanner.scan_all_markets()
    
    if results:
        print(f"\nFound {len(results)} Confluence patterns:")
        
        # Convert results to DataFrame for console display
        df_results = pd.DataFrame(results)
        
        # Round numeric columns
        df_results['volume_usd'] = df_results['volume_usd'].round(2)
        df_results['close'] = df_results['close'].round(8)
        df_results['volume'] = df_results['volume'].round(2)
        df_results['volume_ratio'] = df_results['volume_ratio'].round(2)
        df_results['close_off_low'] = df_results['close_off_low'].round(1)
        df_results['momentum_score'] = df_results['momentum_score'].round(4)
        
        # Reorder columns for better display
        display_cols = ['symbol', 'close', 'volume_usd', 'volume_ratio', 'close_off_low', 
                       'momentum_score', 'high_volume', 'spread_breakout', 'momentum_breakout']
        available_cols = [col for col in display_cols if col in df_results.columns]
        
        # Display the results
        print(df_results[available_cols])
        
        # Show component analysis
        print(f"\n🔧 COMPONENT ANALYSIS:")
        vol_count = df_results['high_volume'].sum()
        spread_count = df_results['spread_breakout'].sum()
        momentum_count = df_results['momentum_breakout'].sum()
        
        print(f"High Volume signals: {vol_count}/{len(results)} ({vol_count/len(results)*100:.1f}%)")
        print(f"Spread Breakout signals: {spread_count}/{len(results)} ({spread_count/len(results)*100:.1f}%)")
        print(f"Momentum Breakout signals: {momentum_count}/{len(results)} ({momentum_count/len(results)*100:.1f}%)")
        
    else:
        print(f"\nNo Confluence patterns found in {offset_desc}")

# Set up logging
logging.basicConfig(level=logging.ERROR)

# Apply nest_asyncio to allow async operations in Jupyter
nest_asyncio.apply()

# Example usage functions
async def scan_current_confluence():
    """Scan current candle for confluence"""
    await run_confluence_scanner("Kucoin", "1w", offset=0)

async def scan_closed_confluence():
    """Scan last closed candle for confluence"""
    await run_confluence_scanner("Kucoin", "1w", offset=1)

async def scan_previous_confluence():
    """Scan two candles ago for confluence"""
    await run_confluence_scanner("Kucoin", "1w", offset=2)

# Main execution function
async def main():
    """
    Main execution - modify parameters here
    """
    exchange = "Mexc"  # Binance, Kucoin, Mexc
    timeframe = "1w"     # 1d, 2d, 1w
    offset = 0           # 0 = current candle, 1 = last closed candle, 2 = two candles ago
    
    await run_confluence_scanner(exchange, timeframe, offset)

# Run the async main function
print("🔍 CONFLUENCE SCANNER")
print("=" * 30)
print("Available functions:")
print("• await main() - Run with default settings")
print("• await scan_current_confluence() - Scan current candle")
print("• await scan_closed_confluence() - Scan last closed candle")
print("• await scan_previous_confluence() - Scan two candles ago")
print("• await run_confluence_scanner('Exchange', 'timeframe', offset) - Custom scan")
print("\nExample: await main()")

# Uncomment to auto-run:
await main()

# %%
# Direct Test Bar Pattern Tester
# This script directly tests the calculate_test_bar function

import sys
import os
import logging
import pandas as pd
import numpy as np
import nest_asyncio
import asyncio
from tqdm.notebook import tqdm

# Apply nest_asyncio to make asyncio work in Jupyter
nest_asyncio.apply()

# Setup logging
logging.basicConfig(level=logging.INFO, format='%(levelname)s: %(message)s')

# Add project directory to path
project_dir = os.path.join(os.getcwd(), "Project")
sys.path.insert(0, project_dir)
print(f"✓ Added {project_dir} to sys.path")

# Import the necessary modules
from exchanges import MexcSpotClient, BybitSpotClient, KucoinSpotClient

def calculate_test_bar_direct(df):
    """
    Direct implementation of Test Bar pattern detection for testing
    """
    df = df.copy()
    
    # Calculate basic metrics
    df['bar_range'] = df['high'] - df['low']
    
    # Function to check if current bar is an inside bar
    df['is_inside_bar'] = (df['high'] < df['high'].shift(1)) & (df['low'] > df['low'].shift(1))
    
    # Function to check if bar is down (close < open)
    df['is_down_bar'] = df['close'] < df['open']
    
    # Function to check if close is in higher 65% of the spread (closing off the lows)
    df['close_position'] = np.where(df['bar_range'] != 0, (df['close'] - df['low']) / df['bar_range'], 0)
    df['close_off_lows'] = df['close_position'] >= 0.65
    
    # Function to check if current volume is less than 40% of previous bar volume
    df['lower_volume_than_prev'] = df['volume'] < (df['volume'].shift(1) * 0.4)
    
    # Function to check if current volume is the lowest in last 3 bars
    df['lowest_volume_in_3_bars'] = (df['volume'] < df['volume'].shift(1)) & (df['volume'] < df['volume'].shift(2))
    
    # Debug columns
    df['debug_inside'] = df['is_inside_bar']
    df['debug_down'] = df['is_down_bar'] 
    df['debug_close_off_lows'] = df['close_off_lows']
    df['debug_lower_vol'] = df['lower_volume_than_prev']
    df['debug_lowest_vol_3'] = df['lowest_volume_in_3_bars']
    
    # Main condition: all criteria must be met
    test_bar_pattern = (
        df['is_inside_bar'] &
        df['is_down_bar'] &
        df['close_off_lows'] &
        df['lower_volume_than_prev'] &
        df['lowest_volume_in_3_bars']
    )
    
    # Signal only new occurrences
    test_bar = test_bar_pattern & ~test_bar_pattern.shift(1).fillna(False)
    
    return test_bar, df

async def test_direct_test_bar(exchange_client_class, timeframe, symbol):
    """Test the direct test_bar function on a specific symbol"""
    print(f"Testing DIRECT Test Bar detection on {symbol} ({timeframe})")
    
    # Initialize exchange client and fetch data
    client = exchange_client_class(timeframe=timeframe)
    try:
        await client.init_session()
        df = await client.fetch_klines(symbol)
    except Exception as e:
        print(f"Error fetching data for {symbol}: {str(e)}")
        return
    finally:
        await client.close_session()
    
    if df is None or len(df) < 10:
        print(f"No data fetched for {symbol} or insufficient data")
        return
    
    print(f"\\nLast 5 bars for {symbol}:")
    print(df[['open', 'high', 'low', 'close', 'volume']].tail(5))
    
    # Apply direct test_bar function
    print("\\nApplying direct test_bar detection...")
    try:
        test_bar_signals, df_with_debug = calculate_test_bar_direct(df)
        
        # Quick results first
        current_detected = test_bar_signals.iloc[-1]
        prev_detected = test_bar_signals.iloc[-2] if len(df) > 1 else False
        
        print("\\n" + "="*60)
        print("QUICK RESULTS")
        print("="*60)
        print(f"Current Bar Test Pattern:  {current_detected}")
        print(f"Previous Bar Test Pattern: {prev_detected}")
        
        # If pattern detected, show which bar(s)
        if current_detected or prev_detected:
            print("\\nPATTERN DETECTED!")
            if current_detected:
                print("  -> Current bar matches test pattern")
            if prev_detected:
                print("  -> Previous bar matches test pattern")
        else:
            print("\\nNO PATTERN DETECTED")
        
        print("\\n" + "="*60)
        print("CONDITION BREAKDOWN")
        print("="*60)
        
        # Show only last 2 bars for condition analysis
        for i in range(max(0, len(df)-2), len(df)):
            if i < 2:  # Skip early bars that don't have enough history
                continue
            
            bar_range = df['high'].iloc[i] - df['low'].iloc[i]
            close_position = (df['close'].iloc[i] - df['low'].iloc[i]) / bar_range * 100 if bar_range > 0 else 0
            
            print(f"\\nBAR {i} ({df.index[i].date()})")
            print(f"OHLC: O={df['open'].iloc[i]:.6f} H={df['high'].iloc[i]:.6f} L={df['low'].iloc[i]:.6f} C={df['close'].iloc[i]:.6f}")
            print(f"Volume: {df['volume'].iloc[i]:,.0f}")
            
            if i > 0:
                prev_high = df['high'].iloc[i-1]
                prev_low = df['low'].iloc[i-1]
                prev_volume = df['volume'].iloc[i-1]
                volume_40_pct = prev_volume * 0.4
                
                # Show conditions in a clean table format
                conditions = [
                    ("Inside Bar", df_with_debug['debug_inside'].iloc[i]),
                    ("Down Bar", df_with_debug['debug_down'].iloc[i]),
                    ("Close >= 65% from Low", df_with_debug['debug_close_off_lows'].iloc[i]),
                    ("Volume < 40% of Previous", df_with_debug['debug_lower_vol'].iloc[i]),
                    ("Lowest Volume in 3 bars", df_with_debug['debug_lowest_vol_3'].iloc[i])
                ]
                
                print("\\nConditions:")
                for condition_name, result in conditions:
                    status = "✓" if result else "✗"
                    print(f"  {status} {condition_name:<25} {result}")
                
                # Show key metrics
                print("\\nKey Metrics:")
                print(f"  Close Position: {close_position:.1f}% from low")
                print(f"  Current Volume: {df['volume'].iloc[i]:,.0f}")
                print(f"  40% of Prev Vol: {volume_40_pct:,.0f}")
                
                if i > 1:
                    vol_prev_2 = df['volume'].iloc[i-2]
                    print(f"  Previous Vol: {prev_volume:,.0f}")
                    print(f"  Previous-2 Vol: {vol_prev_2:,.0f}")
                
                # Final result for this bar
                all_conditions_met = all(result for _, result in conditions)
                print(f"\\nAll Conditions Met: {all_conditions_met}")
                print(f"Test Bar Signal: {test_bar_signals.iloc[i]}")
                print("-" * 50)
        
    except Exception as e:
        print(f"Error running direct test_bar detection: {str(e)}")
        import traceback
        traceback.print_exc()

# Test parameters
exchange_client = KucoinSpotClient
timeframe = "1d"
symbol = "TEL-USDT"

# Run the test
await test_direct_test_bar(exchange_client, timeframe, symbol)

print("\\n✅ Direct test bar detection test completed")

# %%
"""
Standalone HLC Bar Chart Plotter
A reusable function for plotting HLC bars with optional pattern highlighting
"""

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
from matplotlib.lines import Line2D

def plot_hlc_bars(data, highlighted_bars=None, title="HLC Chart", symbol="SYMBOL", 
                  interval="1d", semilog=False, highlight_color="fuchsia", 
                  highlight_label="Pattern", figsize=(14, 10), show_volume=True):
    """
    Plot HLC bar chart with optional pattern highlighting
    
    Parameters:
    -----------
    data : pandas.DataFrame
        DataFrame with columns: ['datetime', 'high', 'low', 'close', 'volume']
        - datetime: timestamp column (will be used for x-axis)
        - high: high prices
        - low: low prices  
        - close: close prices
        - volume: volume data (optional if show_volume=False)
        
    highlighted_bars : pandas.Series or list/array, optional
        Boolean series or array indicating which bars to highlight
        Length must match data length
        
    title : str, default "HLC Chart"
        Chart title
        
    symbol : str, default "SYMBOL" 
        Symbol name for display
        
    interval : str, default "1d"
        Time interval for date formatting (1m, 5m, 15m, 30m, 1h, 4h, 1d, 3d, 1w, 1M)
        
    semilog : bool, default False
        Use logarithmic scale for price chart
        
    highlight_color : str, default "fuchsia"
        Color for highlighted bars
        
    highlight_label : str, default "Pattern"
        Label for highlighted bars in legend
        
    figsize : tuple, default (14, 10)
        Figure size (width, height)
        
    show_volume : bool, default True
        Whether to show volume subplot
        
    Returns:
    --------
    matplotlib.figure.Figure
        The created figure object
    """
    
    # Input validation
    if not isinstance(data, pd.DataFrame):
        raise ValueError("data must be a pandas DataFrame")
    
    # Check required columns
    required_cols = ['datetime', 'high', 'low', 'close']
    if show_volume:
        required_cols.append('volume')
    
    missing_cols = [col for col in required_cols if col not in data.columns]
    if missing_cols:
        raise ValueError(f"Missing required columns: {missing_cols}")
    
    if len(data) == 0:
        raise ValueError("data DataFrame is empty")
    
    # Validate highlighted_bars
    if highlighted_bars is not None:
        if len(highlighted_bars) != len(data):
            raise ValueError("highlighted_bars length must match data length")
        # Convert to boolean array
        highlighted_bars = np.array(highlighted_bars, dtype=bool)
    else:
        highlighted_bars = np.zeros(len(data), dtype=bool)
    
    # Create figure with subplots
    if show_volume:
        fig, (ax1, ax2) = plt.subplots(2, 1, figsize=figsize, 
                                       gridspec_kw={'height_ratios': [3, 1]})
    else:
        fig, ax1 = plt.subplots(1, 1, figsize=figsize)
        ax2 = None
    
    # Convert dates to numbers for plotting
    dates = mdates.date2num(data['datetime'])
    
    # Calculate margins and tick length
    date_range = dates[-1] - dates[0] if len(dates) > 1 else 1
    margin = date_range * 0.05
    
    # Calculate actual bar spacing for consistent tick length
    if len(dates) > 1:
        avg_bar_spacing = date_range / (len(dates) - 1)
        tick_length = avg_bar_spacing * 0.4  # 40% of bar spacing
        volume_bar_width = avg_bar_spacing * 0.8
    else:
        tick_length = date_range * 0.01
        volume_bar_width = date_range * 0.02
    
    # Draw HLC bars
    for i, (date, high, low, close) in enumerate(zip(dates, data['high'], data['low'], data['close'])):
        is_highlighted = highlighted_bars[i]
        color = highlight_color if is_highlighted else 'black'
        line_width = 1.2
        
        # Vertical line from low to high
        ax1.plot([date, date], [low, high], color=color, linewidth=line_width, solid_capstyle='butt')
        
        # Horizontal tick mark for close (on the right side)
        ax1.plot([date, date + tick_length], [close, close], color=color, 
                linewidth=line_width+0.5, solid_capstyle='butt')
    
    # Configure price chart
    if semilog:
        ax1.set_yscale('log')
        scale_text = "Semilog Scale"
    else:
        scale_text = "Linear Scale"
    
    ax1.set_title(f'{symbol} {title} - {scale_text}', fontsize=16, fontweight='bold')
    ax1.set_ylabel('Price', fontsize=12)
    ax1.grid(True, alpha=0.3)
    
    # Format x-axis based on timeframe
    _format_datetime_axis(ax1, interval)
    ax1.set_xlim(dates[0] - margin, dates[-1] + margin)
    
    # Volume chart
    if show_volume and ax2 is not None:
        volume_colors = [highlight_color if highlighted_bars[i] else 'orange' for i in range(len(dates))]
        volume_edges = ['darkmagenta' if highlighted_bars[i] else 'darkorange' for i in range(len(dates))]
        
        ax2.bar(dates, data['volume'], width=volume_bar_width, alpha=0.6, 
                color=volume_colors, edgecolor=volume_edges)
        ax2.set_ylabel('Volume', fontsize=12)
        ax2.set_xlabel('Date', fontsize=12)
        ax2.grid(True, alpha=0.3)
        
        _format_datetime_axis(ax2, interval)
        ax2.set_xlim(dates[0] - margin, dates[-1] + margin)
        plt.setp(ax2.xaxis.get_majorticklabels(), rotation=45)
    else:
        ax1.set_xlabel('Date', fontsize=12)
    
    # Create legend
    legend_elements = [
        Line2D([0], [0], color='black', linewidth=2, label='High-Low Range'),
        Line2D([0], [0], color='black', linewidth=3, label='Close Price (right tick)')
    ]
    
    # Add highlighted bars to legend if any exist
    if highlighted_bars.any():
        legend_elements.append(
            Line2D([0], [0], color=highlight_color, linewidth=3, label=highlight_label)
        )
        highlight_count = highlighted_bars.sum()
    else:
        highlight_count = 0
    
    ax1.legend(handles=legend_elements, loc='upper left', title=scale_text)
    
    # Add pattern count if patterns exist
    if highlight_count > 0:
        ax1.text(0.99, 0.95, f'{highlight_label}: {highlight_count}', 
                transform=ax1.transAxes, ha='right', va='top',
                bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.8),
                fontsize=10)
    
    plt.setp(ax1.xaxis.get_majorticklabels(), rotation=45)
    plt.tight_layout()
    
    return fig

def _format_datetime_axis(ax, interval):
    """Helper function to format datetime axis based on interval"""
    if interval in ['1m', '5m', '15m', '30m']:
        ax.xaxis.set_major_locator(mdates.HourLocator(interval=6))
        ax.xaxis.set_major_formatter(mdates.DateFormatter('%m-%d %H:%M'))
    elif interval in ['1h', '2h', '4h', '6h', '12h']:
        ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
        ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
    elif interval in ['1d', '3d']:
        ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
        ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
    else:  # weekly, monthly
        ax.xaxis.set_major_locator(mdates.MonthLocator(interval=6))
        ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# Example usage and test function
def example_usage():
    """Example showing how to use the plot_hlc_bars function"""
    
    # Create sample data
    import datetime
    dates = pd.date_range('2023-01-01', periods=100, freq='D')
    np.random.seed(42)
    
    # Generate realistic OHLC data
    closes = 100 + np.cumsum(np.random.randn(100) * 0.02)
    highs = closes + np.random.rand(100) * 5
    lows = closes - np.random.rand(100) * 5
    volumes = np.random.rand(100) * 1000000
    
    data = pd.DataFrame({
        'datetime': dates,
        'high': highs,
        'low': lows, 
        'close': closes,
        'volume': volumes
    })
    
    # Create some random pattern detections
    pattern_detected = np.random.choice([True, False], size=100, p=[0.1, 0.9])
    
    # Plot with pattern highlighting
    fig = plot_hlc_bars(
        data=data,
        highlighted_bars=pattern_detected,
        title="Daily Chart with Pattern Detection",
        symbol="EXAMPLE",
        interval="1d",
        semilog=False,
        highlight_color="red",
        highlight_label="Detected Pattern"
    )
    
    plt.show()
    return fig

# Scanner integration example
def scanner_integration_example():
    """Example of how to integrate with a scanner function"""
    
    def my_pattern_scanner(data):
        """
        Example scanner function - replace with your actual scanner logic
        Returns boolean array indicating pattern detection
        """
        # Example: detect when close > 20-period moving average
        ma20 = data['close'].rolling(20).mean()
        pattern = (data['close'] > ma20) & (data['volume'] > data['volume'].rolling(10).mean())
        return pattern.fillna(False)
    
    # Your data loading logic here
    # data = load_your_data()  # Replace with actual data loading
    
    # For demo, create sample data
    dates = pd.date_range('2023-01-01', periods=200, freq='D')
    np.random.seed(42)
    closes = 100 + np.cumsum(np.random.randn(200) * 0.02)
    highs = closes + np.random.rand(200) * 3
    lows = closes - np.random.rand(200) * 3
    volumes = np.random.rand(200) * 1000000
    
    data = pd.DataFrame({
        'datetime': dates,
        'high': highs,
        'low': lows,
        'close': closes,
        'volume': volumes
    })
    
    # Run your scanner
    detected_patterns = my_pattern_scanner(data)
    
    # Plot only if patterns are detected
    if detected_patterns.any():
        print(f"Patterns detected! Found {detected_patterns.sum()} occurrences")
        fig = plot_hlc_bars(
            data=data,
            highlighted_bars=detected_patterns,
            title="Scanner Results",
            symbol="SCANNED_SYMBOL",
            interval="1d",
            highlight_color="lime",
            highlight_label="Scanner Hit"
        )
        plt.show()
    else:
        print("No patterns detected")

if __name__ == "__main__":
    # Run example
    example_usage()
